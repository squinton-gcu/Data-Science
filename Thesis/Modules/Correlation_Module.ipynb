# %% [markdown]
# <a href="https://colab.research.google.com/github/squinton-gcu/Data-Science/blob/main/Thesis/Modules/Correlation_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Correlation Module
# This module will import the processed csv files and the lists of selected features. It will determine if there is any similarities in the files. It then runs a correlation analysis of the similar features between stress and ALZ. It calculates pvalues, standard error, RMSE, and spearman correlation coefficient.
# It outputs into files.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm 
from scipy import stats
from sklearn.model_selection import train_test_split
from statsmodels.tools.eval_measures import rmse
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read in files
ALZ_plasma_feat = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/ALZ_plasma_selected_features.csv", index_col=0)
ALZ_csf_feat = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/ALZ_csf_selected_features.csv", index_col=0)
trauma_human_feat = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/trauma_human_selected_features.csv", index_col=0)

ALZ_plasma_p = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/ALZ_plasma_processed.csv", index_col=0).transpose()
ALZ_csf_p = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/ALZ_csf_processed.csv", index_col=0).transpose()
trauma_human_p = pd.read_csv("/content/drive/MyDrive/Thesis/Processed/trauma_human_processed.csv", index_col=0).transpose()

# %%
ALZ_plasma_feat.columns
# Out:
# Index(['C49 H30 Cl N O', '11-deoxy-PGE2',
#        '1-Hexadecyl-2-arachidonoyl-glycerol', 'C31 H59 Cl N6 O2',
#        'C51 H36 Cl N', 'C4 H4 N4 O2', 'BiliverdinIX+1.4045436', 'C23 H5 N O',
#        'C4 H8 N2 O4 S', 'C38 H75 N15', 'C13 H23 Cl N4 O S',
#        '5-Acetyl-4-methylthiazole', 'C40 H34 Cl N3 O2', 'C38 H58 N6 O4',
#        'Propionylglycine methyl ester', 'C11 H20 N2 O3 S', 'C8 H12 N2 O3 S3',
#        'Glucoheptonicacid', 'GPEtn(16:0/22:6(4Z,7Z,10Z,13Z,16Z,19Z))',
#        'C32 H57 N5 S2', 'C13 H15 N O', 'DIHYDROFISSINOLIDE',
#        '1-octadecanoyl-rac-glycerol', '2-Pyrrolidinone + 2.0697286',
#        'Terephthalicacid', '12-amino-dodecanoicacid', 'Vigabatrin',
#        'C31 H34 N8 O4 S', 'Uricacid', 'C4 H11 N O3 + 6.5848055', 'Uric acid',
#        '2-Hydroxyadipicacid', 'URSINICACID'],
#       dtype='object')

# %%
trauma_human_feat.columns
# Out:
# Index(['hippuric acid', 'gluconic acid lactone', 'glyceric acid', 'mannose',
#        'serine', 'ribonic acid', '2-hydroxybutanoic acid', 'glycine',
#        'taurine', 'alanine', 'squalene', 'aspartic acid', 'glycolic acid',
#        'levoglucosan', 'proline', 'tryptophan', 'arachidic acid',
#        'aminomalonate', 'glucose', 'phosphate', 'UDP-glucuronic acid',
#        'hexuronic acid', '5-methoxytryptamine', 'citric acid',
#        'methionine sulfoxide', 'inosine', 'benzylalcohol', 'ethanolamine',
#        'threitol', 'mannitol', 'fumaric acid'],
#       dtype='object')

# %%
ALZ_csf_feat.columns
# Out:
# Index(['C24 H29 N O3', 'C36 H43 N5 O2', 'C35 H61 N17', 'C33 H24 Cl N S',
#        '2-pentadecenoic acid', '4-Hydroxypyridine', 'C37 H40 N2 O3 S2',
#        'C19 H4 Cl N S', 'Gln Lys Glu', 'C11 H25 N O5', '1a,1b-dihomo-PGJ2',
#        'C5 H5 N5 O3 + 2.1794953', 'C22 H22 Cl N3 O', 'C4 H2 O8 S2',
#        'Isoniazid', 'C10 H21 N O', 'N_N-Didemethylchlorpromazine',
#        'C31 H65 N5 O2 S2', 'C29 H51 Cl N10 O2', 'C4 H7 N3 O', 'C19 H38 N2 O3',
#        'C14 H32 N2 S', 'C10 H20 N6 O', 'beta-vinylacrylicacid',
#        'C28 H5 N5 O16', 'Pyroglutamic acid + 6.857936'],
#       dtype='object')

# %%
stress_topVS_all_plasma = []
for val in trauma_human_feat.columns:
  for col in ALZ_plasma_p.columns:
    if val in col:
      stress_topVS_all_plasma.append(col)

# %%
stress_topVS_all_csf = []
for val in trauma_human_feat.columns:
  for col in ALZ_csf_p.columns:
    if val in col:
      stress_topVS_all_csf.append(col)

# %%
stress_topVS_plasma_top = []
for val in trauma_human_feat.columns:
  for col in ALZ_plasma_feat.columns:
    if val in col:
      stress_topVS_plasma_top.append(col)

# %%
stress_topVS_csf_top = []
for val in trauma_human_feat.columns:
  for col in ALZ_csf_feat.columns:
    if val in col:
      stress_topVS_csf_top.append(col)

# %%
for val in ALZ_csf_feat.columns:
  for col in ALZ_plasma_feat.columns:
    if val in col:
      print(col)

# %%
def calculate_corr(x_array, y_array, metabolite):
  """
  calculates the spearman correlation for the given metabolite. The x_array is a
  dataframe that contains all metabolites. The y_array is the binary variables.
  """
  cor_matrix_initial = pd.DataFrame({metabolite: x_array[metabolite], 'ALZ': y_array})
  corr_matrix = cor_matrix_initial.corr(method='spearman')
  correlation_val = corr_matrix[metabolite][1]
  return correlation_val

# %%
def calculate_log_values(X_train, X_test, Y_train, Y_test, Metabolite):
  """
  This function will take the test and train datasets with the metabolites
  to help run the correlation analysis. The output variables include pvalue
  standard error, RMSE value.
  """
  X_train1 = X_train[Metabolite]
  X_train1 = sm.add_constant(X_train1)
  logreg1 = sm.Logit(Y_train, X_train1).fit()
  pvalue_train = logreg1.pvalues[1]
  stand_error_train = logreg1.bse[1] #standard error

  X_test1 = X_test[Metabolite]
  X_test1 = sm.add_constant(X_test1)
  logreq1_test = sm.Logit(Y_test, X_test1).fit()
  ypred = logreg1.predict(X_test1)
  rmse2 = rmse(Y_test, ypred)

  return pvalue_train, stand_error_train, rmse2

# %%
def correlation_main(dataframe, metabList):
  """
  This function will take the two above functions and complie it into a dataframe.
  The first part creates the test and train dataset from the processed csv file.
  It then will calculate the logistic values for the similar metabolites.
  The output is a dataframe.
  """
  # split data
  train,test = train_test_split(dataframe, test_size=0.4)
  y_train_headers = train.index
  Y_train_num = []
  for i in y_train_headers:
    if i != None and "AD" in i:
      Y_train_num.append(1)
    else:
      Y_train_num.append(0)

  y_test_headers = test.index
  Y_test_num = []
  for i in y_test_headers:
    if i != None and "AD" in i:
      Y_test_num.append(1)
    else:
      Y_test_num.append(0)

  #calculate logistic values
  output_frame = pd.DataFrame()
  for metab in metabList:
    pvalues, standard_error, RMSE_val = calculate_log_values(train, test, Y_train_num, Y_test_num, metab)
    corr_value = calculate_corr(train, Y_train_num, metab)
    logistic_list = [pvalues, standard_error, RMSE_val, corr_value]
    output_frame[metab] = logistic_list

  output_frame.index = ['pvalues', 'standard error', 'RMSE', "Spearman Corr"]

  return output_frame

# %%
stress_top_all_plasma_cor = correlation_main(ALZ_plasma_p, stress_topVS_all_plasma)
stress_top_top_plasma_cor = correlation_main(ALZ_plasma_p, stress_topVS_plasma_top)
stress_top_all_csf_cor = correlation_main(ALZ_csf_p, stress_topVS_all_csf)
stress_top_top_csf_cor = correlation_main(ALZ_csf_p, stress_topVS_csf_top)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# Optimization terminated successfully.
#          Current function value: 0.622670
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.615348
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636331
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.606843
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635884
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.619874
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565316
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.625607
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627250
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635723
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635281
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607889
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.543652
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602852
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.625104
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.604102
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635555
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.609754
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597748
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543690
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.595067
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636270
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.629032
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.636375
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630217
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.631128
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636004
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561790
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.544595
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606816
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.620743
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564335
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590124
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.630390
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.615223
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636167
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.634200
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566101
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.618494
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627825
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.634626
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.634075
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.624284
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.576507
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551417
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613248
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570601
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562534
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605758
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621163
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635734
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566313
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.553359
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597622
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524960
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.618368
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627247
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.523777
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.633745
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596860
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.630389
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554533
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.634301
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.608519
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575138
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570948
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.615122
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.606339
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627211
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636249
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605100
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635167
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592057
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.636510
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.636128
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636211
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575183
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.622451
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.624298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633860
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.625376
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.631727
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.559232
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.636498
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.612646
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.618000
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621454
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.603017
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.620792
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.442359
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.631428
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.485629
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601575
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.614129
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636504
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.594658
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596977
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.526942
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567493
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636369
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.560908
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.683831
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.569657
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588066
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.569527
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.684066
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.474376
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.643173
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571773
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.685257
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.568460
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.682463
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.571021
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.652775
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564022
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.617279
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.526362
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.599159
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.521224
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.625695
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552427
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.686876
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.565586
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663843
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562452
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.674244
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.545978
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.619755
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566871
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.655188
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.559349
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659066
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.548160
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.666467
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570668
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.686840
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.548660
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658343
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649486
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.462858
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.660166
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567674
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.680299
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.508032
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.674188
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.572266
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.609966
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.497027
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.654854
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564407
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.673827
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570668
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.686840
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.566858
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671414
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488061
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.680075
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.570877
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561483
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567171
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573247
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.548660
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658343
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571129
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.686808
#          Iterations 4

# %%
sort_stress_top_all_plasma_cor = stress_top_all_plasma_cor.transpose().sort_values(by=['pvalues'])
sort_stress_top_top_plasma_cor = stress_top_top_plasma_cor.transpose().sort_values(by=['pvalues'])
sort_stress_top_all_csf_cor = stress_top_all_csf_cor.transpose().sort_values(by=['pvalues'])
sort_stress_top_top_csf_cor = stress_top_top_csf_cor.transpose().sort_values(by=['pvalues'])

# %%
sort_stress_top_top_csf_cor
# Out:
# Empty DataFrame
# Columns: [pvalues, standard error, RMSE, Spearman Corr]
# Index: []

# %%
sort_stress_top_all_csf_cor
# Out:
#                                                      pvalues  standard error  \
# Diethanolamine                                      0.033891        1.110180
# Diethanolamine + 5.846524                           0.062883        3.737103
# Diethanolamine+5.846524                             0.077197        3.811653
# D-Homoserine                                        0.116657        0.221461
# Glutarylglycine                                     0.124715        2.070371
# Ethanolamine phosphate (Phosphoethanolamine)        0.252973        0.096475
# 2-Deoxyglucose                                      0.282607        1.281292
# D-4-Hydroxyphenylglycine                            0.295635        0.284597
# Isobutylglycine                                     0.305658        0.315055
# 3-Hydroxy-N-glycyl-2,6-xylidine (3-Hydroxyglyci...  0.393960        0.807965
# Phenylalanine                                       0.411824        1.213331
# Diethanolamine+5.6714797                            0.417262        0.947980
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.442581        1.256771
# Isobutyrylglycine methyl ester                      0.483869        0.439670
# 3-Hydroxy-N-glycyl-2_6-xylidine(3-Hydroxyglycin...  0.517180        0.783562
# Distearylphosphatidylethanolamine                   0.517406        0.767666
# Isobutyrylglycinemethylester                        0.558215        0.430119
# Diethanolamine + 5.564596                           0.578955        0.107305
# L-4-Hydroxy-3-methoxy-a-methylphenylalanine         0.590719        0.912577
# Methyl o-methoxyhippuric acid                       0.606254        0.086966
# Diethanolamine + 5.748325                           0.612784        0.102717
# Diethanolamine+5.564596                             0.629659        1.318553
# 2-Methylbutyrylglycine                              0.642670        0.150972
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.714514        0.104871
# 1-octadecanoyl-2-(9Z-octadecenoyl)-sn-glycero-3...  0.732325        0.272507
# Ethanolaminephosphate(Phosphoethanolamine)          0.768559        0.662928
# Diethanolamine + 5.6714797                          0.784918        0.070366
# 2-Pyridylacetylglycine                              0.795870        0.469462
# Distearyl phosphatidyl ethanolamine                 0.803565        0.624803
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.868770        0.079117
# 1-Methylinosine                                     0.897373        0.873153
# Diethanolamine+5.748325                             0.977696        0.723775
#
#                                                         RMSE  Spearman Corr
# Diethanolamine                                      0.583919      -0.423180
# Diethanolamine + 5.846524                           0.545717      -0.379777
# Diethanolamine+5.846524                             0.539150      -0.314673
# D-Homoserine                                        0.535100      -0.227901
# Glutarylglycine                                     0.616797      -0.292971
# Ethanolamine phosphate (Phosphoethanolamine)        0.561916      -0.054337
# 2-Deoxyglucose                                      0.555194       0.227866
# D-4-Hydroxyphenylglycine                            0.508057      -0.097657
# Isobutylglycine                                     0.534807      -0.238717
# 3-Hydroxy-N-glycyl-2,6-xylidine (3-Hydroxyglyci...  0.499337       0.184463
# Phenylalanine                                       0.523655      -0.162762
# Diethanolamine+5.6714797                            0.561146      -0.130209
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.530424      -0.130209
# Isobutyrylglycine methyl ester                      0.510174      -0.065105
# 3-Hydroxy-N-glycyl-2_6-xylidine(3-Hydroxyglycin...  0.508510       0.130209
# Distearylphosphatidylethanolamine                   0.531309      -0.195314
# Isobutyrylglycinemethylester                        0.511165      -0.032552
# Diethanolamine + 5.564596                           0.539329       0.211622
# L-4-Hydroxy-3-methoxy-a-methylphenylalanine         0.526615      -0.141060
# Methyl o-methoxyhippuric acid                       0.543926      -0.141820
# Diethanolamine + 5.748325                           0.515697       0.027273
# Diethanolamine+5.564596                             0.537509       0.108508
# 2-Methylbutyrylglycine                              0.534283       0.401479
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.521445       0.000000
# 1-octadecanoyl-2-(9Z-octadecenoyl)-sn-glycero-3...  0.528467      -0.108508
# Ethanolaminephosphate(Phosphoethanolamine)          0.537825      -0.010851
# Diethanolamine + 5.6714797                          0.520341      -0.022110
# 2-Pyridylacetylglycine                              0.527653       0.162762
# Distearyl phosphatidyl ethanolamine                 0.534180       0.054254
# 1-heptadecanoyl-2-(9Z-tetradecenoyl)-sn-glycero...  0.530165       0.096542
# 1-Methylinosine                                     0.529372       0.021702
# Diethanolamine+5.748325                             0.528642       0.000000

# %%
sort_stress_top_top_plasma_cor
# Out:
#                                 pvalues  standard error      RMSE  \
# Propionylglycine methyl ester  0.106771        0.844985  0.417623
#
#                                Spearman Corr
# Propionylglycine methyl ester       0.324948

# %%
sort_stress_top_all_plasma_cor
# Out:
#                                                      pvalues  standard error  \
# Propionylglycinemethylester                         0.065484        0.775096
# 2-Methylbutyrylglycine+6.5558777                    0.065506        0.354389
# 2-Methylbutyrylglycine                              0.065693        0.477201
# Dimethylglycine+2.8044205                           0.069230        0.816419
# Propionylglycinemethylester+6.2598743               0.072163        0.463442
# Propionylglycine methyl ester + 6.2598743           0.072846        0.476407
# 2-Methylbutyrylglycine + 6.5558777                  0.077885        0.381905
# Propionylglycine methyl ester                       0.097942        0.763496
# 1-O-(1Z-hexadecenyl)-2-(4Z_7Z_10Z_13Z_16Z_19Z-d...  0.102785        0.653800
# Dimethylglycine + 2.8044205                         0.134699        0.694422
# 1-heptadecanoyl, 2-(5Z,8Z,11Z,14Z-eicosatetraen...  0.184349        0.878292
# L-4-Hydroxy-3-methoxy-a-methylphenylalanine         0.227765        0.492124
# Propionylglycinemethylester+3.163646                0.230651        0.331643
# Dimethylglycine+2.050125                            0.241669        0.101024
# Propionylglycine methyl ester + 3.163646            0.286899        0.357967
# Diethanolamine                                      0.297145        0.398007
# Diethanolamine + 6.332912                           0.345113        0.654444
# 2-Methylbutyrylglycine + 2.0774822                  0.380188        0.336460
# Diethanolamine + 5.8253593                          0.388147        1.828074
# Homoserine                                          0.399414        0.514294
# Diethanolamine+6.6559505                            0.461690        0.181264
# 1-Methylinosine                                     0.479480        0.707873
# 2-Methylbutyrylglycine+2.0774822                    0.491431        0.350494
# Dimethylglycine + 6.2130203                         0.513818        0.094927
# Capryloylglycine                                    0.553678        0.297234
# Dimethylglycine + 2.050125                          0.562884        0.070692
# Diethanolamine + 5.649868                           0.565348        0.441101
# 1-heneicosanoyl-2-(4Z_7Z_10Z_13Z_16Z_19Z-docosa...  0.570375        0.623004
# Dimethylglycine+6.4713974                           0.594753        0.955437
# 1-O-(1Z-hexadecenyl)-2-(4Z,7Z,10Z,13Z,16Z,19Z-d...  0.601858        0.440053
# Diethanolamine + 6.525427                           0.608379        0.117883
# 1-(8-[3]-ladderane-octanoyl)-2-(8-[3]-ladderane...  0.702755        0.611371
# Diethanolamine + 6.6559505                          0.702760        0.081465
# Dimethylglycine + 4.069634                          0.716236        0.070287
# 1-heptadecanoyl_2-(5Z_8Z_11Z_14Z-eicosatetraeno...  0.729947        0.587575
# Diethanolamine+5.8253593                            0.787723        1.574879
# 2-Methylbutyrylglycine+3.1958613                    0.796258        0.373898
# Dimethylglycine                                     0.826030        0.184159
# N-arachidonoyl D-serine                             0.852302        0.144568
# Dimethylglycine + 6.4713974                         0.891102        0.846929
# Diethanolamine+5.527126                             0.895127        0.890842
# Diethanolamine+6.525427                             0.899001        0.817157
# 2-Methylbutyrylglycine + 3.1958613                  0.903491        0.417863
# Diethanolamine+5.649868                             0.905027        0.606700
# Dimethylglycine+4.069634                            0.908148        0.098982
# N-arachidonoylD-serine                              0.920202        0.149005
# Dimethylglycine+6.2130203                           0.931301        0.104820
# Diethanolamine + 5.527126                           0.976458        0.582236
# 1-heneicosanoyl-2-(4Z,7Z,10Z,13Z,16Z,19Z-docosa...  0.981709        0.221022
# Diethanolamine+6.332912                             0.987623        0.642512
#
#                                                         RMSE  Spearman Corr
# Propionylglycinemethylester                         0.433224       0.342962
# 2-Methylbutyrylglycine+6.5558777                    0.466580       0.403485
# 2-Methylbutyrylglycine                              0.520616       0.322788
# Dimethylglycine+2.8044205                           0.453713       0.342962
# Propionylglycinemethylester+6.2598743               0.448880       0.383311
# Propionylglycine methyl ester + 6.2598743           0.454579       0.413572
# 2-Methylbutyrylglycine + 6.5558777                  0.465583       0.363137
# Propionylglycine methyl ester                       0.437416       0.282440
# 1-O-(1Z-hexadecenyl)-2-(4Z_7Z_10Z_13Z_16Z_19Z-d...  0.442018      -0.353049
# Dimethylglycine + 2.8044205                         0.449350       0.221917
# 1-heptadecanoyl, 2-(5Z,8Z,11Z,14Z-eicosatetraen...  0.525864       0.272352
# L-4-Hydroxy-3-methoxy-a-methylphenylalanine         0.500558      -0.322837
# Propionylglycinemethylester+3.163646                0.464611       0.201743
# Dimethylglycine+2.050125                            0.477672      -0.040373
# Propionylglycine methyl ester + 3.163646            0.447168       0.131133
# Diethanolamine                                      0.479111      -0.131133
# Diethanolamine + 6.332912                           0.452316      -0.100871
# 2-Methylbutyrylglycine + 2.0774822                  0.477511      -0.151307
# Diethanolamine + 5.8253593                          0.431113      -0.100871
# Homoserine                                          0.486357      -0.221917
# Diethanolamine+6.6559505                            0.475096      -0.010089
# 1-Methylinosine                                     0.449157       0.100871
# 2-Methylbutyrylglycine+2.0774822                    0.476145      -0.151307
# Dimethylglycine + 6.2130203                         0.476949       0.000000
# Capryloylglycine                                    0.490846       0.030261
# Dimethylglycine + 2.050125                          0.466415      -0.071221
# Diethanolamine + 5.649868                           0.491300      -0.010087
# 1-heneicosanoyl-2-(4Z_7Z_10Z_13Z_16Z_19Z-docosa...  0.447196      -0.121046
# Dimethylglycine+6.4713974                           0.476441      -0.080697
# 1-O-(1Z-hexadecenyl)-2-(4Z,7Z,10Z,13Z,16Z,19Z-d...  0.449558      -0.080697
# Diethanolamine + 6.525427                           0.475775      -0.166463
# 1-(8-[3]-ladderane-octanoyl)-2-(8-[3]-ladderane...  0.464476      -0.110958
# Diethanolamine + 6.6559505                          0.467928      -0.131535
# Dimethylglycine + 4.069634                          0.477043       0.010351
# 1-heptadecanoyl_2-(5Z_8Z_11Z_14Z-eicosatetraeno...  0.480581       0.100871
# Diethanolamine+5.8253593                            0.466658      -0.020174
# 2-Methylbutyrylglycine+3.1958613                    0.477058       0.141220
# Dimethylglycine                                     0.470731      -0.100871
# N-arachidonoyl D-serine                             0.472116      -0.171481
# Dimethylglycine + 6.4713974                         0.470566       0.000000
# Diethanolamine+5.527126                             0.473197       0.070610
# Diethanolamine+6.525427                             0.477614      -0.221917
# 2-Methylbutyrylglycine + 3.1958613                  0.466645       0.060523
# Diethanolamine+5.649868                             0.460351      -0.110958
# Dimethylglycine+4.069634                            0.472321      -0.111026
# N-arachidonoylD-serine                              0.470999      -0.201743
# Dimethylglycine+6.2130203                           0.472353       0.070653
# Diethanolamine + 5.527126                           0.471921       0.020174
# 1-heneicosanoyl-2-(4Z,7Z,10Z,13Z,16Z,19Z-docosa...  0.470823      -0.080697
# Diethanolamine+6.332912                             0.471374       0.080697

# %%
#save values
sort_stress_top_all_plasma_cor.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/sort_stress_top_all_plasma_cor.csv")
sort_stress_top_top_plasma_cor.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/sort_stress_top_top_plasma_cor.csv")
sort_stress_top_all_csf_cor.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/sort_stress_top_all_csf_cor.csv")
sort_stress_top_top_csf_cor.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/sort_stress_top_top_csf_cor.csv")

# %%
#create files for graphs
def create_matrix_graph(dataframe, metabList):
  y_dataframe_headers = dataframe.index
  Y_dataframe_num = []
  for i in y_dataframe_headers:
    if i != None and "AD" in i:
      Y_dataframe_num.append(1)
    else:
      Y_dataframe_num.append(0) 

  cor_graph_matrix = pd.DataFrame()
  for metab in metabList:
    cor_graph_matrix[metab] = dataframe[metab]
  cor_graph_matrix["y"] = Y_dataframe_num
  return(cor_graph_matrix)

# %%
plasma_top_stress = create_matrix_graph(ALZ_plasma_p, stress_topVS_plasma_top)
plasma_all_stress = create_matrix_graph(ALZ_plasma_p, stress_topVS_all_plasma)
csf_top_stress = create_matrix_graph(ALZ_csf_p, stress_topVS_csf_top)
csf_all_stress = create_matrix_graph(ALZ_csf_p, stress_topVS_all_csf)

# %%
plasma_top_stress.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/plasma_top_stress_graphs.csv")
plasma_all_stress.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/plasma_all_stress_graph.csv")
csf_top_stress.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/csf_top_stress_graph.csv")
csf_all_stress.to_csv("/content/drive/MyDrive/Thesis/Processed/Selected_Features/csf_all_stress_graph.csv")

# %% [markdown]
# ## References
#
# Difference Between T-test and Linear Regression—Ask Any Difference. (2022, January 22). https://askanydifference.com/difference-between-t-test-and-linear-regression/
#
# Harris, C. R., Millman, K. J., van der Walt, S. J., Gommers, R., Virtanen, P., Cournapeau, D., Wieser, E., Taylor, J., Berg, S., Smith, N. J., Kern, R., Picus, M., Hoyer, S., van Kerkwijk, M. H., Brett, M., Haldane, A., del Río, J. F., Wiebe, M., Peterson, P., … Oliphant, T. E. (2020). Array programming with NumPy. Nature, 585(7825), 357–362. https://doi.org/10.1038/s41586-020-2649-2
#
# Larose, C., & Larose, D. (2019). Data Science Using Python and R. John Wiley & Sons, Inc.
#
# Mukaka, M. (2012). A guide to appropriate use of Correlation coefficient in medical research. Malawi Medical Journal : The Journal of Medical Association of Malawi, 24(3), 69–71.
#
# Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., Blondel, M., Prettenhofer, P., Weiss, R., Dubourg, V., Vanderplas, J., Passos, A., Cournapeau, D., Brucher, M., Perrot, M., & Duchesnay, E. (2011). Scikit-learn: Machine Learning in Python. Journal of Machine Learning Research, 12, 2825–2830.
#
# Ramzai, J. (2021, May 25). Clearly explained: Pearson V/S Spearman Correlation Coefficient. Medium. https://towardsdatascience.com/clearly-explained-pearson-v-s-spearman-correlation-coefficient-ada2f473b8
#
# Reback, J., Jbrockmendel, McKinney, W., Van Den Bossche, J., Augspurger, T., Roeschke, M., Hawkins, S., Cloud, P., Gfyoung, Sinhrks, Hoefler, P., Klein, A., Terji Petersen, Tratner, J., She, C., Ayd, W., Naveh, S., JHM Darbyshire, Garcia, M., … Battiston, P. (2022). pandas-dev/pandas: Pandas 1.4.2 (v1.4.2) [Computer software]. Zenodo. https://doi.org/10.5281/ZENODO.3509134
#
# Seabold, S., & Perktold, J. (2010). statsmodels: Econometric and statistical modeling with python. 9th Python in Science Conference.
#
# Virtanen, P., Gommers, R., Oliphant, T. E., Haberland, M., Reddy, T., Cournapeau, D., Burovski, E., Peterson, P., Weckesser, W., Bright, J., van der Walt, S. J., Brett, M., Wilson, J., Millman, K. J., Mayorov, N., Nelson, A. R. J., Jones, E., Kern, R., Larson, E., … Vázquez-Baeza, Y. (2020). SciPy 1.0: Fundamental algorithms for scientific computing in Python. Nature Methods, 17(3), 261–272. https://doi.org/10.1038/s41592-019-0686-2
#
# Wu, S. (2021, June 5). What are the best metrics to evaluate your regression model? Medium. https://towardsdatascience.com/what-are-the-best-metrics-to-evaluate-your-regression-model-418ca481755b
