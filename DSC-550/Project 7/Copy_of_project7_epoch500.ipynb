# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('/content/gdrive/MyDrive/project_7/data/tinyshakespeare/input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1
epoch = 500

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p, e = 0, 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while e < epoch + 1:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
    print("end of data.... new epoch")
    e += 1
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))
    print("epoch: ", e)

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss))# print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# Streaming output truncated to the last 5000 lines.
# mose esing off me. First this hems not lapss Angemperena
# Constonemard!
# un
# ----
# epoch:  281
# iter 12498400, loss: 38.521443
# ----
#   the nobongher appring as as your at Romes
# I shath part, you had hoirs if I'll name.
# My lord, ye's your want aftouse
# and we night would was Volsce. It thine of you
# Mymongome us mine but of truth well
# ----
# epoch:  281
# iter 12498500, loss: 38.706526
# ----
#  had in paurighted dear toon'd hither, and the depact this
# gone, nor even brief tound stood to-morrow but it hast, to,
# Your tol'
# With his, makes team, while regar,
# If you haming, and trumpeed: the fais
# ----
# epoch:  281
# iter 12498600, loss: 38.517885
# ----
#  o sir? indsting not your lick?
#
# VITHEMER:
# Where remays to beat heart not
# And take thrange it:
# To this hand.
#
# LADY GRETHAGIUS:
# I have heard thee? therek set for the give your pack let I devise.
#
# Prough
# ----
# epoch:  281
# iter 12498700, loss: 38.509147
# ----
#  l it a lasting yourself:
# Nor with compon me hoath'd yoursho and which ca'fore two footish
# our humble.
# But his wonnible nesters.
#
# ANTONIS:
# God' thou as I comes!
#
# CORIOL:
# HASllourenus. You art you hurik
# ----
# epoch:  281
# iter 12498800, loss: 38.574856
# ----
#  e godded and paingly world a fear the too,
# Where's mored of his well all Loveng yo: grow Cauld done shall be them affectio. Buckingled, I would mark, appraft, shavenchio?
# Could is shall showly.
#
# ARSEE
# ----
# epoch:  281
# iter 12498900, loss: 38.192848
# ----
#   stear to't: Is have fountle or wears,
# That shall hear me, map now dely to the broke
# Towry:
# This better me no; what have but thought, and eat and vight take me out at up he uncle the king within.
#
# Lor
# ----
# epoch:  281
# iter 12499000, loss: 37.934295
# ----
#  that the gode you live that have him our askige.
# Thy
# hay, streaver
# Secthins war alls the at heavy thee,
# I' the gray:
# I make o'er
# diret brother; wrenigal.
#
# CATISLEGUS:
# His dewar,
# I patied me King.
#
# GLO
# ----
# epoch:  281
# iter 12499100, loss: 37.713452
# ----
#  od they part the yourtest their honour every herve lack. Thou
# should demance, she of that to death. My shall the cutityed I unsellio's toocy, melt, love
# comant,
# The heavens
# your mortelf, of give I per
# ----
# epoch:  281
# iter 12499200, loss: 37.755266
# ----
#  OUCESTER:
# Is orner; and thy crable,
# Intruet if is o' thy could's master,
# As stelps and your dram.
# Doth.
#
# LORD ROWES:
# Head
# Marry strong the worse: being his sell's calother this miver.
#
# QUEEN ELIZABETH
# ----
# epoch:  281
# iter 12499300, loss: 37.673709
# ----
#  e be'cul my turn:
# Go, but hath all as murdle unditen:
# Sand look they warr not, and that nemant with your church
# If for news hoce, that well man,
# thy orsible we much not and your had what you if wench.
# ----
# epoch:  281
# iter 12499400, loss: 37.633133
# ----
#   with thousand much trilippirmens,
# Besoubly my mine.
#
# Secanovost
# That is if yenard.
#
# RIVERS:
# Yields; I fram: and mupess, you arge, attenack to sider of lowllo up
# of I know,
# Whonce,
# You doat such retee
# ----
# epoch:  281
# iter 12499500, loss: 37.407026
# ----
#  mouly lead-be say
# There I comess, par-rang'd,
# Sourhal. 'Tis swees thunks;
# When triamemblerful-blood thou?
#
# KING EDWARD IV:
# For not wholeptes, prays nor him here childremsh unto that mimer'd thy land,
# ----
# epoch:  281
# iter 12499600, loss: 37.407307
# ----
#  g,
# If thy iuld I be gown my prestors. Whan woman and you a worous herd outard, before not norew, lovinglact park'd more bount charning,
# Alone?
#
# CLARENCG RICHETRBAs:
# I'le it unto pray fis these my proy
# ----
# epoch:  281
# iter 12499700, loss: 37.408824
# ----
#  LOUCESTER:
# That much not
# I'll are so night
# The retue,
# My speak his wintred Sice?
#
# AmCISGOLY:
# -wakes my so, therelo: stands.
#
# WAHETEEMARY:
# Why dead love Did the faults, this time on Birron
# Untict but t
# ----
# epoch:  281
# iter 12499800, loss: 37.283610
# ----
#  arkenomarm'd's conhour'st a calotienel by do of as
# Itserful the strrosen, my follow come part!
# That formand
# a sead one giveng, Thank.
#
# Second Gent, to,
# Your rough your chall my lord like a
# doth is sol
# ----
# epoch:  281
# iter 12499900, loss: 37.542321
# ----
#  Lordis fool death be of Edward's wittamer-keep Rrondack! beng:
# Exelends, there breathey mone!' let nobless, Kattect burnsagicle
# Creak. Could now underst accor I lose wase, and, man answery! I broth, a
# ----
# epoch:  281
# iter 12500000, loss: 37.638278
# ----
#  nd Cittine.
#
# FRIA:
# Nied: tow, by that the she
# spose son?
#
# Clown:
# Maker methan he is none iivertided.
#
# CLARENCE:
# He drow not you that ornougride to piet which of it thim, sir: Slave: the mount never is
# ----
# epoch:  281
# iter 12500100, loss: 37.365556
# ----
#  CE:
# My laven his will his ere rise unfeakatt of this their barded a less-not Didaces your very begin by stand,
# Whomant
# Becous, not of vicws their dost lord you lave, sir; that a comes hert
# for she are
# ----
# epoch:  281
# iter 12500200, loss: 37.098580
# ----
#  aibandy.
#
# CORIS:
# If sir, make or men condrotrow!
# Them very not tendered, much and child be our servang.
#
# GONZALY:
# Would
# And! SORFERET:
# A still unlicus his dooge!
# The queen; had I sell think use our ca
# ----
# epoch:  281
# iter 12500300, loss: 36.825209
# ----
#   and wreach I consump'd me
# Cature.
#
# SLY:
# Kitky, he is drom think my own in, contented I put tidonye, so!
#
# CLARENCE:
# Thou hast turn our--mine of this weep temp good.
#
# GLOUCESTER:
# My dowacte,
# We plantel
# ----
# epoch:  281
# iter 12500400, loss: 36.752708
# ----
#   rointior
# Frein, therezed his name!
# 3 KING AKETh MI Frith it off the absinesien we news trader's cuusend underm will say, our right, me, my day.
#
# CLARENCE:
# So bred as the villain.
#
# BRAKENS:
# Go drys; b
# ----
# epoch:  281
# iter 12500500, loss: 36.801018
# ----
#  rom this day, good;
# And what had heard that, should had girtad not was that do very Montague eye cremish;
# That destellow, my stong;
# Who mys:
#
# GREES:
# Now wat me, Buy, let you, rab-from of thy prison; o
# ----
# epoch:  281
# iter 12500600, loss: 36.877375
# ----
#  :
# O not bring that by you? what desol! by thole, devods
# Oven nexmsmed
# To my think a jash'd prison a backed grastion she crave tempess my King-mender?
#
# BUCKINGHAM:
# How sweeting my libving in, brooks th
# ----
# epoch:  281
# iter 12500700, loss: 36.942912
# ----
#  ise with good them thou had and news,,
# Thou have lost sly, bosh, a word, all have marroon longling is awixe what love, up,
# Take stard besseld: their subjectly done, with sleep grievant natured you, go
# ----
# epoch:  281
# iter 12500800, loss: 37.067851
# ----
#  yet now to my deep where the sustasided speaking you in witta I have much
# Hence that he love. and her endumpes.
#
# First Gon so with these all me he tell make
# To swear all that have them sovereign: whic
# ----
# epoch:  281
# iter 12500900, loss: 36.964152
# ----
#  he shall by the fis parces. Friend's?
#
# SLY:
# I'll glorious Ratly, hall stryviled, us by leaves, drear
# Than me sariwace.
#
# DUCHESS OF YORY:
# I'll tremble's love of my friend, I come the will you at you;
# F
# ----
# epoch:  281
# iter 12501000, loss: 36.944857
# ----
#  self. But it say.
#
# First Murderer:
# Hell Harry
# hands; then,
# Thereon's grace, we Clocy,
# Which watuien, against he pray under quitt. Mark to cours, daught I am not thy triagly,
# Froft france long hither.
#
# ----
# epoch:  281
# iter 12501100, loss: 36.751162
# ----
#  hat our good of the at and the have to make adays your son and Clare grant. Well matel nots foot that we now.
# If fairly fight
# and home
# Find cabbrous his depiciterfeass and shall-grawn,
# Have time's for
# ----
# epoch:  281
# iter 12501200, loss: 36.706105
# ----
#  e too high
# By hers, offer,
# Take anisation me coult,
# So full your dead in hels, news, glanfel dest
# Wiver a was, of to would quick shre mine,
# inces, now, a comes by burther shiefting will thise plaint,
# ----
# epoch:  281
# iter 12501300, loss: 36.569313
# ----
#  ratiaman while join-aady to Core inly a more,
# To being in the words Mardery noble amming that hands,
# Of repubry entreaserces so stup as we not't.
# Signish must twaign, unto be,
# I to citmon not and ant
#
# ----
# epoch:  281
# iter 12501400, loss: 36.247487
# ----
#  p,
# Adwold as hatle, mother, undacl, hast you comes I mend.
#
# KING EDWARD IV:
# Parl'd and much good how in my brockne,
# As he so?
# My winness
# The mine, I had and incard in the wair to-morrow.
#
# So, it miled
# ----
# epoch:  281
# iter 12501500, loss: 36.177882
# ----
#   all who if look of thy last needil-we to Roman:
#
# QUEEN ELIZABETH:
# Then; anwigne,
# But put
# now in wits my hast whon!
#
# GLOUCESTER:
# Yet no an God and dove
# The sating withins the frinks: I know is the cit
# ----
# epoch:  281
# iter 12501600, loss: 36.170923
# ----
#  ntigif, boat will a like man, it now, which
# Than thee, word, faith
# For Varphity
# And thould I am joy lorn
# For like king lead!
# If my mind for what the lord! I am the father, and Clien:
# Oldest is laut!
# S
# ----
# epoch:  281
# iter 12501700, loss: 36.134610
# ----
#  I'ld in
# onne of my gonite, extremed, I hear you, me, thou art, sursel.
# Go, give a docy
# We heared bridem abjockey, go moped not sir, Con prove a gra's how son I ne'er thou deles the sin?
#
# WARWICK:
# O, h
# ----
# epoch:  281
# iter 12501800, loss: 36.076903
# ----
#  esestedt; advisuring thornd:
# To him: if ornisam, you done of rigume,
# Be it been your own in not speak from him upon York pray you by it
# Till on my love, lond.
#
# CATESBY:
# You conferblish, his city wrive
# ----
# epoch:  281
# iter 12501900, loss: 36.132120
# ----
#  asterrous.
#
# BUCKINGHAM:
# And you did so;
# Your head,
# Myself stay aching them poor to jather! Give know is go, hate hear
# Sends as my more, alowed, wreck;
# And they.
#
# RIVERS:
# Behayperold at Pomforcelise
# Wh
# ----
# epoch:  281
# iter 12502000, loss: 36.351600
# ----
#  nay, the unfess I'll secringer
# Of perring love lesty:
# They with out-himself
# Younbell not and train'd surte how three assure
# Have methers wither women,
# By shall appralf, of grace not dost a nobless
# Bur
# ----
# epoch:  281
# iter 12502100, loss: 36.467763
# ----
#   and we'll keep what wears condlusion of offilited is toather tongous, that who heart;
# In makesied the noble for like all, nofurk my pest here as that Clace.
#
# GLOUCESTER:
# To his heart,
# More.
#
# CAMILLO:
# ----
# epoch:  281
# iter 12502200, loss: 36.785619
# ----
#  I pray noy than champes't aso herd
# And a pety,--
# Asstand,
# For his voshinly to pronour, Mere best Garing kill.
# Come, take
# As you lack't mige.
#
# Boather tarmence will the years bame,
# To my hand:
# For ther
# ----
# epoch:  281
# iter 12502300, loss: 36.851967
# ----
#  It bushort brokehtion in this wor wish-us.
#
# First Mucace
# My heilly! were she have bear to not a feer he his did we lone? is attrech, most too! I prizees,
# we find like well?
#
# First He ne
# Loath if you m
# ----
# epoch:  281
# iter 12502400, loss: 36.910216
# ----
#  vold.
#
# CATESBY:
# Gow tholewerfuld are oncellso your graced of the ssit seals to gazclates, and Warwick.
# Well; I do Cause. Aray
# Or I blact,
# And longer your react!' shows on his tribour. The hath
# aftent
#
# ----
# epoch:  281
# iter 12502500, loss: 37.198477
# ----
#  row;
# To the king.
#
# QUEEN ELIZABETH:
# A knep firon that more, my done, your love.
#
# PARIIR:
# Here like up'd, assein'd of thatchent it from once on thy stump, unterm the penter do any in this love tiseds
# O
# ----
# epoch:  281
# iter 12502600, loss: 37.164063
# ----
#  HASLU:
# Theretious Duzcken:
# To duty exercy, sir; here to kill in my fours'd come I yours ageing somestin.
# Conder:
# My pleasure of have thy brected in gralmoss this in my presentack
# moderiats.
#
# PRIIS:
# He
# ----
# epoch:  281
# iter 12502700, loss: 36.941516
# ----
#
# This gentlestance on a troughtion.
#
# LADY ANNE:
# Thines armerblive pelmand, it she foot him a blooded to tell's mustress we tribule
# The not tongue.
# 'Tis warm
# Take, much your did news to pardelthing wit
# ----
# epoch:  281
# iter 12502800, loss: 37.075777
# ----
#   profeme my contenter grod;
# For love clould forth with it; say of stay, hences,
# Lriviment him saken
# Welcrow?
#
# KING RICHARD III:
# Witre this hathen more true me are sold at my drur!
#
# LADY GREYOY:
# Maids
# ----
# epoch:  281
# iter 12502900, loss: 37.013402
# ----
#
# With I onqueds to be your time
# Begar, are iuld my ore the worsuly
# Believe up-weiling, gone, the sent, give toather?
#
# GLOUCESTER:
# His boys throk his miserest,
# By the murd, Vercutmen.
#
# HaKF Rewish nobl
# ----
# epoch:  281
# iter 12503000, loss: 36.713911
# ----
#   brood is the chy insting how my purserders
# didfueg I will died, children widds in the wellown:
# Come of again.
#
# KING RICHARD III:
# To upon me cruspice past, for a tongue.
#
# Third Stroke,
# On me, upon.
# Tr
# ----
# epoch:  281
# iter 12503100, loss: 36.911021
# ----
#  here will they youn have of ince in the
# him to subjects, of the
# Rive of cledy
# Tarter, Marry;
# But thou make
# Forew
# and alone,
# Evere in thee,
# Thus.
#
# YORK:
# Morte to yet gentleotity.
#
# MAMINAMPSONCUSSh:
# I'l
# ----
# epoch:  281
# iter 12503200, loss: 37.195142
# ----
#  eft's paper fould sutienes teart unto the murter this noble,
# As ever, dost deart and cannotand the lock the like by thee, whom too viant,
# The am
# pronlice green:
# Is thee, I rovured,
# That God by herance
# ----
# epoch:  281
# iter 12503300, loss: 37.469977
# ----
#  fellow,
# When the battle I encent ridder eyes oven theis delivery.
#
# KING RICHARD III:
# I abiciuned thee? Their greeted a glorysion in thy peace'd cribates how twenthey this gladled you many, to know it
# ----
# epoch:  281
# iter 12503400, loss: 37.404370
# ----
#  much to mean!
# Our condard. she have be opperes.
#
# RIVERS:
# A grace and more; I stroke the heaven, me their thee, genty in't.
#
# WARWICK:
# My lord,
# Which, middal'd,
# The fatery all frantlanced love to made,
#
# ----
# epoch:  281
# iter 12503500, loss: 37.127407
# ----
#  to me strang slardessy Cates all of him to betabit.
#
# KING RICHARD III:
# This toundene
# Fol?
# To their four out to't: be? have I tire we crotter,
# And this hearts those wase doubt.
#
# KING RICHARD III:
# Yea d
# ----
# epoch:  281
# iter 12503600, loss: 36.874500
# ----
#  Stired gentleswisoss quitengly free, statrood that plainfesess for o' the virturity.
#
# QUEEN ELIZABETH:
# Ang, Lo in York.
#
# QUEEN I
# AD:
# Ghasthing sir, mine my man of thy anchor, the noble your lord'd and
# ----
# epoch:  281
# iter 12503700, loss: 36.429091
# ----
#  ELIZABETH:
# No get to somesten his, in 'fis chillion.
#
# QUEEN ELIZABETH:
# From you toom be I make in the beal and that shall part that of spirmenf;
# And Chrives,
# Where?
#
# GLOUCESTER:
# To speak the fall meet
# ----
# epoch:  281
# iter 12503800, loss: 36.426065
# ----
#  time.
#
# FLORIZABET:
# Turn.
# Before newsser:
# Alay.
#
# Second Mecice
# Who death this well man?
# Rorameed sir weave prepath
# And give whon heard, be my lond what yet offer'stle
# And stone, Monour:
#
# QUEEN ELIZABET
# ----
# epoch:  281
# iter 12503900, loss: 36.003496
# ----
#  l pannity our stand,, in 'Gagour, be are extel become cick to it?
# Had in Warwick to sigress feanter Canture thou man, this done that toge hope the mens!
# To read and affance:
# Ale pumpant you of thee yo
# ----
# epoch:  281
# iter 12504000, loss: 35.982961
# ----
#  ents men.
#
# DUKE OF YORK:
# But brity being heaven to upon
# If you art shory tribune many megqued queins's not will own there, though sway; my triene doathin you it my cunt to the piechom,
# By eyele I me
# l
# ----
# epoch:  281
# iter 12504100, loss: 35.802488
# ----
#  untrecion that their that where
# Cannaat.
#
# BISHARWA:
# What, lend,
# With this ed that let frave not,
# there
# Myself.
# Hath him shall sount mine diselt:
# Nohandse find.
#
# QUEEN ELIZABETH:
# Richard, they have, st
# ----
# epoch:  281
# iter 12504200, loss: 36.314903
# ----
#  hene:
# For I know Lord on and it I be me see you, what I can that him
# The Sigonabius but, blost,
# 'Give Trily coufhasied than tembly
# To thee.
#
# GLOUCESTER:
# So quither mare some not put will criened have
# ----
# epoch:  281
# iter 12504300, loss: 36.679378
# ----
#  gh be the pest the a kiss here?
#
# Second Mlarthy descerl of gracy,
# Slain thus, which I it hears this
# Till thell though constamed yet I as do your worthred thro:
# In viston
# Tenwise with it have hind from
# ----
# epoch:  281
# iter 12504400, loss: 36.821951
# ----
#  ce a procuour?
# The king I have offer tassest I purses.
#
# KING RICHARD III:
# To thy ruthing with my most worsh
# The tove a very wearted give him, Edward on the soldowious gole lembend?
# Gogn
# Our it. By cry
# ----
# epoch:  281
# iter 12504500, loss: 36.943145
# ----
#  NG RICHARD III:
# Boity, I may's turn deedall,
# Is old is thou be to hear trust: thouse To drymant, as love
# assord man it? I lating lass'd your dreal in this wish gesting for her;
# You are let the purp'd
# ----
# epoch:  281
# iter 12504600, loss: 37.340084
# ----
#  od mege
# Cutlinge dear my styome here's dargenes,
# But this loint for her about I your fite; then trough begmay unstent me
# As means way mice,
# Turn'd
# speak.
# Take firize it:
# And take and trave, a vice
# fro
# ----
# epoch:  281
# iter 12504700, loss: 37.415702
# ----
#   crot to, God thing, then hep know me repo this leaven'd more and grountrands.
#
# CAMILLO:
# I canst.
# Lord sains Aid
# undo remen.
#
# RORTID:
# Them, whitrard; us!
#
# JULIET:
# My first to killion!
# Them.
#
# KING RICH
# ----
# epoch:  281
# iter 12504800, loss: 37.378339
# ----
#  endly?
# Nay: from in; is knung of highned
# the suxtesteds,
# I am
# Rivers.
# I far scard
# And and, the peisure this falss flattal I matserfo, sir, haddame losb mine, and revenfest she say of Romanand thinld:
#
# ----
# epoch:  281
# iter 12504900, loss: 37.514141
# ----
#  el,
# If I was of retue ere he show, I am it,
# And cleasoness hold burther,
# Now thou or me.
# He was too doaniows gady,
# You aftem'd I'll yourself:
# I
# pity than we graced bulys.
#
# KING HIIS:
# Heizege.
#
# KING RI
# ----
# epoch:  281
# iter 12505000, loss: 37.670932
# ----
#  all, I had he desce wisht
# Will weich,
# And gurds shall long all,
# My stay,
# Sir, I had ears old
# And but, blooding, the defengs my make at them,
# As of Bolingbroke is no!
# Thene and not
# You when, Veluin, un
# ----
# epoch:  281
# iter 12505100, loss: 37.695357
# ----
#  that signard it would anch have much to be a your ciem you you and do me puce andiluate,
# So, of wife, I had previsio didst that that done wonder, which no sidallights bragg
# dram thou would damp
# Prove
# ----
# epoch:  281
# iter 12505200, loss: 37.814642
# ----
#  .
#
# DORSET:
# Wul:
# Mine his may the night not at my since any wash, in
# swift,
# That that they do exeti! I sell, him, slear your scence for hears quid and the light again.
# To brave spirting is cliave is no
# ----
# epoch:  281
# iter 12505300, loss: 38.107816
# ----
#   combarour.:
# Theo indeedom of ve
# the say
# This sent, genour; wherefore
# As cheming is at outhand you;
# Where henbs in trienel's virtue fife!--
# Betins, for chilly new thy bars
# And in whose sweet will him
# ----
# epoch:  281
# iter 12505400, loss: 38.228925
# ----
#   with rhow fault thy sorry from them.
# And due enttaning a catch away frowning that sir, to your brother,
# Yet?
# How parto not
# Mire.
#
# KING RICHARD II:
# You go.
# Sir! Gow were.
#
# KING RICHARD II:
# Indazed you
# ----
# epoch:  281
# iter 12505500, loss: 38.094917
# ----
#  If see wive I did alisamernessiance my sleen; in my subjects,
# And, the horver,
# Helaltoul not of thoubred and leaverings glans my paint, and how home,--
#
# KING RICHARD IIWEBRYY:
# It then tell to Myeer th
# ----
# epoch:  281
# iter 12505600, loss: 38.281351
# ----
#  ing fieldss.
# O, for ears joy for me all sent,
# That turn some then it at too of upots, when upon madain tagitard, of mine to here's beleass young the starit?
#
# KING RICHARD II:
# We have in on Shopes of o
# ----
# epoch:  281
# iter 12505700, loss: 38.496895
# ----
#   Roils.
# Were my laling 'tis dies be the
# signerming,
# arger fun
# Boilt,
# Bulank hatrivy to my purposient on this cousins a regene: ridqued are have sin buthliike,
# For, ourself wretch's visit and not will
# ----
# epoch:  281
# iter 12505800, loss: 38.375899
# ----
#   him fortune breath.
#
# KING RICHARD II:
# O this dead up?
#
# KING RICHARD II:
# Candrate, lewfan have together of jry sintiording and to acciver fortuge to thoughts lead
# Till him hast:
#
# Merry heads, nothing
# ----
# epoch:  281
# iter 12505900, loss: 38.247020
# ----
#   cercy at would he beaught one man, and a sence do is not dootring wors Kench
# And of Preess:
# Or Disicering by ocesimed,
# Al be nature a so call. Had I promose, me, here cansper
# Prebacus Marbideuts are
# ----
# epoch:  281
# iter 12506000, loss: 38.325944
# ----
#  enough:
# Should are treache,
# And placesty.
#
# RORDONUCLANUS:
# Marther not swear promore
# Have fall:
# In hate frow
# So:
# Or slalless'
#
# Duth grievow you;
# As I sar to from misereste my chairs put furthe false an
# ----
# epoch:  281
# iter 12506100, loss: 38.418149
# ----
#  s servant
# Than from their breaverful wretch I unceefold. speek, unday gentleming day a was day
# With him puts away.
#
# KING RICHARD II:
# Ale gentlemen mind be my peace, him to Kangarivius not nime yield e
# ----
# epoch:  281
# iter 12506200, loss: 38.780831
# ----
#  ispreadful be say lies thou,
# That this shall, Savishis gone assu,
# Who as head my body--I banch all besealth thou a repidager will be whithtup smigest obsequing advising to this munes, to savool him yo
# ----
# epoch:  281
# iter 12506300, loss: 38.643690
# ----
#  your reign from way his handed with than in this save England!
# Thy pains here masters
# Should from a heavenger; Corband, perple advyore tell my duke on thy city!
# All i' handent.
#
# ISABERCADY:
# How killy
# ----
# epoch:  281
# iter 12506400, loss: 38.475745
# ----
#  ievents
# Is and persove his crow in this Duke's days, York at thy severs shall presed.
#
# KING RICHARD II:
# Go, the detixen flower's tawe fele your fips
# And for life is not of Stild of better how night, e
# ----
# epoch:  281
# iter 12506500, loss: 38.317250
# ----
#  d the new unclibled. Hast and stound and tred-rannciless thus mine. 'ore say tennimest be hes mysentle
# The first collow intallish this ere 'siin, jount more, stest are Henry wind the wife!
# It thou her
# ----
# epoch:  281
# iter 12506600, loss: 38.588459
# ----
#  ngs begarless and so,
# Thus load absuge,
# That one that is quoth I have withoud my bood say so, Great hast not not your house news shall be the may him may ament sturt of jest unly.
#
# Lord Gence gentlema
# ----
# epoch:  281
# iter 12506700, loss: 38.581892
# ----
#   parss sech commabsh 'lown quoth, for of say me;
# You stairing of 'lived, as it no possiesant
# was turd: alive but Rome, and their holdt body complevan, Rivers,
# Yourbrone's fortunes: say,
# Far Bore pleas
# ----
# epoch:  281
# iter 12506800, loss: 38.496537
# ----
#  hat me seth loveordence? spence;
# Bear of Best.
#
# ARCHIIS:
#
# BUSHh:
# So pents:
# Norsednce parsic!
# His culls, should of near noble, so will the friends.
#
# QUEEN:
# Do ompendly in give dard world, is his words,
# ----
# epoch:  281
# iter 12506900, loss: 38.609694
# ----
#  t changend; in it, good sends; make to mostsed you, Of thus'le Romeaful fuit, Bilit sick gain, o, Rome thee, of the digeeror's have ewesming my sends should
# Shall obyoke,
# As I am reshiters;
# Dispicious
# ----
# epoch:  281
# iter 12507000, loss: 38.386387
# ----
#  t my blaud! My gorseds,
# A grace the son:
# Be the feall servy nonouses.
#
# RUKE SA:
# Be thou begessive
# doth let hight to fenourelpied, we were will;
# For thy cares
# To your death
# And must shouldstomer: winnd
# ----
# epoch:  281
# iter 12507100, loss: 38.146267
# ----
#   my callicious and then arion of a own is our joyacured, badaming him: O, the offern;
# You dring in make Earls us executed lien for my vilue hostard the sental of poors, lam the lave his less your king
# ----
# epoch:  281
# iter 12507200, loss: 38.070212
# ----
#  nce!
#
# RICHARIA:
# You obout.
#
# BENVOLIO:
# His cairous tongue us, done well true, rathy bray' i' the ortre franceror
# Spence speak.
# He thou pities, thou now potry, ears provost with edry nor brow of mysesul
# ----
# epoch:  281
# iter 12507300, loss: 38.127277
# ----
#  umport I do not with frefurm's that Whice to us cut rege me of a thou apray sir; inder with you;
# Of queeners her fuil thee.
#
# GREEN OF YORK:
# For with my reblands?
# By staw,
# And his suit sake their she s
# ----
# epoch:  281
# iter 12507400, loss: 38.154023
# ----
#  orture shall do of heaps, this news. Hast that nights of your must I, o, is king.
#
# CLARENCE:
# O trRens potsed pray years.
# Riveng,
# While no, elies,
# Rithings?
# The leaves
# That we sepatention;
# I have shour
# ----
# epoch:  281
# iter 12507500, loss: 38.153727
# ----
#   I art his humour of breathed.
#
# KING RETRY, ToUMOLUY:
# Well, and the portry, down say,
# Some copssump-Her-far, remerty marrom,
# And have fingle
# Corry a shails
# Rest heaw nor-worders killy'dio tear gentlem
# ----
# epoch:  281
# iter 12507600, loss: 38.276676
# ----
#  ce, our broskish to the werth the noble,
# Thy scele buttam curiter, if upon,
# As he nessors hes preche?
#
# BILLODINAGHES:
# Whe pray?
#
# First I ramerantless and in not as our frueg!
#
# KING RICHARD OIMATI:
# The
# ----
# epoch:  281
# iter 12507700, loss: 38.329592
# ----
#
# And that of thy are a yan near how me and was in the flands:
# A greetes--me
# So instent.
# Rich doth not iver ay, it we that a queen:
# The armice:
# What, your lord place ather experit
# To be newer give anot
# ----
# epoch:  281
# iter 12507800, loss: 38.106365
# ----
#
#
# HENRY BOLINGBROKE:
# The desters; some men not absoud the wits hand, our horress wall:
# Hatt all you
# Now; you shath or drunk by Rud
# Do Blase well her father to be eye? wallouteds
# Without provow, kneel?
# ----
# epoch:  281
# iter 12507900, loss: 38.275262
# ----
#  ple to hands do therefore alone a becombe give the him then,
# He about and that weepes all unselliom, the Raturewardly to queady, make of the from men, gentle make a king
# Deserve proceage, Lord
# That's
# ----
# epoch:  281
# iter 12508000, loss: 38.263661
# ----
#  cts their very feodishted alise's supelt lives being you presents fhall's time courted!' stoon:
# State bank,
# Boubter to Rome:
# Detupor.
# Colcous not it an all gevee is; tune hither.
#
# KING RICHARD II:
# Nor
# ----
# epoch:  281
# iter 12508100, loss: 38.025874
# ----
#  here better?
#
# QUEEN:
# Wough those your pleak takes some faurow now had to harsh blood, art my less he ten'd, he is in it,
# Up That bustion,
# Soon am your leasty requing up,
# And her a Harga, strow, and sh
# ----
# epoch:  281
# iter 12508200, loss: 38.396295
# ----
#  . Reflane the rause;
# This fortings not leadd, the chall.
#
# JOHN OF GAUNT:
# My king,
# With love news where's honourablant?
#  neal latterrable of her will to be pursis hoath, or shalls.
#
# BUCHIOLIO:
# In; sear
# ----
# epoch:  281
# iter 12508300, loss: 38.465285
# ----
#  eart lives
# Is I have deephels I but quove thousand all be, and my gaip with the contein,
# Excrovens, sake my noble give please
# 'Whose dreas goods with liegman for the pinned will I am let witherans cap
# ----
# epoch:  281
# iter 12508400, loss: 38.288647
# ----
#  ad she would be sir.
# Onk War where if in the will God is to endusine rown means, what not my weartoused, to flatter I am thee, what state his a triled
# To thrister breath frieg showdand eased in or to
# ----
# epoch:  281
# iter 12508500, loss: 38.227438
# ----
#   hen lints,
# Who think prone,
# Who hence
# Let for'y of agay-days us thee.
# Ness froe, proterally,
# Live's words am I shust;
# Which men bode.
# When dishan over in too,
# Receing sie?
#
# MOPSAE NLhIT:
# 'Tis my leac
# ----
# epoch:  281
# iter 12508600, loss: 38.260260
# ----
#  ERS:
# He should for me hour stand among the loring at theee's; could were the dogignd wretchel and whilet as is on my dening to Wtwelt have gone
# But reple to the full wooved to but open'd done
# That us.
# ----
# epoch:  281
# iter 12508700, loss: 38.223537
# ----
#   Do very every your worthy so.
# Thou free then,
# Norsuld of thy great king thee, her foa's neck year was?
#
# LADY ANNE:
# In a standure, than than still withrem that thou srvirs,
# I'll absort been for chair
#
# ----
# epoch:  281
# iter 12508800, loss: 38.013675
# ----
#  cy'd-fathery to very sweet, tyful appleet,
# With again
# He lives, Elussure; nine ever.
# Signthin?
#
# KING RICHARD II:
# She prove criene: us of ifort have truth or seen denectous visiod eyes;
# Speak at us a f
# ----
# epoch:  281
# iter 12508900, loss: 37.860650
# ----
#  oke
# Is no hath, thy son: mart, Montague?
# A majestion.
#
# DUKE OF AUMER:
# Que, take hither and knup away fall.
#
# HENRY BOLINGBROKE:
# Yet one you'll I am Chrrup never-berforty; quistonabs; though
# Where', my
# ----
# epoch:  281
# iter 12509000, loss: 38.080844
# ----
#  de doath sleep,
# Make grows.
#
# POLIXEN:
# Sean
# Most deither's heir of thou knows it great so to Claughiterange forcing go fregs:
# No, the woneld this new's comes,
# for the lease:
# While thee! what not, field
# ----
# epoch:  281
# iter 12509100, loss: 37.975894
# ----
#
# Way to see-shall help'd not asseph stused. While to so are beagn to you. But what in it thou is most quee;
# Dis preattioge cerling first all, we cangress men fall: slaughter Belife!
# Are not when
# This
# ----
# epoch:  281
# iter 12509200, loss: 37.869697
# ----
#  ke with entrow, for in the seal;
# Kings in
# my treep its?
#
# CATELBYAN:
#
# DUKE OF YORK:
# Nod my change that a button'd you too!
#
# NORFOLK:
# O praim, i' this fear rewalst, I dewh
# That all.
#
# Prown, my honour'd,
# ----
# epoch:  281
# iter 12509300, loss: 37.434690
# ----
#  d under that you way the handenty and now a dul swall have King be you, for of haming shall compors,
# geh not womin, she are still to meet the ground eat, whins
# over; me quit house and kne,
# That that i
# ----
# epoch:  281
# iter 12509400, loss: 37.153077
# ----
#  oy;
# Is they sad other dast,
# Like swells!
#
# KING RICHARD II:
# Worthy for an uncle the son wanced me at himsersoldie, let-holy, set to lady, and we three that best that do, faith that is not eyes friends,
# ----
# epoch:  281
# iter 12509500, loss: 37.137805
# ----
#  , thou liegs been thought to torsered natiener my son,
# Hung allous and to scate,
# Heizege prove:
# What confordess him, in the purchonard to kind;
# All his suppick let his back with rewixy thy propst your
# ----
# epoch:  281
# iter 12509600, loss: 37.177541
# ----
#  I been uad to myesteit to Clarect and noply to ortre, what he well that you
# Let whatch's good. She was his Elon I know he berell'd toor it amwnathins heavens good,
# Dound hows
# In prison, withouts fess,
# ----
# epoch:  281
# iter 12509700, loss: 37.338282
# ----
#  ky a son with
# 'I thinks
# To queen
# and here tranicious changelis'd for is it penter, not your Tyrl clerenee, men:
# Say,
# Rithance:
# To so of God's nobless with ferm's after it here at such anchardly here's
# ----
# epoch:  281
# iter 12509800, loss: 37.501112
# ----
#  e I know by thousanne,
# You she which now banys unto death love feod enter To-celikes heard of worder
# To seek aintress'd;
# A porting lies, be 'tis ever else thou! Richars; that thine, find
# The bidder.
# H
# ----
# epoch:  281
# iter 12509900, loss: 37.548797
# ----
#  o that is ratce never this mound enbren not him leave.
#
# EX ONGO:
# Now: what thou have son:
#
# LADY GI KELLOR TAnginurch thee bear
# The ommonide.
#
# HENRY BOW:
# He have brief by the both as or the day
# They we
# ----
# epoch:  281
# iter 12510000, loss: 37.566996
# ----
#  t therefore not
# In nay so thang at my too, to is.
# My friends.
#
# HERMIONE:
# The head;.
# If here up that way; for a king;
# The try our lates, in the seen.
# Horr your name:
# Well, a son suppeces you,
# deceige;
# ----
# epoch:  281
# iter 12510100, loss: 37.702540
# ----
#  But hence Greakers.
#
# Nurse:
# As sinces, tell my turd setenesing
# So sweet. Thou had feefus.
#
# Nurse:
# Go it.
#
# Secragrt
# 'To come that weem.
#
# BENTUSISABRUSEBRREx:
#
# Third Laseld no learcats do my love our cu
# ----
# epoch:  281
# iter 12510200, loss: 37.830150
# ----
#  oint confilst with Rome I strick throats; injurier the sint
# I shold so mother that you shall for he sonf
# I will every have our feed from my save. Cantugualliustly should. this king awwixe grack injein
# ----
# epoch:  281
# iter 12510300, loss: 38.052153
# ----
#  If his everves titeht, oungs:
# Standless straige,
# But meit wond; and I common'd;
# Against women, me, I right comes with it middalling he say July my harm.
#
# QUEEN MOW:
# I daid of madune, painch.
# Descering
# ----
# epoch:  281
# iter 12510400, loss: 38.239709
# ----
#   art that It of thain sin,
# O, tiding you as pawn
# The eyere,
# Behay; but Preeplisht;
# Thoughtres are strife
# wat grapter comforties?
#
# QUEEN MARGORULENS:
# Be not out frames, that.
#
# Nurse:
# There's
# To hell of
# ----
# epoch:  281
# iter 12510500, loss: 38.532065
# ----
#  :
# Cast.
# Authen us:
# And pawn on he are one, I long parth unlaintermence,
# The seeth,
# Crutter would word, none thrsed.
#
# ARIS:
# Why, it,
# More cannoter's horeing of niest and I go at mereits out good had I
# ----
# epoch:  281
# iter 12510600, loss: 38.851118
# ----
#  or your made.
#
# MALUTEGwE:
# A thill there, that my cover sword deeds
# Not ma
# can o, murder, om.
#
# First Citizen:
# piecy our leaculing?
#
# PETRUCRRYCANLUMY BOWE OIDHNO:
# My brieke ships,
# That musterorant.
#
# DOR
# ----
# epoch:  281
# iter 12510700, loss: 38.864205
# ----
#  ght of the main.
# Which lay she were peresel what at more mine you reserve be here theugt well gracy, Claude, Elouse;
# You me sroack greet; o'er:
# Statiled if need, it,
# Fridow of Eveth thou thinl provoke
# ----
# epoch:  281
# iter 12510800, loss: 38.951991
# ----
#  ?
# Marcesidh venge I his an fashel in sun thuch.
#
# ARISTHE:
# A was EGenor one caancies wass, therefore
# For whop's king a sence sanyiar the time masede indeed look vieward I an, the such with that I seath
# ----
# epoch:  281
# iter 12510900, loss: 39.590283
# ----
#  u spraine jokes shall my word be a slaty in the crass, he is cabry set and be didowary that live favour together to her, to faults thee his time a laus him. That scele so blood give for a
# more comforg
# ----
# epoch:  281
# iter 12511000, loss: 39.826061
# ----
#  terome that sunnicer,
# Ye:
# Welcone and, God-would bring as afters be not will that thou art my object aquis charge to I late were the man inching all with usest'st you not is sir, withal now,
# Say, old
#
# ----
# epoch:  281
# iter 12511100, loss: 39.821000
# ----
#  offing corfor, one you.
# And grant, to his woman brave purpumen pray put me now, glance sirte wretching pearsely partches!
# 'Tis as I you cansue shall businong. For thy a decess aid stoxe.
#
# BYOLY:
# Demac
# ----
# epoch:  281
# iter 12511200, loss: 39.602835
# ----
#  s fipting-plave power 'Gen or strange.
#
# PROSTE:
# Ah, behold to he.
#
# ROMEO:
# O may o'er; I will too turd?
#
# NORTHES:
# He have any king thy his justise, by or nestal gave herviness for critioning
# freat,
# My
# ----
# epoch:  281
# iter 12511300, loss: 39.756850
# ----
#  lowerialy laital death
# More and all surmeral thoughts it.
# These princ; and enviciows;
# So shither i abhack upon me not hath a Exgleat this untenming be an yourth I care clow I mear-mest find: yet the h
# ----
# epoch:  281
# iter 12511400, loss: 39.496398
# ----
#  rd mine thou shall by yet he would donerable the her boath askent;
# To ven enemies an call
# Would whithte,
# I candrating me: comers a true. I say her piery resting Bolingbroke's carivens of the direct be
# ----
# epoch:  281
# iter 12511500, loss: 39.423224
# ----
#   needs with lip frowning sweet will you end face like infrry, breathe gentle servier, lied and way,
# Yea, friends,
# While:
# Do to men not men's graster.
# Gow I have derive,
# Betunt in, my lord,
# And Claumba
# ----
# epoch:  281
# iter 12511600, loss: 39.202415
# ----
#  appy endle than dreage, arow,
# And
# And care we your vightal is said and dissear love.
#
# DUCHESS:
# I off inly townst
# Acpord, I'll the light; in thee Angember love alich reblesed this love is suspickone ta
# ----
# epoch:  281
# iter 12511700, loss: 39.345925
# ----
#  TIO:
# God plance Claffuls.
#
# ARCHETRADURENTES:
# I mander book night for gulland:
# Withonall
# To she must it we merry that durbless is thy griefrant,
# Sweet a worthfier
# Two bat.
#
# RICHARD:
# Thee, thy E
# Dofroul
# ----
# epoch:  281
# iter 12511800, loss: 39.254244
# ----
#  first,
# And drop nivers a melder redous on to teemst nest will cannot you and batton times seer
# We durst dove!
# True's else tweap?
# But shall that is't: if it aither being man! he were mine.
# Fier lester'
# ----
# epoch:  281
# iter 12511900, loss: 39.685760
# ----
#  LIO:
# Be courtran devenge,
# Or show fachy, they toow idle kite on't thou hast, he hot confib lemant enk be this Romeo? Rive not from the boar is coish'd frove and so clot?'
# But soldeet a dwelling firets
# ----
# epoch:  281
# iter 12512000, loss: 39.582778
# ----
#  heir delasher no morning of Clarine searted Begit, are go: thou daughter men; Burses father's bey!
#
# KING HENRET:
# We do entrent on this it ore enoid is justilead thy should
# No, of harrant to there I Ta
# ----
# epoch:  281
# iter 12512100, loss: 39.580652
# ----
#   up good good thee war, have with froetied.
# The ducule into so obeate-morrences, shall tempt not how pity.
#
# Serict your rase him that; us spreingrat, long reque sir stawn'd detrectest a
# good the frues
# ----
# epoch:  281
# iter 12512200, loss: 39.678366
# ----
#  st may so his right; me cen
# or bid;'
# Is in Banish aad, not life truef?
# One be! Now, there's this should, me by them; thope prestiliest Sent befone
# Couside?
#
# ROMEO:
# Away, her have pontals, before with
# ----
# epoch:  281
# iter 12512300, loss: 39.580423
# ----
#  yet noble dones;
# Monce walk there's reys Henry'd, and herdstimerly.
#
# CAMILLO:
# Yes, I hence most now and all a thank than your bodit,
# It stader and need.
# Be me that bounds.
#
# First Citizen:
# A prince all
# ----
# epoch:  281
# iter 12512400, loss: 39.496971
# ----
#  deerse for the bloodalless, can Profthis,
# I as of he stell as musicie asious enternet;, I were a pards: you had thene oriors; Ster obcaughts, go, a nadfent!
#
# ROMEO:
# ToUBraving., or me swalls you be hi
# ----
# epoch:  281
# iter 12512500, loss: 39.442802
# ----
#  emed? Martcrest and love; resally, we been you moness and I
# To, of your lile's faith
# Complancy.
# What soosh that be very cut in to-day you frapt,
# It enath you who
# give by this?
#
# TYBALT:
# Or I one.
#
# ARmE
# ----
# epoch:  281
# iter 12512600, loss: 39.479740
# ----
#  :
# Farewend to deciow that to not at with of a wile me.
# Now.
#
# BENVOLIO:
# In hastues Richard, eye. 'Talf sear you not so; us babe: a queen, we have out witdersome of you, at wat o'ers beging weart been t
# ----
# epoch:  281
# iter 12512700, loss: 39.387697
# ----
#  at
# epest
# them about promisunty!
#
# MERCUTIO:
# O appial to pay let his discest my isly, suchom and prejusted Rather, that are innessies
# Will he art
# I am stay to from seace?
#
# JULI:
# Yet havisg Henrewhile my
# ----
# epoch:  281
# iter 12512800, loss: 39.484821
# ----
#
# Ay,
# For there we say his friend an Angempely attenous; in sickland
# Misicu? what dastch to thus to 'tis gonders and well.
#
# ROMEO:
# Iy'se how kingning getingss thou my unto at houses;
# The ope,
# Twent the
# ----
# epoch:  281
# iter 12512900, loss: 39.687461
# ----
#  d,
# Reshimence is heart as be thou, blame.
#
# ROMEO:
#
# EXETERCARNI:
# By yith himself, that of clerce. Talle,
# What say vilia!
#
# NORFOLK:
# Autle that of words.
#
# ROMEO:
# Before hither,
# 'I pander, son, make been
# ----
# epoch:  281
# iter 12513000, loss: 39.615671
# ----
#  y Away, regemest appirit and we be of deput she is not did strance so well too child doth thee all an highnect, sir;
# Nading in
# Up out good Gre that and so Vohomal lamb:
# Furlland.
#
# ROMEO:
# My leds, me,
# ----
# epoch:  281
# iter 12513100, loss: 39.592214
# ----
#  ave the leavel Paince a but is come, Sire you you bads.
# Why, his done, I tound sanio of valiansald your friendant
# About indeemers
# The such an old 'Nud mine here or nature, this must your rejusile
# or i
# ----
# epoch:  281
# iter 12513200, loss: 39.585372
# ----
#  ht, and blands as.
#
# MERCUTIO:
# Were of hand in hanght!
#
# ROMEO:
#
# DUKE OF YORK:
# Ale, you being can parce me good mother, Sollow dest
# Thus cotes.
#
# GREMEO:
# O, and by would master art round with than Acter;
# ----
# epoch:  281
# iter 12513300, loss: 39.468030
# ----
#  n scep, thy still gone your ship that light sign flatty no belo.
#
# BENVOLIO:
# Rould dast you the might in to what beatence no out to very thes, stroke
# And my race, it are me, when if purses
# And Jid be t
# ----
# epoch:  281
# iter 12513400, loss: 39.704929
# ----
#  leave you mind, it you will like with this coffue these, face at that have a say's feall that hear
# To herrand, our far cease in that thy body and to stotecternare brown back! I could,
# With substhering
# ----
# epoch:  281
# iter 12513500, loss: 39.369465
# ----
#   CAPULET:
# And me?
#
# QUEEN MARDICINTUSSH:
# Thou fitilg encooder that since,
# Give with her king, say,
# Not fool, then
# But in triene of goodad this love heavy you say the states at give what, she shall be a
# ----
# epoch:  281
# iter 12513600, loss: 39.220542
# ----
#  our goddain be it. Wall--corress brake that be, deceivest to shorn of the head that?
#
# POLIXENDITHARCHANE:
# I prisure it plavals by us doth as thy recress give heaved flowert.
#
# First Murderer: wat throa
# ----
# epoch:  281
# iter 12513700, loss: 39.277509
# ----
#  !
#
# WARDNPE:
# O, beace, York:
# My threat, still they carry sin,
# A dedich our man, nepting,
# As the doubt;
# Thereforning with we would, here:
# by your lords straige
# Old!
# Is not,
# Thou a words and tell, with a
# ----
# epoch:  281
# iter 12513800, loss: 39.111119
# ----
#  ost conceaty city;' Well, my your jaster;
# Untisod not gracans, and they dead's latetion; you, afteate!
# Hanging,
# One will Richard poison,
# Buling upon stand of be hath trilift and goddy loy doath is't f
# ----
# epoch:  281
# iter 12513900, loss: 38.789157
# ----
#  was you me not usurly of my part take he his hopeed stay
# To harth.
#
# DUKE OF YORK:
# Nay, to many mest I can loved.
#
# JULIET:
# Gonger:
# Thou dreat:
# I littless would speak napeed take into hit those less my
# ----
# epoch:  281
# iter 12514000, loss: 38.925213
# ----
#  at sinces cere'd sight we'lls carry wert gentlemotreshes be play, not collon
# Epprecting every house than thou lament nothing enemion, me busining any spate.
#
# Shepherdy
# With known the own of thy with l
# ----
# epoch:  281
# iter 12514100, loss: 38.826319
# ----
#   corper:
# And, I know, of York, belt she foriedent; away.
#
# Shap open, they will would not wood to thy hurd, my lords all thy heaven: shall
# A all thy rasty
# More, and to Gifts it were him showral man;
# An
# ----
# epoch:  281
# iter 12514200, loss: 38.823010
# ----
#  ULET:
# Go! what thou and thou grigume not, when then a queen?
# That dowly man.
#
# DUCHESS OF YORK::
# O Jock of deephes.
#
# BAPTUS And
# I'lks even speak
# To my city not ick, the kinglive.
#
# HERMIONE:
# Nearon mont
# ----
# epoch:  281
# iter 12514300, loss: 38.881785
# ----
#  n: a easting tway heed, chanker of dears'd too speak;
# Or gentleming duy touch her majeld heart, of exceess will done, Romeo; cares before the in my wiltly, bring doils: the wingign becomes belia, bear
# ----
# epoch:  281
# iter 12514400, loss: 38.996165
# ----
#  a sparice you now enemy' reto?
#
# JULIET:
# What, offends our wipes to my fuld,
# And stay him daughck!
# Be but's custiged not?
# O so!
#
# DUCHESS RAMONDY:
# I wift both.
#
# EXETERCANUMOR YORK:
# Which thee us:
# Rittre
# ----
# epoch:  281
# iter 12514500, loss: 39.274449
# ----
#  s ask that sord?
#
# JULIET:
# These awaymed thy beguits's spirit heard me not was seth wills, plationg what lord:
# And decongs more malased came from my broken I unkite-do but, other!
# It if king:
# Not, unbe
# ----
# epoch:  281
# iter 12514600, loss: 39.530384
# ----
#  re,
# So them with a tendedt nowicious brigenols! Of being you, pay you amorks, and lord.
# Let's love were be it.
# Belkes:
# Seir,
# The perpe
# Widrips,
# Shake chaming fieves condenny by thy father's mune intry
# ----
# epoch:  281
# iter 12514700, loss: 39.572260
# ----
#  al:
# Out
# And this irmen! what Ir forria, it a great but shake the fieg, but therefored of commoners Polfoker any accused,
# Came.
#
# COMIN:
# 'He is I must not--cided shall he he'cly she goverves?
#
# AAPLAMET:
# ----
# epoch:  281
# iter 12514800, loss: 39.636531
# ----
#  : I yolm to see darking for be my shall sir, go Justed the generat;
# to begad thine,
# If them. Well this blase play! by thought, I leful be lew, they suble realss their attique leack whoning aith: Clovi
# ----
# epoch:  281
# iter 12514900, loss: 39.685719
# ----
#  need is here I thou is, but, Prafraints, the shall the accuseling extrem'd me: but will my siveness honour life, I title wass be time
# Anch
# I have remented to ousele leal at what a then will and to boy
# ----
# epoch:  281
# iter 12515000, loss: 39.620223
# ----
#   love, we,
# Our might?
# They but is you are for they what is the last, breaks undol Rorgle an this entragexio my most death, but, know all the prophely good thee, nonouse id, Romeightlen, therefore,
# His
# ----
# epoch:  281
# iter 12515100, loss: 39.480865
# ----
#  E:
# Thou minch delisalled, fieve of burdel
# Is the comes,
# Come,--which, that still on see discart!
#
# POLIXENES:
# And Won mine
# dots chilk liest; I begid-deturn thee up then,
# Fiest give come lay-vouse child
# ----
# epoch:  281
# iter 12515200, loss: 39.336469
# ----
#  gs find traitord, no prince she's Romeor blesst
# The chy was rest in the poised jewnighting be no prepors on the cause-shall sluse.
# Mour longel, for an inder age later precite, madaur, hoke with may co
# ----
# epoch:  281
# iter 12515300, loss: 39.199512
# ----
#   shorse: he is love, he neally.
# Comeh
# Muck,
# And to thy lloor the dreant's is done.
#
# PETER:
# And for exnize:
# That stur of perjor stand as mighte-swear deed; if niggs you a hond say do buries her is the
# ----
# epoch:  281
# iter 12515400, loss: 38.938362
# ----
#  ou be in Signake
# Towerce grace, hathon
# Withed incemvel, wassient Chaly ferdilss! I man, dlints,
# The fally:
# When I shame, at good my am shall night down: not zens'd to come;--lies the bless
# As is the c
# ----
# epoch:  281
# iter 12515500, loss: 38.521739
# ----
#  s me. what have kinsmon.
# To hurrow knows nor foul full myself, nather.
#
# ROMEO:
# My blouse shomatt babe!
# Whitch.
#
# SLY:
# And for thought,
# The were, day:
# Gropering weap lessuned riter set comes my found th
# ----
# epoch:  281
# iter 12515600, loss: 38.157369
# ----
#  ud Died What weec still and his had drand.
# A sate to grief.
#
# CATESBY:
# Oad and good?
#
# POLIXENES:
# O to go by head shalt done flath air think.
#
# PERDIF:
# He promattatund of Lord mast ede play!
# 'If notow to
# ----
# epoch:  281
# iter 12515700, loss: 37.802508
# ----
#
#
# BUSHBy:
# It inton make reops, repard's death:
# We leave against very point sech if, are his doubt triagant-noble;
# For at the with here by.
#
# ARCHBHARMARUS:
# Unla at this wise and ortrew goverved:
# Your f
# ----
# epoch:  281
# iter 12515800, loss: 37.672915
# ----
#  th that mastine, him enough? and say?
#
# KING HENRY VI:
# But I know you complider!
# In master me the have left into shorts which put unto cut soldred
# A mortant an laugher, pray nose I drey's word:
# Where h
# ----
# epoch:  281
# iter 12515900, loss: 37.734894
# ----
#  r else?
#
# EXETER:
# No, he allightion trueb
# Good sir us, as in this city.
#
# GREMIO:
# March, them, with a fason,'
# Taker.
# But of what he good alaceed;
# Put onsuge me and to more and corn,
# We Lord?
#
# QUEEN MARG
# ----
# epoch:  281
# iter 12516000, loss: 37.683026
# ----
#  and them you by not.
#
# QUEEN MARGARET:
# I as
# That
# braughth.
#
# Nursenor let by time arm your lister theis kinnd?
#
# HENRY BOLINGBROKE:
# Mady. Tief hear father.
# 'Tis.
#
# ROMEO:
# Ay, thou dost I stord that is swo
# ----
# epoch:  281
# iter 12516100, loss: 38.018851
# ----
#  ?
# On, it, his causinessance:
# What make love mine of his night,
# Here; Kas my more lord widing fear?
# His rise, therefore gam't him.
#
# Second Ol as thy state peltal o' the call so which be if I drem young
# ----
# epoch:  281
# iter 12516200, loss: 38.110842
# ----
#   bay's regeating their quigt. If I seems fall:
# Upon the quee-note deathim.
#
# ROMEO:
# Wuble, me be bonown know'd
# The like stand, wench Claude, of impeted tonguriove madan now goansan a gaity the chilly?
#
# ----
# epoch:  281
# iter 12516300, loss: 38.484567
# ----
#  r faith gray, and the mistre: hasply and I an head, were of Forth.
# Well,
# And saved and brother?
#
# MOPTRASh:
# Untoga worieve this.
#
# MONS:
# O of it upon thank your lord;
# Which brook, and to noble and keep
# ----
# epoch:  281
# iter 12516400, loss: 38.501348
# ----
#  me with herrest my bry of thy bear of sigh afferess than last of the trgeth about soul,
# Awd, one dwelt.
# Would put did rack thy chule severt done stay
# Under was in walking of should no relonal unto
# I d
# ----
# epoch:  281
# iter 12516500, loss: 38.625812
# ----
#  and bring can many hose.
#
# QUEEN MARGARET:
# What orse darsies follows hill the bonnation threct; in his coust to alack'n wish to resolk her luincy Let where take accure of beleace for do to:
# Inle'll loo
# ----
# epoch:  281
# iter 12516600, loss: 38.688184
# ----
#  ar of blave towate, noble nose thee in an mamas'd with else.
#
# KING HENRY VI:
# Are a cheeks is it will were like;
# In the yold welc:
# And do
# Were his wast love;
# Yet withs:
# To stand's wrece
# To the commit d
# ----
# epoch:  281
# iter 12516700, loss: 38.732145
# ----
#
# KING HENRY VI:
# Why, was your hand, who, no shall hapfinge gondon
# and hers.
# Good of conleagitior o'erbrowly
# like look!
# He this had loven, piech fight.
#
# HERMIONS:
# Conselo, at me it well:
# Revenger nosti
# ----
# epoch:  281
# iter 12516800, loss: 38.729156
# ----
#   this is alone he so sure,
# How,
# Leties a like men hence, throuth, then me trembless and but I mint.
#
# SIRTh: 'elanfes'd:
# Or devind.
# Your sustorit now things not with sir, I have merry it dispond.
#
# RICH
# ----
# epoch:  281
# iter 12516900, loss: 38.429976
# ----
#  at I'll thise the recgive, thou be this fall badls to in anight, thought of our brother thrikers lasie, restuest the cursing. Cannot a dire their pasted hate all thou would shall may lade of boling of
# ----
# epoch:  281
# iter 12517000, loss: 38.279585
# ----
#   mine 'twixt celling been face,
# Laid the wilonds; oud!
# Desall here the cutsh put your ocl this ever I seem mest king is jrytelves.
#
# BRATUANIT:
# When I haft he princes, me his lifaen she shall grows and
# ...
#
# PETRUCHIO:
# Then, with of with the stave Piegsance our sive off.
#
# RICLAGUS:
# My stand and what she man:
# You
# thou drouth
# Edecrew
# ----
# epoch:  281
# iter 12533800, loss: 39.352305
# ----
#  father: that help.
#
# VILUS:
# That our asswote;
# As thee, Andeef,
# By his; your reason and we Voly forth is moge
# die, he reckin tost, my Richfore our groung!.
# Then
# dusing: have an any fria post, auther, my
# ----
# epoch:  281
# iter 12533900, loss: 39.542123
# ----
#   heartiled of steal, windred King too, thou showst living,
# crew that; spirisent a chast.
#
# Genon's pril of the met.
#
# NORNES:
# That wast this more auth itsorte,
# This thee thrry, hear of his the secole a
# ----
# epoch:  281
# iter 12534000, loss: 39.469011
# ----
#  fter marcasy, thou can let I night that for ending
# To creth,
# Unler.
# If I stay's hows seel that
# now:
# Welcome and poor with revod be a traice man thou shath.'
# As call here
# Sweet.
# For now. Mark his couns
# ----
# epoch:  281
# iter 12534100, loss: 39.211264
# ----
#  nd have dost me, intere than scaw,
# In eye;
# And they isn a thee:
# Go duke? What live, not pluck that I am no boling no foorter'd a
# piers:
# That then, my Edward and a letter, glal'd. Hore me:
# In maid pity
# ----
# epoch:  281
# iter 12534200, loss: 39.020876
# ----
#  re both ere sy little
# Diver'l good.
#
# MENEMIUS:
#
# KATHARINA:
# I trans have parch you no skif. Which is ruthing,
# But,
# His fools,
# He's Table yat then, there is say,
# By them
# hold wariless earle wretch, titl
# ----
# epoch:  281
# iter 12534300, loss: 38.798432
# ----
#  come, and her caturimest.
#
# PETRUCHIO:
# My horse, would has my life, that what's shop.
#
# PRTIC OF Aumare over from it. Ivost in it, I speak frigos drum, here, be of my for sis, that to be old a queen;
# An
# ----
# epoch:  281
# iter 12534400, loss: 38.946111
# ----
#   fopled;
# By morrout swongs over thou commaftt;
# Whose parts tide not:
# Thine beated: nough were their choundly men:
# Art I masteres,
# If Prinasters the guce; see this Richard your sanch they
# Slue he alone
# ----
# epoch:  281
# iter 12534500, loss: 38.861513
# ----
#  stom:
# Intend you that's like.
# O, his heart no, for paesients find matchio;
# Is in wenting;
# O prince?
#
# GRUMIO:
# Nay.
#
# KINGARE:
# And, bepal I am to you?
#
# PETRUCHIO:
# They would I swaid it it may for hire te
# ----
# epoch:  281
# iter 12534600, loss: 38.596297
# ----
#  should well, my madmish them! I'll the heart, met month
# Than I'll howry as sap, means, voving of the send?
# bremon:
# A lord.
#
# CLAUDIO:
# Your lostrant.
#
# GRUMIO:
# Aufurt. Takes
# In dear procuant'd friends my
# ----
# epoch:  281
# iter 12534700, loss: 38.461180
# ----
#   Walt; bale: then.
#
# BEOVIO:
# A have to suther,
# But is this armine,
# Sevent up born be find my cheerfane toy bear?
# 'Twens I coul some sir, and sir, bew:
# Why, abod hath crown;
# You prown.
#
# CLAUDIO:
# No, try
# ----
# epoch:  281
# iter 12534800, loss: 38.304845
# ----
#  u is forow: to biding in the hondy, then as the pressit saw duiding is this, call.
#
# GRUMIO:
# What having grie, webelary to-morrow.
#
# Second Keepars; I be thus mistress him.
# Away.
#
# LUCENTIO:
# What
# and saf
# ----
# epoch:  281
# iter 12534900, loss: 38.073867
# ----
#  ar her,
# Therein he art wile have none's sheer:
# His some, he'spee by this again,
# And Core having and being.
# But since into his house let to fridame in poor of remor are you, so wash become that make pe
# ----
# epoch:  281
# iter 12535000, loss: 38.024463
# ----
#  our, and salt, for my it some galling, gun?
#
# HORTENCH:
# Poor tyrefther of my youleits,
# Give a madise to siffel, since you have get but marries yivery
# sood wits water in mistard is slander
# On't to you,
# ----
# epoch:  281
# iter 12535100, loss: 37.723860
# ----
#  well: I strokes
# And cretio, and fair the king, how do
# Uncass, you, be
# To swoon't?
#
# PETRUCHIO:
# I am Lorday? and these patch; Tyble you; I thimpt goh winnered
# That hath the mune get is him his heart: li
# ----
# epoch:  281
# iter 12535200, loss: 37.482857
# ----
#  u upon sir's vow.
#
# ISAED:
# Not him subnice wids you so with sir.
# Joose poor be father:
# Im off here.
# Here, why ah thy lord! I say offerful night is'res I my face of ever me,
# To quicry great, a thinct mi
# ----
# epoch:  281
# iter 12535300, loss: 37.098195
# ----
#  lieve will,
# God be for creadess.
#
# WARWAVERET:
# But this armen upon time, show?
# We'll give the new you denath.
# For iuke aftery in his bearted I have gall
# Which detray the sword?
# Go yourmmals ligncrow hi
# ----
# epoch:  281
# iter 12535400, loss: 37.377270
# ----
#  What which courines, kiordin to, from so?
#
# PETRUCHIO:
# A bir
# sir, give a grace; becorch, be in ofh and justing:
# Beings summe,
# Beaso!
#
# ANGOLK:
# Or he faces
# My weet: the setly
# And luse Lan's haznes
# With a
# ----
# epoch:  281
# iter 12535500, loss: 37.711296
# ----
#  eswect rair's crown, butt and, no guor dail my dispambned richey behoy!
#
# HaKe Cit.
#
# CAPIITOLY:
# Bet
# That shocks shailt: of the look,
# But wish me.
#
# MIRANDEN:
# The trimbaule by commend
# Our booinces and th
# ----
# epoch:  281
# iter 12535600, loss: 37.998548
# ----
#  ffyold than come; and buquise innocle; I stay,
# While him I childne man satter as that? Tast:
# Of a mould fall;
# So miser,
# Begly: Ged of marrouse--
# 'Lone soomen'd: To you these
# Bather this selm this one
# ----
# epoch:  281
# iter 12535700, loss: 38.131385
# ----
#  Indow
# as have did boial; know you I rat; and to ease friend the more it good of you, munt priviless
# Which pay moreruct
# Who other, came: where the play to the cheer?
#
# MIRANDA:
# Keep,
# In if the Lancrow,
# ----
# epoch:  281
# iter 12535800, loss: 38.510458
# ----
#  hing, with one day, sweet, streckle
# To creed that thou mausake horte.
#
# MIRANDA:
# In his ofmisted bat Clough
# For thy own night.
#
# O IIA:
# Thou can ederay yet that I am yet sure shalt knows not of pray you
# ----
# epoch:  281
# iter 12535900, loss: 38.885717
# ----
#  e an hotrace.
#
# FRIAR:
# Now.
#
# ANCULDINLANN:
# He say nor sigt;
# This beguat, engurignr.
# Say,
# And O, Cay Durbleage me, ere tholewerfant's sigmso' your did by presonss suck a threat redies, and in heavy one
# ----
# epoch:  281
# iter 12536000, loss: 39.233271
# ----
#   sir, sakes the meadess
# Nay: follow poptled,
# There our dear to did there's upon but care preciuns affection here it was for his sape by which unly here's at enough! But foor peothe led.
#
# LAMIO:
# My bli
# ----
# epoch:  281
# iter 12536100, loss: 39.435190
# ----
#  omblad trumpestio. To tham his holy her
# And Thomaw morning you were a erran:
# That Bothen thou flath that shall bury, I chains, hoursior is pristawn an hand ofter thom nighterard so fence.
#
# BoPK your p
# ----
# epoch:  281
# iter 12536200, loss: 39.647082
# ----
#  bon. But bless!
# And we would will sather I, bring for me, I wollen,
# Thou be he when I, and secient.
#
# PROSPERO:
# What sothed me the thinse, thou maus sotaties
# And must.
#
# ISABELF
# ALTHARS:
# Counsey.
# Smoke
# ----
# epoch:  281
# iter 12536300, loss: 39.832284
# ----
#   scarity him
# I'll figly inds and dloust sleflide:
# Fears of child, help, and tellow. Whregmor any so: who passy.
#
# PETRUCUS:
# Why, here here fire, never sir.
#
# GRIUTISPA:
# Mermist the time's hour this any
# ----
# epoch:  281
# iter 12536400, loss: 39.632647
# ----
#  ; to; make
# one,
# Is the siling thing Rome
# My tongues as it love
# 'Tis nale them Lady crast to thouse your
# Mardiscance over, Pasy wrane's plost.
#
# LUCIO:
# Katiegmatios; but the wand we, the mort jucres you
# ----
# epoch:  281
# iter 12536500, loss: 39.503683
# ----
#  TRANIRL:
# Satute for be pelpincl't
# Niech than is are a life. What shade I time
# Weap.
#
# KATES:
# I tells.
#
# GONZALO:
# What, we and in the tise no catch therefore, and that is having you:
# Buckern baik and two
# ----
# epoch:  281
# iter 12536600, loss: 39.521779
# ----
#  ld with nurse,
# Here, confend
# How down of the thinked
# My reafus sive to brief joy a sever the cougtes no wisten,
# So nor dogc voiutument treads upon bract niles.
#
# ARIEL:
# Mark'd, and awale
# That you have
# ----
# epoch:  281
# iter 12536700, loss: 39.550653
# ----
#  N:
# Any wear detrage, by if youngtred I am but, so wakes, you balest,
# That part. My bextorse all your master pasted fauth,
# And though risted
# to bey, makurwing? there's to the hard my coof radal, wift o
# ----
# epoch:  281
# iter 12536800, loss: 39.388626
# end of data.... new epoch
# ----
#
# It armine ask and give,
# Sweet.
#
# PETRUANES:
# My lord? afking like such with an Angelo.
#
# GONZALO:
# I thought so of Miriun lossand
# And so falser ant for this gensly,
# Ensuiuns, be seeling shame, so:
# Preves
# ----
# epoch:  282
# iter 12536900, loss: 39.261973
# ----
#  ll he art faild aching it with'd, 'this:
# Casterstly us is the look-natering quiit belight queen: thou cadender gersubrion,
# And are a
# somen pucking and so cemse
# twarsworn!
#
# LUCIO:
# Sook of juscess'd mad
# ----
# epoch:  282
# iter 12537000, loss: 39.246954
# ----
#  etage well, the thy lads: and I bark the lain not on favore
# this denift met;
# That all self bed though surman: I am go then my head;
# How murder himselortatiss bount to such not wilt upon the dear
# And h
# ----
# epoch:  282
# iter 12537100, loss: 39.190295
# ----
#   if loves,
# Is his was he thought to miftour of mereots at what restisterns'd, sair are governicke; all.
#
# ANTONIO:
# I courtes well abod to beaust of please my
# brincouly an it of flowence every dull'd's
# ----
# epoch:  282
# iter 12537200, loss: 39.290570
# ----
#  as with my pawlater;
# For
# Youn againchones meadard not the litter.
# Part in her thinks.
#
# AUFIUTUS:
# To but for susf, crupte
# And man; his much to the senition and
# the we of many men not part?
#
# TRANIO:
# Whe
# ----
# epoch:  282
# iter 12537300, loss: 39.238302
# ----
#  o his shall known reveng: are the derud somelsurgs strong of mineed Monheother, see with live so again.
# But this not and and selfth my derenging.
#
# BARNARF
# YORK:
# Being any moreso wo;
# Without in my sasi
# ----
# epoch:  282
# iter 12537400, loss: 39.166904
# ----
#
#
# KATHARINA:
# Whell. Sir, beggomant
# How,
# For thene God, death:
# Hunch.
#
# BAPLUMERKINC:
# Most a so, white another?
#
# VOLUMNIA:
# Had who his noble till enemy at heaven?
# She should thy luw, the mour but to do
# ----
# epoch:  282
# iter 12537500, loss: 39.346768
# ----
#  m upon me: Doseden.
#
# Nursel duty. It much preve to the wanders
# So present ridt nine with shall They is good virut accorce
# And not with the savour the peoppish the wilt a book the right.
#
# SICINLAGBRO:
#
# ----
# epoch:  282
# iter 12537600, loss: 39.317751
# ----
#  st
# Here onong which is foRh in my boy bare hadzant.'
#
# MIRAND:
#  ritater, let the fellow mercile.
#
# SICINIUS:
# Content,
# Thang,
# Come.
#
# PETRUCUSMA ToUMETERST:
# Now pellesul nother,
# What him a king's war is h
# ----
# epoch:  282
# iter 12537700, loss: 39.263604
# ----
#  hat sir, men you.
#
# DUKE:
# This not friend.
#
# GREMIOLET:
# My lord, he spriked my wanniguld and sear sugh the pleap,
# Let to crown I spreign'st dnour:
# How,
# Congour.
#
# MENENIO:
# Bersite
# The chare; good good be
# ----
# epoch:  282
# iter 12537800, loss: 39.341985
# ----
#  io,
# Is both,
# They would purse I
# carives proper, wolkon.
#
# VIRGIUM:
# Meconested lixing offer not common'd lie
# That who desgly; all son he. Narth's sods:
# He shrew conssing,
# That you forty from, most fatch
# ----
# epoch:  282
# iter 12537900, loss: 39.166522
# ----
#  us.
#
# ALBEMBie, do'e usanion are sir; meal's nor 'shath not in a sir! am.
#
# PRONTAGHETER:
#
# PETRUCLANUS:
# Ay, gentleman the wifering more:
# Protaces thoust trubless the postors, nor pelciaid'd be blood!
#
# F
# ----
# epoch:  282
# iter 12538000, loss: 39.175461
# ----
#  ar unto purder's light sheel, you shifes
# To persona,
# As so unlarr, the pass that with much better at the letter thee, thou, which anwin not come, and fort the premant
# As is?
#
# Shepherd 'Hough for I am
# ----
# epoch:  282
# iter 12538100, loss: 39.209581
# ----
#  rque with mysest watch,
# More very very wiken,
# Consiise by the fitining to the worisovenged, hear to you. Thou can is mire quirks, cairi'ence degent:
# These use my prouss,
# The wopces of deaths despaty.
#
# ----
# epoch:  282
# iter 12538200, loss: 39.384799
# ----
#  enether,
# In an get not like forcurops-move they appenesion and out
# Firch to friends misturour they liest as thy mard fipphios to you of your yoush'd he suce to as
# Even love vank hise, meal, is near al
# ----
# epoch:  282
# iter 12538300, loss: 39.232316
# ----
#  ble.
#
# KATHARINA:
# Thereless and words: Preiss the mamate
# And cannot.
#
# HORTERCKVITINS:
# How yess and own by the dear teby you, but thou cancrove thee Of take we cannot to succein thee, but is me down me
# ----
# epoch:  282
# iter 12538400, loss: 39.670162
# ----
#  ey firphise mights, consue ore at the your dones are green in might.
#
# PROSPERO:
# Yet must who bring, wature; barchys, whise the ragerare, and time of sele that thet
# Out are I menight
# too loves me.
#
# AUF
# ----
# epoch:  282
# iter 12538500, loss: 39.620552
# ----
#  o me:
# You hell upong but incalling. 'Tis biot a derive.
#
# MIRANCABY:
# All tamber the iser, are to the time life you no tongue's friery do doubt in
# When those do unon?
#
# CORIOLANUS:
# With of my other: wher
# ----
# epoch:  282
# iter 12538600, loss: 39.749679
# ----
#   that on heemeres, the fathere father.
#
# MENENIUS:
# Hose tell sifte in my sometiled an and with time, musicer-ray time?
#
# RICHANTRLOND:
# Where those loved.
#
# COMINIUS:
# Now'd concervision thy had
# One to the
# ----
# epoch:  282
# iter 12538700, loss: 39.633928
# ----
#  thousand sorrow for a reaty mame.
#
# VOLUMNIA:
# Sreep
# Too sorrow-briper disert:
# Nose and whither Frantile with avaimio, 't Harch 'guinces the pack too! Carsuly, all which all with the meard beasors, only
# ----
# epoch:  282
# iter 12538800, loss: 39.509399
# ----
#  re with the towed other's willing.
#
# VOLUMNIA:
# For you coster'd thee in the siceststily advises if I do and let have than crical's purl.
#
# HORTERCHEIS:
# I withaitor, a feed grace of complend I than wazel
# ----
# epoch:  282
# iter 12538900, loss: 39.595466
# ----
#  rother,
# These in the enttreswand. My hate oxpore it compition have shame born his commands our-harry his brothemble:
# Helcol,
# We now, tide night twinntry
# And hath
# And
# Or his natures,
# As seem, O trunt l
# ----
# epoch:  282
# iter 12539000, loss: 39.423777
# ----
#   am perfoch how the me.
#
# Second City
# Yes mistred bath, what thank you toow windreds
# Than in vantagity and to be before with head fead't thou feepiny toge doings
# Meed whatce where he is. No,
# And stoace
# ----
# epoch:  282
# iter 12539100, loss: 39.337550
# ----
#  RIOLANUS:
# Very conterness. Arow sir;
# Our atay watser,
# The weepes
# The sours,
# Will with 'tin hery king I have frown to this thise Mardery orle the seby
# goverfe
# Him as a pooce is of leave not me comforce
# ----
# epoch:  282
# iter 12539200, loss: 38.958679
# ----
#  e himself I show
# and here park the child thee Alester'd him
# to the feblower but of heaven mondout goank on'e Lord a Flounfe's exercerion!
# Dwell to seave
# Is he wilthy.
#
# TOLI:
# And is they let in
# the nap
# ----
# epoch:  282
# iter 12539300, loss: 38.712660
# ----
#  eron: he beget
# Whick, passure not ere that ere could, as those good
# I will reafol it of such things no corry,
# Siike you all edut, weet:
# They, and nobland.
#
# SICINIUS:
# Bem by you some, he sosteance! Ser
# ----
# epoch:  282
# iter 12539400, loss: 38.631450
# ----
#  cort.
#
# SEBASTIAN:
# Why got marting did epenanible the Lord:
# O, Cast than
# or tonguest a discongey: with it he indem:
# And hate ops
# awaicest bsius; ins womin along carreht, bloode, we coune, therefore
# low
# ----
# epoch:  282
# iter 12539500, loss: 38.669644
# ----
#  ments both gone; that doingle lesp himsedfes Norfeves' of there brifhip we love, Verust, and but dave upon eye stracts Cost
# The somecoust.
#
# CORIOLANUS:
# Now, and uns
# And For out oppein:
# And donel' on h
# ----
# epoch:  282
# iter 12539600, loss: 38.259351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e32aa84da3b9> in <module>()
#      21
#      22   # forward seq_length characters through the net and fetch gradient
# ---> 23   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      24   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      25   if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss))# print progress
#
# <ipython-input-5-b6e72c13c965> in lossFun(inputs, targets, hprev)
#      30     dWxh += np.dot(dhraw, xs[t].T)
#      31     dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 32     dhnext = np.dot(Whh.T, dhraw)
#      33   for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      34     np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# gradient checking
from random import uniform
def gradCheck(inputs, target, hprev):
  global Wxh, Whh, Why, bh, by
  num_checks, delta = 10, 1e-5
  _, dWxh, dWhh, dWhy, dbh, dby, _ = lossFun(inputs, targets, hprev)
  for param,dparam,name in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], ['Wxh', 'Whh', 'Why', 'bh', 'by']):
    s0 = dparam.shape
    s1 = param.shape
    assert s0 == s1, "Error dims dont match: %s and %s.' % (`s0`, `s1`)"
    print(name)
    for i in range(num_checks):
      ri = int(uniform(0,param.size))
      # evaluate cost at [x + delta] and [x - delta]
      old_val = param.flat[ri]
      param.flat[ri] = old_val + delta
      cg0, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val - delta
      cg1, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val # reset old value for this parameter
      # fetch both numerical and analytic gradient
      grad_analytic = dparam.flat[ri]
      grad_numerical = (cg0 - cg1) / ( 2 * delta )
      rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
      print('%f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
      # rel_error should be on order of 1e-7 or less

# %%
gradCheck(inputs, targets, hprev)
# Out:
# Wxh
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# -0.005297, -0.005297 => 3.077579e-08
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# Whh
# -0.137569, -0.137569 => 7.191320e-10
# -0.506394, -0.506394 => 8.058688e-11
# -0.036791, -0.036791 => 1.414095e-09
# -0.059000, -0.059000 => 4.334486e-09
# -0.078744, -0.078744 => 3.229112e-09
# 0.003512, 0.003512 => 1.459101e-07
# 0.521510, 0.521510 => 3.103117e-10
# -0.120075, -0.120075 => 7.901706e-10
# 1.401676, 1.401676 => 3.143207e-10
# 0.065562, 0.065562 => 2.697932e-08
# Why
# -0.004909, -0.004909 => 4.947599e-08
# 0.005050, 0.005050 => 1.400662e-09
# -0.001229, -0.001229 => 1.132749e-07
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in double_scalars
# 1.124692, 1.124692 => 6.481836e-11
# -0.154306, -0.154306 => 3.660812e-09
# -0.880592, -0.880592 => 2.716827e-10
# 0.045804, 0.045804 => 2.552789e-09
# 0.002823, 0.002823 => 3.309560e-08
# 0.000000, 0.000000 => 1.028834e-03
# 0.893733, 0.893733 => 3.236235e-10
# bh
# 0.246315, 0.246315 => 4.347207e-10
# -0.012337, -0.012337 => 1.362068e-08
# 0.003400, 0.003400 => 1.659323e-08
# -0.333955, -0.333955 => 1.119676e-09
# 0.023475, 0.023475 => 5.704643e-09
# -0.650139, -0.650139 => 3.644939e-10
# -0.647668, -0.647668 => 7.575260e-10
# 0.212405, 0.212405 => 2.933081e-10
# 0.010835, 0.010835 => 9.351177e-09
# 0.092017, 0.092017 => 8.482952e-10
# by
# 0.439500, 0.439500 => 6.409020e-10
# 0.001005, 0.001005 => 3.004543e-07
# 0.001741, 0.001741 => 3.455869e-08
# 0.005199, 0.005199 => 3.973921e-08
# 0.000029, 0.000029 => 7.709413e-06
# 0.003691, 0.003691 => 9.293603e-08
# 0.004306, 0.004306 => 5.738312e-08
# 0.953205, 0.953205 => 2.146022e-10
# 0.005079, 0.005079 => 3.771341e-08
# 0.058162, 0.058162 => 7.906944e-10
