# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('/content/gdrive/MyDrive/project_7/data/tinyshakespeare/input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1
epoch = 50

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p, e = 0, 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while e < epoch + 1:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
    print("end of data.... new epoch")
    e += 1
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))
    print("epoch: ", e)

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss))# print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# Streaming output truncated to the last 5000 lines.
# Cleinip
# ----
# epoch:  50
# iter 2189700, loss: 46.201561
# ----
#  d bemen'd pund where my pancubreane
# By fear I corrtors blom's;
# I ablost
# To soveniely,
# 'lleved pill munrering thene.
# Yol scaems! you then is dith gracomy, thou here serier and we broon'd I were:
#
# POMy!
# ----
# epoch:  50
# iter 2189800, loss: 46.301219
# ----
#  e am hastord
# Towven ope eave,
# Non is nom not leeve you he spowdisce!
#
# RENCIOLE:
#
# CORIOLANUS:
# Bews thour,
# Wroad: houd tury, dramenle.
#
# MENENIUS:
# To met let gewned now mai,
# What the beay;
# Ssmonnithout,
#
# ----
# epoch:  50
# iter 2189900, loss: 46.037519
# ----
#  allior peefortor swice' a hought you, had Butt uphart, and itreat's the macather did
# Lay me?
#
# MARIPDI:
# That could her heads
# Wiblain of fol gather you then
# You thound foill a plood, haouboge it uppean
# ----
# epoch:  50
# iter 2190000, loss: 46.064363
# ----
#  per sent the morl to is lien gote he cold! Hamimare
# Now a tarier
# Of pit! I us scome moth's have verussone.
# Yry, I no.
#
# DUKE VINPUA:
# Weled,
# Bet'd her;
# And of not my conce;
# It have
# Nor, oor oad for scov
# ----
# epoch:  50
# iter 2190100, loss: 46.072334
# ----
#  our bos,
# Praves like sees smiesw'd libsemen
# cemasing goo fordice?
#
# FROLDINANUS:
# When thorlivet:
# Ther,
# And, torg'st, by
# hos 'twip pext our heve! I meaned,
# Then beat sroth white arnoce be as Ame to sir
# ----
# epoch:  50
# iter 2190200, loss: 45.836392
# ----
#  ding in with this thou noble mat, bet.
#
# Herdspangs, bun Edmandane.
# Poves here ison bond time Anomeds the garmy the gareder thy gond, o'st her.
#
# Prot.
#
# Thirty.
#
# Mirs, it yeet, I init itcobe sanect as w
# ----
# epoch:  50
# iter 2190300, loss: 46.137136
# ----
#  ne,
# Auningies woss:
# Egloctice be in thamoun and sa and a viltwaus: he. Leicofing for, it farck and, offore:
# Dicincury to pice fors agage,
# As sime hevenasopced wasbests you,
# Tichied I sapt And headry n
# ----
# epoch:  50
# iter 2190400, loss: 46.008543
# ----
#  arrhief the dow,
#
# MyLuR:
# Whist to, on.
# But.
#
# Piting.
#
# GRENCELLA:
# Bigser,
# Have
# Tquied:
# When,
# Prance!
# For sain; Peakie a.
#
# CPIO:
# Moy
# thou, be not who sefing?-:
# Than mins
# Ah manse thee? IS prouned withol
# ----
# epoch:  50
# iter 2190500, loss: 45.935702
# ----
#   Ward;
# Getiuls
# Londt your will nete love
# What trutle.
#
# novas is calling thy prangel:
# Then deent.
#
# PETRANIO:
# Us venure maise mosems queery,
# That his otlase toser wither wor, the forow Low more pive sha
# ----
# epoch:  50
# iter 2190600, loss: 46.082026
# ----
#  tuod haves
# Where, bothain lither up, what gook.
# As my and usbous
# The
# my crie compaus?
#
# POLIZATUS:
# Cel give copeet.
#
# VVORANt
# Encooders
# Thige stury
# But of his, I
# Hanrweter that
# And helves fexece,
# Ay, be
# ----
# epoch:  50
# iter 2190700, loss: 46.186582
# ----
#  nour deave, fure
# Yet lont ingrigh.
#
# CORIOLANUENTELLUEE:
# For com'd periman aighaw!
#
# ASTheid an shawnd.
#
# CORIOLANUS:
# Seay banter the mire nove Cith laspery
# O this, we cust and resovust no'd,
# And for my
# ----
# epoch:  50
# iter 2190800, loss: 46.327571
# ----
#  os!
#
# MEwRUD:
#
# Sease
# We knall
# This
# Are wilt Preit than is, worrsuy the poing
# Ane, Shill Lign's tomue conoty my with larone, the gathory
# so litfiarfars of's sifst migon be pittratius go bood, witholl th
# ----
# epoch:  50
# iter 2190900, loss: 46.280668
# ----
#  e inortioly atry hilive cole tal sinner; wome'd,
# He to forsa! shath mither the wood out foush?
# Do sin ouble Cowren, he withf, whinef ono us.
# Buristanes stows gour, rever the such tere qiad'd no.
# Ke te
# ----
# epoch:  50
# iter 2191000, loss: 46.223967
# ----
#   myes they langein and to latest yo,
# If compony:
# which yoursty.
#
# SIIIINGHANNES sen?
#
# Firm:
# lown:
# And! By
# Het,
# Donchin I cour supcen, gract save: rilk.
#
# Seasest ood, you he heneient pury
# Cope as am giv
# ----
# epoch:  50
# iter 2191100, loss: 46.245662
# ----
#  age out tame at Kise Kind it molly my all abule fainch sweandle,
# And she gath it taply Come soury's, go dike in hey utheren'll that of of his of he denkelt your in Spontle, holregt
# Say:
# Will, thil so
# ----
# epoch:  50
# iter 2191200, loss: 46.363529
# ----
#  thoughess to I reather that frietrir deadh to this?
# To sip way pleerd's in the bewn! Mere nought giverente
# Thy loow's of frie.
#
# DUCELIA:
# Wheientil
#
# Oo Thy, wellt:
# Make, and how canst. I'll there oefor
# ----
# epoch:  50
# iter 2191300, loss: 46.242397
# ----
#   have tamires ever the cect. Inwers tence your were many mangh.
#
# ForvANDY:
# Nor mow.
#
# VEMINIUS:
# And it if wicrornow Boanter: ald.
# Thacks,
# It mone;
# He lew, bean, dy bier me
# To my rees asward have. But s
# ----
# epoch:  50
# iter 2191400, loss: 46.202809
# ----
#  suse, ond us in they Marder.
#
# HENRIIV:
# Nor there:
# On is here your doncuck me;
# breforgr sir, hath I war the Dukss as tchasunted;
# Who ey you mer
# Whie prangel, God
# brices get's anZond So torpa aw;
# And's
# ----
# epoch:  50
# iter 2191500, loss: 46.307584
# ----
#  meakn,
# An woudditise cove wortre! ofrn henute 'onfugalastion osen?
# Sury
# Yeth knale:
# I brifen lenes:
# Are,
# Hemprely should so, uncaceman.
#
# BRONIO:
# Nay, my I ding here our may.
#
# PETONIUS:
# Nond.
#
# JOHNIUS:
# ----
# epoch:  50
# iter 2191600, loss: 46.483249
# ----
#  heatist,
# Ale yours im ir not.
#
# SANUS:
# For witly wise well lixtrinery.
#
# LOHENCENTERNA:
# Heagene these love prixtary gaiunds.
# A deagh troin will life but thouse vere and flece. Wat bade coard but a hims'
# ----
# epoch:  50
# iter 2191700, loss: 46.407748
# ----
#  quear hear
# He your of neer sad! wow it now cion conspenpely sul the be fake for thes you recelourt of at; a, and gived you aats you swire will not lutneran, there that wirentble and canter. Time thee
# ----
# epoch:  50
# iter 2191800, loss: 46.603449
# ----
#  f,
# Frir I harr'e fether settise chin doscegp. Ifer beceincented: rather his him what will nou habtangn on of tam homand. Hath a bireven, shali.
# There buthizen: the tithoon a the meals his to in touth
# ----
# epoch:  50
# iter 2191900, loss: 46.567361
# ----
#  S:
# In and of my kiny but tyrus thad witugemert'lighth:
# Les hath. Kizst thy bes
# How; wis that, then the upprant was loid sow tith undach a Morltantao:
# To we
# menvet that, bredard;
# As to meantervy you ha
# ----
# epoch:  50
# iter 2192000, loss: 46.621508
# ----
#  ?
# Shibs?
#
# FRENIOLA:
# I lor hiftem'n tispinsing all as will eok sprey your chate
# That for of appon; and Calb gordriat vitith som's knadep Yet I ale.
# So see pretice.
#
# Sist:
# And any wort
# So manis;
# Mwo vip
# ----
# epoch:  50
# iter 2192100, loss: 46.757466
# ----
#  h merier to five our be it Hot we't ese.
# Dot for contove of lave,
# And.
#
# Nordsull, Wily may tix grewar shard you that hewd you dues we tishh muck;
# But wherreo,
# In a cat bo't him; of it, to a to to pris
# ----
# epoch:  50
# iter 2192200, loss: 46.696472
# ----
#  ty, begh fless whenes to let your me,
# Sust whan,
# I dome for with Row thou his with seron in new A hins:
# The cous-fiphour amanon.
# If five:
# Hest sustay terly hears he but you, betire coms
# and?
#
# LUCIO:
# c
# ----
# epoch:  50
# iter 2192300, loss: 46.857248
# ----
#  dt I kingur for
# inciighdlen In and cone gotiour wolng Had, you
# Noncucion wows; nottrerace fray!
# Ferr.
#
# DUKE VIO:
# We varls, I king.
#
# DUKEN:
# As denriich Cove Nentrore,
# I gord.
#
# GBOUS:
# Be his high you of
# ----
# epoch:  50
# iter 2192400, loss: 47.098050
# ----
#  thruber's of a had they dishers othar;
# And ot there your at the plone it prewange is at the wor;
# Who bit?
# Noblike poad of beteroffor be to gair, wous on.
#
# BONIOL:
# Where you ser's nors made there swost
# ----
# epoch:  50
# iter 2192500, loss: 47.061186
# ----
#  ove dells: masI our;
# He hilpliest dreal the depast you tiun with cear is whitens on sterrcise. Have him
# Well requenos;
# Xnoin bely
# Their offt. And Cachile gunod, ore fare? hinins,
#
# LUCIUS:
# You eveernir
# ----
# epoch:  50
# iter 2192600, loss: 46.877187
# ----
#  ligct procqued you nollotion rangh;
# Of as heant?
#
# Frambe you mad:
# Sears.
# Thear
# Bredeate oftermy dightraves Gof dove,
# Hodh of is bealone,
# Hoth be the wish they
# Syeame fewer:
# Thee eriy, one anse cuce no
# ----
# epoch:  50
# iter 2192700, loss: 47.014901
# ----
#  S:
# And vow,
# Must of to
# Podturaingh amsoy,
# And my and to verms,
# And Clave; snoithenacknoust did offy lind,
# Whie:
# I'll
# '
# herial o'lich notirer, for latssern,
# I wood conde! chearth the pliectarf,
# Frost h
# ----
# epoch:  50
# iter 2192800, loss: 46.882395
# ----
#  ith wordden, your it ericelmeif, may's beasiunt is wordwaelth shave beme tead!
#
# LUCIO:
# What'dl thoud would it thrord not ce beivendast.
#
# BRATIID:
# 'Twad come is qill on
# Lorr, is deon y your judc: thou
# ----
# epoch:  50
# iter 2192900, loss: 46.363905
# ----
#   mudk to that house
# Hayoule cheech
# Hin your of hearth this swel.
#  Lust Heade, what thou frobly all the make neppa! sayser
# Buty not upoined,
# Sid warce tentioke Eifsel if cace
# Will now the gocles porry;
# ----
# epoch:  50
# iter 2193000, loss: 46.115164
# ----
#  :
# Meragh.
#
# WORICLAS:
# He soat ofr come Hemieg!
#
# GLOUCESTERT:
# Wish prous fnow, sordiced ever with wotclung, whie:
# Whou gich you sill, and yor beok exerpears potias lersisenricy, mady cro.
#
# COMINIUS:
# Nor
# ----
# epoch:  50
# iter 2193100, loss: 46.302936
# ----
#  itest to giak have
# And word
# ppreep band.
#
# CORICHERNENIUS:
# God Dived eventiod, for all conds thee spirthities.
#
# Banglest that thy dutting chamo,
# They whipts thou like gare him
# Onesp is sfore;
# Nor is he
# ----
# epoch:  50
# iter 2193200, loss: 46.245645
# ----
#  r his beode; of bos;
# The cockess you, what thy quece the vowd he mentiy trate with not and, sirk hadsick: deatire in bledull she.
#
# SION CAUFLY:
# And in spespce; fork proped,
# We will at what rather;
# Sen
# ----
# epoch:  50
# iter 2193300, loss: 46.144990
# ----
#  ou hand'd that let madrat.
# Hand teely you it manlise buther lend me
# Widsblat mour.
#
# BENESY:
# The to yound tot nowns, fielt hornome love, itles ofmy the firse quapain my gnaly: I heness a donch.
#
# Loyed
#
# ----
# epoch:  50
# iter 2193400, loss: 45.856638
# ----
#   did tay yee
# No, have fir'ss, yet you on ward:
# And of, on ench. Lothy and, come.
# They deing, queen conther to:
# Bid,
# Auld thank that mane that arane;
# Goid; and mist,
# I treening peace them.
# Noasten, mus
# ----
# epoch:  50
# iter 2193500, loss: 45.898705
# ----
#  st which whan. Guctelol and eppairs,
# If 'arngeret:
# Vors combste.
#
# Simoinfer so how, as for come misucest trayinit?
# Alight chank: hem kempen, the son purder now,
# Upord:
# And in and than shighthent gelts
# ----
# epoch:  50
# iter 2193600, loss: 45.879754
# ----
#  natherves spo, and my cought hear their and deay is you then no houbking steak &fery
# Must alont:
# With gokentarm'd.
#
# Sigh, stere but strefloum a your deather befur
# no spake prekphice,
# Thes but gond blo
# ----
# epoch:  50
# iter 2193700, loss: 45.583068
# ----
#  reined was heit will I fall now tarbece 'me fatended's meven cheeplen:
# he of he wave for burs cath pead him.
#  Bid, nod with the gad hear of wanded; affor?
# Inges is thee sir I,
# Rame that did be plind a
# ----
# epoch:  50
# iter 2193800, loss: 45.802428
# ----
#   noble:
# Enter to me nay, the not you the strase, pear Rilters chach him as thus, hen faxmand,
# And so pean and Rowed my paght botl,
# Ro, cased ye:
# And comelf's and, bite the your be sorsome tolo! whearl
# ----
# epoch:  50
# iter 2193900, loss: 46.133667
# ----
#  o' tate vish will is yous ance and knd their you dien in the for to ay mows, and he; agochir shall which have, vitiens is homed, when so hew harw I merotues, thy whet comn
# Be hemptame be groPe thanksa
# ----
# epoch:  50
# iter 2194000, loss: 46.144121
# ----
#  ith:
# Infeth, it womes she tays to bake ald goay stoms,
# And gevene to vire:
# And his hath buty e deceen sprusemy?
#
# LUCIO:
# Nor thee fathed and fenie: you dequers the cancenth? Wame inter is slike
# mfer?
#
#
# ----
# epoch:  50
# iter 2194100, loss: 46.084486
# ----
#  r to have
# resving cus maddat.
#
# WARINA:
# Ever,
# And he spothen Wad. Hould ouss? With of antwillend you, it tormect his
# my plal bromper,
# And if not gy it whit.
# Muth in wor,
# mas fitser you itst and to.
#
# GL
# ----
# epoch:  50
# iter 2194200, loss: 45.859448
# ----
#
# Thee.
#
# ISCERENSAzSWhE his! but.
#
# SLOA:
# Seving---breatty be.
# Ulenge dor:
# I shatile toy muke gand tix gimer it or
# Nay this pruss
# Lot, youd as and that wititure: munast kits:
# The promans your, heeltsel
# ----
# epoch:  50
# iter 2194300, loss: 45.696595
# ----
#  t acure thy sunent amactimes!-
# Uove's.
# And smy and of thek canmtary I quessned
# Bet.
# Make le his you what how nothich is and our know, And weare cous ery be Ed in shald book with thewele
# Axpe, I here t
# ----
# epoch:  50
# iter 2194400, loss: 45.815202
# ----
#  w In pean
# I'er and guss me my waty:
# And shangt and; wo.
#
# BARTAON:
# Yryous, what, thynyery-now!
# Tasted, of ghas telistforife, to hy misting senrizecced
# Whie, il must have wewelfin;
# I drake life, cike, m
# ----
# epoch:  50
# iter 2194500, loss: 45.767415
# ----
#  h holl If fo I brecel on!
# Fe, indoutt muster of Ssto: pringuive,
# Siver beave!
# Not hathol no:
# A pripor the good have
# That and unto olustery's clopsbre.
#
# DUCDICHIS:
# Mhy creake, bus witt
# Whou sholl the w
# ----
# epoch:  50
# iter 2194600, loss: 45.692364
# ----
#  T:
# Thy have whisfermany:
# Whaithins there, or flomeep not the oaness
# Summfornt is ginds:
# Cabmer:
# That of this show were dreath's to
# Her anfols my har, Tnow dise, sa?
#
# Seighing; and insurgew vilpspoure
# ----
# epoch:  50
# iter 2194700, loss: 45.852519
# ----
#  eteat thou secks befong stare thy brod merpsto thy trom greary ay I''d your but sage I'll gool
# toll,
# Firs aDkanqued, of mituss he tordy repook. Swas wand tald by;
# Uftleseder and sommans in leck, brot
# ----
# epoch:  50
# iter 2194800, loss: 45.845502
# ----
#  K:
# Say ppot! I'lb forve
# With goss, you your gonders,
# Whichingun laestice 'gor that cropave!
#
# BUS:
# Nustit, my wreanfhing to the in colut son poight avo,
# For heill shall come.
#
# DUCHENCK:
# My lood, him Ri
# ----
# epoch:  50
# iter 2194900, loss: 45.794969
# ----
#  rly fure, car hese ville:
# Then daye,
# Shill hee have mine, preed of you? I'll.
#
# VIRAPUS:
# In ligld, and all theberped lod he fer you hasp'd thou meatifelt
# That ashe fite,
# He sir Come ce
# And torbon alfor
# ----
# epoch:  50
# iter 2195000, loss: 45.683600
# ----
#  nit, raver him, my rethord veablieseas and ships rotiut therach so comlous to bop and hou spoved? fur fort harated the efe 'ysang whab bit:
# Loat, them he his the swy.
#
# Murdiond, am the goncre: Cas del
# ----
# epoch:  50
# iter 2195100, loss: 45.562957
# ----
#  And to it: of 'lien:
# Weppon onke, newal,
# Ledesly uplonchan. Hought aly gixt a not I benely,
# Aw,
# Mad hayaviurs.
#
# For IVorsellf's mane think drucung aul and the fegt, you 'How.
#
# LEYD HANCO:
# Farn let whe
# ----
# epoch:  50
# iter 2195200, loss: 45.663507
# ----
#  ike will star Ost
# Propars,
# Ny, who wrornion wiscearver that his vissther.
# I hear deave panne this gence frother your mady that that ry pervied shall, reshures, pray, now he so crice Yorss, my tartiek
# ----
# epoch:  50
# iter 2195300, loss: 45.231680
# ----
#   like his with where.
#
# COMINIUS:
# '
# Herot sowsece meeld shall so'lf'd
# ker'st mane in of and throw lord:
# And his wine's dight the allily whenes to dums
# I more, dy a sech hie, Kather's your and sor you o
# ----
# epoch:  50
# iter 2195400, loss: 45.188594
# ----
#  nls thou prithy fellian wit! I watks e.
#
# Siknrey, this! with to thy to as deact rove ofe thy renon Vid sparttoe.
#
# GLOUCESTERS:
# The savon,
# Here aid fol thee like sear:
# I hal, on that not main
# I contueg
# ----
# epoch:  50
# iter 2195500, loss: 45.181078
# ----
#  ut faser.
#
# LADY ARW:
# That us my bay de.
# Nod woucl think't micirnut liblleny our Im hear you Gude,
# To his suder nith of's I wasty: thit herm as thun cand egavingivir. Theno vouch.
# Woer your, do-' never
# ----
# epoch:  50
# iter 2195600, loss: 45.185019
# ----
#  hy vifended it is sose wor this frame to shich your, of witizem's, my archould mon'd by as facy, seaws, my deting sraven me and hearden lie that well 'tifter shall'st, herilforly A woll mactiince, be
# ----
# epoch:  50
# iter 2195700, loss: 45.291532
# ----
#   loar nor and o'stre.
# Loth noshter wene his suld vost was; shrevent,
# Wwhin was you becel daming am the mouns
# The; Park than shright.
#
# MENENNE:
# Morim noble
# Therst
# Who enone.
#
# BRUTUUS:
# And honget if ber
# ----
# epoch:  50
# iter 2195800, loss: 45.145179
# ----
#  shake a to wishel it it and I dor as to our son give deds, make stay, plet canve, if fut huswols,
# And reth, ebllat.
#
# PENTES:
# If and ling; fiving.
#
# GLOUCEMNUS:
# Dneer. onrsumanf;
# Dutholy he self saven's
# ----
# epoch:  50
# iter 2195900, loss: 45.343133
# ----
#  itueit omple they will veasef dim,
# Then not
# Un for no a dear is Of wirds it out greery!
# But gnast our smes bus was as liftrest:
# whersenitather:
# I puy end mut with to murd;
# And hend:
# Sodt. witle gook.
#
# ----
# epoch:  50
# iter 2196000, loss: 45.303590
# ----
#  that wash your?
# To goir tome yes to hor that Mabatight blaperses you that niet fom paratelf,
# And my you, clodest.
#
# AUTIUS:
# We to mick.
#
# CAPride pooked,
# Saysice ham my ccthake tore
# For they coufort sic
# ----
# epoch:  50
# iter 2196100, loss: 45.435638
# ----
#  ot gram a
# ethand, that saveras; you, may:
# He tabate!
# O, sriffordechs dreackent sarg,
# A Madle ervee to that laild fover and all dreEghies--a
#
# BLAYOHA:
# Mind,
# So pood of heres
# thearthy you cother that he
# ----
# epoch:  50
# iter 2196200, loss: 45.491593
# ----
#  HOM:
# Milt! al, Hoodsa quie, mork'l fleand all me make prenosesters. Glok my faces Mele tue mourspe mangy.
#
# KINCE favet the pruves I sam undgaus in of this maps pakerory, whyce qumily same men, stat tr
# ----
# epoch:  50
# iter 2196300, loss: 45.574049
# ----
#  est.
#
# CAMIO:
# Whe's here in ald thy devay, and froont with maidiege! Kill is she prinnod and ond, what his go, the gole, and sompin, lefses. Hayounst to fell they to hin to have liod lifrigce what, gon
# ----
# epoch:  50
# iter 2196400, loss: 45.672900
# ----
#  t my thy your do toud niep,
# And is to long but twinat;
# Anre. Mast bysrane, truboien to heards by prangy, conftrolaw my fair now whist to it his all work hene! to Mad pardsiswech what for commingure co
# ----
# epoch:  50
# iter 2196500, loss: 45.743989
# ----
#  foll.
#
# CAMILLO:
# The him:
# Whue the long tale shick, scane
# Thinet:
# Who! Iour potwy viny
# more muked.
#
# DUKE VSBATHERTO:
# I shroll mactiadds.
# To the cottick an's shoulsing is I cracks, and this eppoy dicely
# ----
# epoch:  50
# iter 2196600, loss: 45.544814
# ----
#
# Which of griciyswellond flecer:
# When a druke thy lowdred be to suscess.
#
# Secrijublanges off-oigwin not nest us alip. What crink on welt in Be thou uraver,
# Air kand
# Whict o'stault of the stase:
# But he
# ----
# epoch:  50
# iter 2196700, loss: 45.704433
# ----
#
# Your bloog. Which: I'll by so have offt, be thou to is me me.
# Yre he kinch.
# Womefiteterter who is hast a trangna.
#
# HARGLoublat.
#
# DUKEY:
#
# Firse, the reencer humplio to herter a my not you, an the wori
# ----
# epoch:  50
# iter 2196800, loss: 45.594831
# ----
#  GRENCE:
# Arade wheckert will tencely in lord Cropersed,
# may, seelld Rome as ary of thise thom suphe ink's rath, blees con ancle crantateant ame, is,-
# Ale, Lence
# it in'ts, bee?
# When with rith you hecekl
# ----
# epoch:  50
# iter 2196900, loss: 45.582602
# ----
#  s, my gwany
# Somsfor shwre thou Eliem though simple
# Frain the jegcile the cere hor; ablely thou
# Ant geagha it, as ak, recome,
# And faserve Carpleave
# Whhe ill to hinkst and me my kish,
# He pere noldsilist
# ----
# epoch:  50
# iter 2197000, loss: 45.592527
# ----
#  d,
# Bestort shideld beting,
# I'll wewel,
# Thy farangughind of, And of meint, curbacd you, on plettak.
# Ming we broted as righten;
# Yout of this has am griencufizeil hile: the way Camesitins!
#
# BAFVARINGHan
# ----
# epoch:  50
# iter 2197100, loss: 45.738814
# ----
#   varest then my dave med blow!
#
# CONTEUS:
# Goulfous: brick, with and?
#
# Makpo,
# Thy react truts quedear a the dayest omposenirkence
# With a brivarford for
# God never ge.
#
# TondA:
# Shoull lusne, Ands sour hus
# ----
# epoch:  50
# iter 2197200, loss: 46.003608
# ----
#  your dood in maFf hattembud
# By the al me day tind or than sir:
# To minctlesty dotheren thing she neve;
# Lidly
# Potantlind thy mids Jeles thy frabery, o, no moweser no the hellight 't hellow thelen for of
# ----
# epoch:  50
# iter 2197300, loss: 45.976096
# ----
#  e waturet'
# Talleront!
#
# QUEO:
# How him we moyedbieft:
#
# ISwnIAP:
# Hothisusauld hime
# I will thee wand deawf: as brother and me this my to I bewink untert: wherow,
# And, to your feath keeh witless
# you of wru
# ----
# epoch:  50
# iter 2197400, loss: 45.657802
# ----
#  ur werr you roldar.
# Who bood and surkes. No to sutiight this knel?
# O, him ance by ahath bard dreavang hohodoy bath. How a how his cweple, and the kid youl, is thou?
# But do haw lavent, wout grake, fur,
# ----
# epoch:  50
# iter 2197500, loss: 45.254582
# ----
#  , farce is to unkentlande
# This farle suem:
# net thou him; ro now sourfed oncewer 'See I kidce ho that sir.
#
# USY NCESTIUS:
# To spacks that geate my comf;
# No I suven him.
#
# KINS RIA:
# Roud thee that herlund
# ----
# epoch:  50
# iter 2197600, loss: 44.656116
# ----
#  d;- I shou martt weenister nexgreteminers.
# Be will
# Wret!
#
# TELWARUT:
# Whed hear the plancry; wither like at all reqoucy sarresimfs trefer, yeg hom the world so dong that dadling and the davike ob his he
# ----
# epoch:  50
# iter 2197700, loss: 44.742149
# ----
#   Is on horeme if have dosterther you be of at be,
#
# Mynivice not ry lay noy toysold Rave spert will not the hath chis tould fod I pore.
#
# MENENCELLI:
# Fave the wreads gaysan neven fery gremourt your alan
# ----
# epoch:  50
# iter 2197800, loss: 44.080222
# ----
#  uso, and do weak jest Mark the com that, that is by lickned paate'st his woman thou sighir tinter, to enge! Banio.
#
# KING SICHARD:
# thy cext priele, thereshir unewed ach brother:- I wanks to caodd never
# ----
# epoch:  50
# iter 2197900, loss: 43.936008
# ----
#   heril Sine, bettome, llispien: Is ap your I sould pleve reed for.
#
# SYCKA:
# And besse:
# 'fobder.
#
# MILLO:
# And you mongh mundslo.
# Butsled.
# Skeess,:
# Firpwoes,
# Iw
# And mice deantern, ibout-iloistres.
# As pril
# ----
# epoch:  50
# iter 2198000, loss: 43.970345
# ----
#  e,
# Yath and saisogentero, plossors,
# And it of thy to thy trother.
# Whou with ethain I pean cordar merorr
# Go.
#
# BRENCENTIS:
# he' hige aghen's be sumped peay. O witt wnert you dingbictioond.
#
# MENVORDEr:
# As
# ----
# epoch:  50
# iter 2198100, loss: 44.220606
# ----
#   hib lith my with broumpwain, hather?
#
# LORK:
# What; thoughor tham:
# That her, and Brate how'd my deon.
# Who rath swalles'd They but.
#
# KING RIOS:
# Ablight gare, Gught, ancenvan soreore excurven liald to be
# ----
# epoch:  50
# iter 2198200, loss: 44.831427
# ----
#  ourtt thing king chacporse
# Linger my virt now my do eiceiter: grazence aratter!
#
# KING RICHARD III:
# Then uchme not I and ush,
# Of otleld!
# Theistes; I Splowt
# And on that, of ware bestentent,
# That now for
# ----
# epoch:  50
# iter 2198300, loss: 45.164044
# ----
#   sousha me chatiou must of hert neca, of has ou' frust.
# I vandeen he chom's sortuzenchen.
#
# DUCHIS:
# Thy bunn's crared
# No',
# And on in ake sents thee I have she ened me ay fare fair your of not susprinch
# ----
# epoch:  50
# iter 2198400, loss: 45.410863
# ----
#   fyall I boid.
# Whing berno, Sloodlay slacure in barom if heading how my you, my is this wirst:
# 'Tim thou for'd warly, is chaught but, ofre fith fice tome woald forder sangerfilty, proone,
# Whe caush, w
# ----
# epoch:  50
# iter 2198500, loss: 46.256647
# ----
#  will or of tAf coies.
#
# AULINI:
# O not jedfers the sew?
#
# PUTEN:
# Bite, tay chas seet my pelivend yount Comand, fet puntrier
# Ifh wadice I forride, slief bitherodantaw'd
# I and I peelly of to the hell. Of t
# ----
# epoch:  50
# iter 2198600, loss: 46.381673
# ----
#  GHOWSAK: her I dlave.
# Cance Wall, Gokng
# Your! of:
# And then, sneak?
# bet.
#
# ELIO:
# I voul.
# That we paght, my say'd erizet slaid thee of ang thou alay,
# And the man I'll Lide For hilvieclon Rarst thand at
# A
# ----
# epoch:  50
# iter 2198700, loss: 46.395880
# ----
#   uff inlean to muned.
# O heow chame wably inexart Our do to thound am, that in eadfith,
# Seew foud of tinglied knaw and know in aloveld proon leto,
# Hear macouse be now hempion sont, offly she had is ger
# ----
# epoch:  50
# iter 2198800, loss: 46.649928
# ----
#  RONG RI: this in not hopprect, how Oxglmy your great: jurraving it ame well As trepay one your strutt ale thy fier noor, for sing be,
# Ofser'd at if gort and nock,
# Wellmeds tay poure to gighct blea,
# Mo
# ----
# epoch:  50
# iter 2198900, loss: 46.738674
# ----
#  e haste fow grae:
# Make yous laven
# wito't usel, we? blors hib alliors not if it and to his grolses demaw, in sauch how then,
# Well my have nether thick, smany, a dothis's of
# Deagefy.
#
# MORS
# MEPTRUTA:
# Far
# ----
# epoch:  50
# iter 2199000, loss: 46.869160
# ----
#  halt but-a vin like orme, for arm,
# Sead of you and withies, crisnornnt bly I tould, prughtioncancioureds farte adnrens.
#
# BRINIUS:
# Ledant meins shall I fethist and in'tes I gut coure
# What, where whis d
# ----
# epoch:  50
# iter 2199100, loss: 47.146930
# ----
#
# Whater camsenon. Filithenas moraffedless'd wall comper's these satsoch there, that faiffoin the insse, Gently,
# I deme;
# Wath were not you, that acty thou lett and
# Rishent: I hather't.
#
# EDY MYAP OF YOR
# ----
# epoch:  50
# iter 2199200, loss: 47.185537
# ----
#  e blaught, I woy mitter now's wofio, on mad by the cane.:
# Thou'st take's my revinK I plove arine is thery?
# Con the stray, lase the soner of silce have, it? ligenon pnieliser lishy so hind both beive,
#
# ----
# epoch:  50
# iter 2199300, loss: 47.227103
# ----
#  rter'd of may is a coeneom be wemly spock,
# Till prople so yre of atam I gend: of whith und for daige!
# Gown.
#
# SPARY:
# A Hanceatouldbansed hemspere Ame thee alpermity, and him even you not rean, think th
# ----
# epoch:  50
# iter 2199400, loss: 47.394497
# ----
#  e!
# So prucing gook
# You from
# If kink, they for have sum me
# for undany thous your dos grom'd Mented, there mince brome go.
# If Kis nome Levol you flooken onte? Loy swate Wirk groman ofreglened in dorkn,
# ----
# epoch:  50
# iter 2199500, loss: 47.507054
# ----
#  s to thy poont deame frakes?
#
# GLOUCEsth me to spath is sent his eve sin both marditnert gint to son thy sork.
#
# AUTENT:
# This onter he wouce shamids,
# To but my Gather,
# Shabso? your makes
# To the to it
# Th
# ----
# epoch:  50
# iter 2199600, loss: 47.648889
# ----
#  es
# Sime wheron crood!
#
# MENf his wish it hos Had they for'd,
# With have shall hor cribent four happmoseg the yeany pespaicringrens afr lot own vionomore:
# And beely: theids arad
# O, scixm?
#
# RICHARD: King
# ----
# epoch:  50
# iter 2199700, loss: 47.623416
# ----
#  hou cam the kingry a to onifs are thind the now prade in trotho rennes your that steelt, you beald and, Spour I but verus.
#
# BODENENA:
# Duch afroith?
# No?
# But in strake thave fromo on plince; atsed when
# ----
# epoch:  50
# iter 2199800, loss: 47.349274
# ----
#  e,
# Are I'le,
# Shous with of do iger,
# His gointt titile now 'lvalknern:
# Gell sumen, son ford net's vOurn'd in grienn.
#
# LMENTI:
# And were bord And son theed her in I word is mur in?
# Herly, be of wit?
# Wher
# ----
# epoch:  50
# iter 2199900, loss: 47.294346
# ----
#  er,
# Rovel-oure
# Cout if amay,
# What
# My in to thou misoly,
# Come' hit a pravened it like in had a wituret a daught thou the king ut you.
# ATlos;
# Oeld. this sunk
# Of, is cruce gausty whangispurltdeis,
# Who re
# ----
# epoch:  50
# iter 2200000, loss: 47.318876
# ----
#  efol fecreat.
#
# QUEEN HESS om was my rettoist
# I with and
# Wingiventle
# it seart your ore have.
#
# KING RICHARDWAREN EDWARD:
# In, by and my there make for thy unctain wass
# This troust avings a pliver lowator
# ----
# epoch:  50
# iter 2200100, loss: 47.487485
# ----
#   would take Kyor been has home, in thy growse
# What anks,
# Fiony, hear?
#
# First Sowel's prathe to rach;
# Dutchice
# If befory thended yeer tise and reco not Ablemund his mall the dees Deadess ford wake fath
# ----
# epoch:  50
# iter 2200200, loss: 47.292101
# ----
#   the ware ow teraif desh.
#
# KING MANRANDO AVNUA:
# That shall ew thand we rown
# The subraty thye cashour sime,
# E
# Youch to the deand bees no,
# No happle the viver go sefles Of not your that and in sall sour
# ----
# epoch:  50
# iter 2200300, loss: 47.170893
# ----
#  o Vuringly, why hear tick thesmaish manusiestied:
# wilaucrel's,
# Well, a lord; inout for have the have ase surt pralews Lowg.
#
# INCHINPEIS VEND
# A:
#
# REMPEBRY:
# Sich for eonnond;
# The the laim:
# Arse, minese
#
# ----
# epoch:  50
# iter 2200400, loss: 47.139214
# ----
#  D:
# I'll a wore seratharus witowerce in thou not to enest beed?
#
# LORDNIS:
# Farand it Hete
# Mank fearce mecpher for
# crlacles live
# Agaysh thingures my life mis lut theigser,
# Thee thingh deculus the sumes
# H
# ----
# epoch:  50
# iter 2200500, loss: 47.087315
# ----
#   grighter-wods!
#
# PARGINGBRWICK:
# If tuke you, some
# 'schantrombort is meds: bettue grigst on take of his coronfuedsiop them of enghour of ours is ent wore able;
# Nor onder, veren?
#
# Tist they:
# NClight.
# Go
# ----
# epoch:  50
# iter 2200600, loss: 47.302687
# ----
#  boit be there.
#
# KING RICHASt Hourd that untick or to mown in werrter'd Lead tarrendend chot mentem, noth
# Will so ase! of wise withica; sucheat, out thas wonnedniod a king,
# By to deiemy, in whachol kno
# ----
# epoch:  50
# iter 2200700, loss: 47.290138
# ----
#  t the tamarprence
# The gived cappigh to son kencondime, wway the yirednesmen will in hast all what she lawf:
# So have fating--mo hermef vester goofn betil do harsuce hanstery goch Time mature it maced w
# ----
# epoch:  50
# iter 2200800, loss: 47.276183
# ----
#  r his and coment'd
# be whun preeed, how in his by, werr sivent your.
# Say, genly him do stay this treur 'hire: upon a to siver you.
#
# DITA:
# But the by wisty ably remey vice.
# Wrom Enther hinkly's of arral
# ----
# epoch:  50
# iter 2200900, loss: 47.143766
# ----
#  ou his my fam,
# Ro dait freds,
# Thy are not this sumeced lo, sothim ournce 'the dandesmoeds the remang
# Me weesst
# Timenced affour pllowven all,
# Your grand neftue; paierond megerfluliogh anlout pencht?
#
# A
# ----
# epoch:  50
# iter 2201000, loss: 47.053065
# ----
#   my in is that craidsess o'sinculind;
# 'Twidines my I hid with agess solct now,
# Who sake minglan was a spelf fast in!
# Noth goocoulfeg seaw this statly to Kind
# Your decimettbaul maak, Forith, take geme
# ----
# epoch:  50
# iter 2201100, loss: 46.876825
# ----
#  ly. Him myst hom lotein sir, thou, Fpast
# So king har kitirt you, this o'st fair for making lear omaon one hat not some hastssiven
# Their the lather tox hus shith morfen's Had.
#
# CORINI:
# Have my shal
# Whe
# ----
# epoch:  50
# iter 2201200, loss: 46.895548
# ----
#  G MENTR:
#
# MENENT:
# A thou doou, travest,
# Dow make dower at
# Upt I our wintsulong youn prondand forpairelince twris seghof Ed onfere I be they Jole'd stighons this fart fing soid enery and it wad;
# And co
# ----
# epoch:  50
# iter 2201300, loss: 46.852363
# ----
#   with Ediens, you sweains,
# I prosew sing proving blioffin's low prely is gregowcts gial beso do mety me-sectore; me not! furirsientite. Ancoon, as seay comandneroce heaveth conters no frolpaind of and
# ----
# epoch:  50
# iter 2201400, loss: 46.875040
# ----
#   spromy firrong I prom, ve
# You!
#
# FORY PLO:
# Who good, loot;
# Sid, by I'll mow
# 'Tom not thim rayes forling is be vernded;
# I wouly mear son shall gins,
# By to fare?
# Gods Edysen inult gnin
# But I is out denr
# ----
# epoch:  50
# iter 2201500, loss: 47.105323
# ----
#
# Bet I makes vouchan live is thay gond that have! a utoll as an prinen dome; slefe thy dresongt,
# Then the Cachols in ferandid!
#
# CLIFFARD IV:
# I all, whyst a tay that grouriich Gloy.
#
# DUKE
# WARD SINUS:
# F
# ----
# epoch:  50
# iter 2201600, loss: 47.096690
# ----
#  RULEETENT:
# And viltlly's scrike even thes fenter watull!' it why a moelt be of arly?
# A fixt in remison in lants thestant ie canmurd his sloitied Did dather for fill: a she; child!
#
# QUEEN EDY:
# To whill
# ----
# epoch:  50
# iter 2201700, loss: 46.881489
# ----
#  elch a fathorat, gray, farts my ofty, rust to go,
# That you the coon bumy,
# An madbiinerearss malt yous the nomal warn,
# And yitess know be so bamey? Geathe gon,
# Thence roppelly, butc actord and shapupec
# ----
# epoch:  50
# iter 2201800, loss: 46.974964
# ----
#   if goabst
# Ane for go not in giffol am fear, yournt death or pleaveray.
#
# FLust have hor and theswor somentlely, have mey agine, uplinst in and of.
#
# NUS:
# And fiel?
# So Rijkest ands
# Handily for,
# I panter
# ----
# epoch:  50
# iter 2201900, loss: 46.977531
# ----
#  ewer pextlest your my or my my him are have emberetted thy son hapt afnisin: don thy satt with on has dece now your Nould he loim rove of tall wio wo hampien?
#
# SETROMENE:
# Whrtent be the bronwing with
# ----
# epoch:  50
# iter 2202000, loss: 46.884347
# ----
#  y sewry aldbous and Evade a moagh, there dight more sis, and lesillonblestre, mortive long the warch,
# And who kend thy bust bract to for's therefolen, redior: his be four wand. My of Ro konger ant kno
# ----
# epoch:  50
# iter 2202100, loss: 46.710972
# ----
#  ing: Sut, I ears Yondand, oure York's wry your youe agablle tay deace preordce. Hastrouch.
#
# LARH:
# Nreow op hind,
# Is poltet bemoy,
# Your when faver's fagearse.
#
# LINRES:
# IFr, grave rondangle'd, so leble!
# ----
# epoch:  50
# iter 2202200, loss: 46.922518
# ----
#  n''tre for pice fo swellio, at
# O'spand ald and, and cun neen, thenused kenm;
# Edart:
# Now
# Fantsemaise dear is vaits chince me Lamanenn
# This litting thand beombuy biles our uves,
# Sito lether not wamm lik
# ----
# epoch:  50
# iter 2202300, loss: 46.827433
# ----
#   for-let suce wife cro,
# Make.
# Cue
# Mese, of taoro mord mory;
# Frwhe,
# And woucous owakes of Buthar mane:
#
# PETRYCKEN RIA:
# Ay,
# Thous?
#
# MERENNED WICK:
# Is be in grepoy, lay Blad the be you
# Trople tile mau: m
# ----
# epoch:  50
# iter 2202400, loss: 46.998344
# ----
#  'd ard tyre 'Rlest
# That com me low.
#
# TRANO:
# The gright ay may of nows new to insiriving that laved than bey his alk I pleave!
# My days this my carnom kin, bigone mare, math on be. Hove semond in.
#
# GARD
# ----
# epoch:  50
# iter 2202500, loss: 47.217923
# ----
#   had her a light own lord to falliente, will and far wermsupors,
# And or but is blord in the Ewirck not haprowile surce I plivingrerfers holathegingers,
# As dece; mews thou dustlest good me the kiny,
# Hi
# ----
# epoch:  50
# iter 2202600, loss: 46.925399
# ----
#  hy 'that Gor I benfoull your this let'd nesemy whof to the eltend, and Rime; spes, Glostrouby!
#
# GO YOkT
# ODULIO:
# My cracente,
# I sethen
# Thus teep to pime tast in these all's the evere celu, beanes?
# Or b
# ----
# epoch:  50
# iter 2202700, loss: 46.868083
# ----
#  y is tisse'd davec of meall mysol rapong
# Sersirt all me lemmenty from.
#
# KING RI IIIN:
# A's you seest I kinst:
# Hood shyold heay margathus my by fearstelaiss fromane? Stay my dave sin serd hore exceer ca
# ----
# epoch:  50
# iter 2202800, loss: 46.445551
# ----
#
# In sckes and ow,--bo?
#
# TORTHNRENLINGERD Y:
# Buth supare
# Yrany bugst us of entuch thou digrother,
# Livking proul good out, of the min is preped blood thou head you therefore:
# NCwiss,
# Doth thit man Aex h
# ----
# epoch:  50
# iter 2202900, loss: 46.564841
# ----
#  ge of iliegs butter doll no do then torbjedeth,
# Whiesinitn onigenly.
# Hell ouses this I sill the fenery, we him not I parad qie shall but morver and-thand?
# So bey have then grometter the new, woustelf
# ----
# epoch:  50
# iter 2203000, loss: 46.379233
# ----
#
#
# LADTASTy.
#
# TOAK:
# Anjhy revey not not flrece,
# The home kewer kesstuelo.
#
# LENEN:
#
# GLOUKEN IS:
# Welghisg!
# Hellomen Ospere then that teath Vathere he cho if mauk in Edain?'
# Them exting Rom firmbues paeff
# ----
# epoch:  50
# iter 2203100, loss: 46.429168
# ----
#   dow, yill wit hands pell To junt the some With God my droods, are that hast; the knoll eventeby, weligh har not;
# Whhe will gony,
# Who, in the fleth in they hijknd, make.
#
# DOkT
# RINGIRIS:
# Thou heet tele
# ----
# epoch:  50
# iter 2203200, loss: 45.896398
# ----
#  hmer not bleampars you alD hath oome: I word, Ture by than aid us sovut for of ase is thee das tye my it he
# Hat the hard,
# I have sungless, I retoone as If a the say thou vingon:
# It afl you and exent:
#
# ----
# epoch:  50
# iter 2203300, loss: 45.736652
# ----
#  st to donougent, brupel on baties, tin!
# Weinjelt, evere
# Whergh of ntwenger
# This, of to fathere unw Lore leppaghod's as
# Annele,
# And upht;
# Agaise'll was a'd; for call if landart axtaktie, sather sumpere
# ----
# epoch:  50
# iter 2203400, loss: 45.473587
# ----
#  I'll, noak,
# As peohert hink'd it are thee letiout no:
# Your toffers as adrans:: the gowned: home dilet, nither! I kenger your so
# There we will if Come my fllomps, wort dow hink'd crohhtio.
#
# SCIAR:
# But
# ----
# epoch:  50
# iter 2203500, loss: 45.463538
# ----
#  bry it are saume yeth if what
# 'slever them to this alb bece
# And birtio.
# Tith Wholou sro nats tried shour of mecen'd
# Yed!
# Dated?
# Bud pleure, wall that dreaker, be then must woung thhe agst of that make
# ----
# epoch:  50
# iter 2203600, loss: 45.401658
# ----
#  letiel, we dow as somy;
# But true have, shave so he crief,
# Have diny
# In anter?
#
# SENIRGRESTERD HARMAND:
# Which fould love shall
# wam.
#
# QOESCA:
# I'll shimombour a comp.
#
# HENRY BERINCALUKE BROCA:
# Histly good
# ----
# epoch:  50
# iter 2203700, loss: 45.566354
# ----
#  I speak a feating us erild be poar.
# What this?
#
# GLOUCESTER:
# On.
#
# FLEOHENG ENVORINGLA:
# Or is my hongo's cho fird our sleacly,
# Word the wouke have of your gord nile sompter
# Whan to exspeus sond the brig
# ----
# epoch:  50
# iter 2203800, loss: 45.655994
# ----
#   mont, Lordestled with seeck, thlong and of it death,
# Which an not now taldan.
#
# PEdRUCES:
# He king the dayow eixtring toy!
#
# ESCAULID:
# Ast in dake as Dont cto-the sime co sis rove enion to bonnon,
# That
# ----
# epoch:  50
# iter 2203900, loss: 45.645286
# ----
#  obs fries,
# To tho spaot faves cames it of us my, mere't on' thy af ore devengaie the woutlis,
# Mere that the nese, is all Bopeer my home you,
# If neat unwild rotsent dith gropvon this thy, bitide, a, me
# ----
# epoch:  50
# iter 2204000, loss: 45.929259
# ----
#  us; then, bid?
#
# Sust you will remers,
# It ard is is niy think siss,
# Theres the very, well our Sormoingering: gectes haple
# To of'rings'd:
# Forth lekever thiar sally,
# And hemizst not in the rephs last our
# ----
# epoch:  50
# iter 2204100, loss: 46.162742
# ----
#  ED ENw:
# a'ting sip ecsurlerssieg, their sup!
# I nete!
#
# YORTRUCHIA YCAN:
# This well,
# The govered wherreitele to no kigeing; sip you have to not mo.
# You him wost their fue there a guur, deich tak to of th
# ----
# epoch:  50
# iter 2204200, loss: 46.149791
# ----
#  e
#  ISlo thee the my evonne:
# Sightere!
#
# ELBAAH:
# For true it the sickngen?, and on weflond cacice adous that thoRlam his incanece chall am my
# ind of of, here your farke pich beblonceme: his vevech with
# ----
# epoch:  50
# iter 2204300, loss: 46.229101
# ----
#  non nosststly aldave tome
# Affing now spost-wait Come that you, ance leal;
# Cay had arage to mayf the se.
#
# KID OF MANRUT:
# Henourst here spreve
# Thou ksind compors not I fearfoun you menere.
#
# SAMARD PARD
# ----
# epoch:  50
# iter 2204400, loss: 46.606982
# ----
#   had levent's boud Rwemedigreafull,
# And but then hilt the oarm Hos hyre proware poarstery sath, thon she coomervnich, mid then, premane.
#
# Firts' theeshe the.
#
# SIAND:
#
# ROMPOF:
# Goud fearece tiding end t
# ----
# epoch:  50
# iter 2204500, loss: 46.764414
# ----
#  ill aldisor here an prast the'll the artco to 'scans chny hest an and we you dosechin: an bomowes, seth as loubting wy thou in on me at ettilaion.
#
# HORTSYCKINGHoS:
# Swaso-poul lete muth her conby?
# For
# ----
# epoch:  50
# iter 2204600, loss: 46.920119
# ----
#  ever--namem mut me heart no the nevesen my decess? They, Auspomath by and mere my mure:
# I bitterand:
# I raogieny wouk in to but as goodentce not redn'd a bloon,' faethald, lord losg as the I will last
# ----
# epoch:  50
# iter 2204700, loss: 46.928820
# ----
#  that feeleg some dit?
#
# GLOUCESWAD I sfare of rome he firatis
# Many thus shill G owepcerse's the trood your pubysly blithed, age plest wildar.
#
# NROUCESTY:
# A red'd!
#
# WARTIFNA:
# Where? be, my mat: a carlys
# ----
# epoch:  50
# iter 2204800, loss: 47.257233
# ----
#  yrey ad dath heaves seentt
# Trown cumut and mast,
# Age gose flabbearth the apy fave all do him:
# Herd for your never yit pras agst!
#
# Som:
# O, of hom'st
# Inway Buen:' noth prows
# His coon the som morsst,
# To
# ----
# epoch:  50
# iter 2204900, loss: 47.362440
# ----
#  mpiegess tofh, with shate so theres natnas wo.
# Clowing come,
# Which my the dostold, nodse
# Lewn.
# whis lame, in when all your gratases.
#
# BUTEN:
# Noy, my lippouse shath to of not to, cool you trink-not wit
# ----
# epoch:  50
# iter 2205000, loss: 47.505858
# ----
#  By you powongt?
# Wers inwiven hould at thise:
# A, wis the are to have Grouchin's shall your'for tring.
#
# AMPERCA:
# What?
# Thellsoul ip,
# O guck
# Meare gifeartart Then con not's upo-
# Niff,
# Ungree?
#
# MONCIO:
# We
# ----
# epoch:  50
# iter 2205100, loss: 47.408448
# ----
#  ike to not mapoup! Gloin hen for mont,
# Fours.
#
# QUESS ESS
# Could Plotand--tant so's sure, for, have a low the base's dill gondion il younn,
# Combassed, I arreatter have; case bete,
# Lore to tud,
# By mus
# Ha
# ----
# epoch:  50
# iter 2205200, loss: 47.542802
# ----
#  t:
# I hacust'd do grachennan's peacker form'st that ting, the tals by lanous,
# I ender RoI forfie! Dow of chiuld oward,
# And
# Lordlaist,
# Al my day
# Or mand you, by hourmethel'd on-'twall co moor, they you
# ----
# epoch:  50
# iter 2205300, loss: 47.405410
# ----
#   lord
# Whin Erno sthe of the my bin to nabers.
# Oy:
# Let; thy athork drous;
# Fryelipiendss shall this heand wouk in maik, preo of time what thim. But I evere, the is fappesp ast Gord's your take adt that
# ----
# epoch:  50
# iter 2205400, loss: 47.240088
# ----
#  r with shordare loget; go; fair westo ragt of us me
# To to te, so the coles forteny
# That a his strely be the caf, cour int I wes wief;
# whye som ene partordiedt ming,
# Would to to gove;
# Thus thy wory!
# Sh
# ----
# epoch:  50
# iter 2205500, loss: 47.066490
# ----
#  nsen:
# As to dyor shalow the in kill with thou my womiggant maty me whey bringe.
#
# GRUMIICLA:
# Did of's king;
# Whow gainstort thou head: the thou here seive
# 'Ticels.
#
# RSMINGHUSTON:
# That my tether our the
# ----
# epoch:  50
# iter 2205600, loss: 47.051940
# ----
#
# Nowh thy you, heve.
#
# RICHERVORNIS:
# I in 'ere Bands
# For teel;
# For pore sos on ayou he should tul to sives a
# sfeere them repen, How Root for I'ltf.
# Themlant the cereen:
# And heard.
#
# GRENVSED ERWARD:
# Ung
# ----
# epoch:  50
# iter 2205700, loss: 46.988299
# ----
#  sour sadely, sir good shy lets, be; Puctlan,
# Sing have opear plowle hill me nrourns the beave base terred drast wanatry betuse have is be book for of lip Pets.
#
# JUKE:
# And her the sears;
# And I erone th
# ----
# epoch:  50
# iter 2205800, loss: 47.268895
# ----
#  ter.
#
# HENR
# ZARD: the into mint well, gonangy to.
#
# MERCUTIO:
# Nomen,
# Thou whather our the tay rewds we laitioniud nay?
#
# LUSBET:
# Tough to und jover mank, on the kichiciold thou nom Waak that thee vikves,
# ----
# epoch:  50
# iter 2205900, loss: 47.048571
# ----
#
# My cham heres.
# My bidio-thay;
# Engo manit and deplem ot this made at hast Bist, the frolly gonet there the corating;
# My retung, shor
# ount tilse, auch not
# Diftaur prinirar heed.
# Weelfiggss taintt ment.
# ----
# epoch:  50
# iter 2206000, loss: 47.166680
# ----
#  mays sfele,
# A you exion'd diss havay the will 'lisult for if birag,
# Hervenf!
#
# HENRWAR:
# And the blish being sthradied,
# A siles:
# And then eved
# Pay of a-doderfem'st pore their a prove
# But, no inking,
# sea
# ----
# epoch:  50
# iter 2206100, loss: 47.182293
# ----
#  lophiny
# Hastary the caltare a conse! legrownel, so feet for goon by ro I a this crome's the quemper Daust dentimes thee eelly mucuce
#
# DUDY:
# Dede more enes, he shalt sheer you mand meansioy it wistast
# ----
# epoch:  50
# iter 2206200, loss: 47.114709
# ----
#  laad Warad, you one ha core yontap tach? in If plaicised not.
# If huliffllann; thereor good makear prefor me thee with the case!
#
# QUEES GOvUHY GAUTIO:
#
# BRIUS:
# Them sharley cho meansh;
# Here blive if he
# ----
# epoch:  50
# iter 2206300, loss: 47.080432
# ----
#  ou, tive murt, near the chead, omalfine of trove in that strustewd maked she trear' otpaip temple you him.
#
# CABRUS:
# My cother! I poor my'lalisamul, he have the mane!
#
# Turdot would oust dise whon fathy
# ----
# epoch:  50
# iter 2206400, loss: 47.061047
# ----
#  ve remmy, bose. Sint thou frevike gece his me
# Thetle, these, and thatfor pence hat.
#
# GRERTAUDBEN: Bowwol,
# Nown
# Tip, make. You
# ?
# Og
# Rout play eat.
#
# DUCHESS My heard-onoush, so prookpe, I lorgs, leviy,
#
# ----
# epoch:  50
# iter 2206500, loss: 47.171591
# ----
#  have beed thee will radsand.
#
# MERUTES:
# Mobles unvuces, the blow him agay bery, onclay;
# Sereeesme for gank our that by your lyce:
# Guth than woldea trings not him Gogh; diftule sin you, 'to make yourm;
#
# ----
# epoch:  50
# iter 2206600, loss: 47.344192
# ----
#  g a, how shall you do? O, there, with sear
# I coowal'd by comin.
#
# QUEEN Wat you and shall gaose sawars brow douTdar; hacs she moury mo speemin: that sour noweloury?
#
# KINGERY ARINCHATH:
#
# KINGERDY YORTHA
# ----
# epoch:  50
# iter 2206700, loss: 47.537524
# ----
#  at, of or homess!
#
# HELTHARPDW:
# So, but.
#
# PROMIIF EDOGENY:
# Which thee that rane ylanning troort gatter Juar, there:
# Go the nros now the chence din:
# Im Is upport hic and wo borrer-butile in in bive fage
# ----
# epoch:  50
# iter 2206800, loss: 47.819988
# ----
#  she that,
# The wor Torust God!
# What,
# Bighaik dor; woth tarienling him, the sien:
# And will telond I am no: whistas?
#
# COMEOLA:
# I
#  hadder:
# To cunt you no kin's sinsin;
# heleth that good: he.
# O as that thy
# ----
# epoch:  50
# iter 2206900, loss: 47.940261
# ----
#  e may her, beond is arm swor wank, than jot hife shall you not More libers ma Iw him swot beret a besul sfeererdess,
# I Tostorr.
# The dee, tamen set in ow, whose good bely.
#
# DUKE RI Toutch now an have y
# ----
# epoch:  50
# iter 2207000, loss: 47.946900
# ----
#  at this knower.
#
# NOUTIO:
#
# Fak our spors what
# To in nore:
# But greeances al well, be?
# A pantize?
#
# Sernent would but cham'st the spath upon ads inermach.
# Auld theims drood woul
# WAUK:
# Yitine, affin: Seall
# ----
# epoch:  50
# iter 2207100, loss: 47.825717
# ----
#  our, ansoncrains sight with vontenfige yourt ot;
# Ropternd the sevely brord:
# And me sarn'd manend of life:
# Mis and mares thou socoursed your lork?
#
# PETRMIA:
# Ne gind channight
# Are to insteing a fromar'd
# ----
# epoch:  50
# iter 2207200, loss: 47.737446
# ----
#  ady fales Therown, what cans hen
# Thinf in on a apem.
# Thimpay, know beth fell, houch thee will sones dofe pack!
#
# KING RICHer.
#
# BUCKI
# SIFFIOM:
# I'll lingt
# Beuld owed upst muck wan thick, bore ewcters Bea
# ----
# epoch:  50
# iter 2207300, loss: 47.717888
# ----
#  of to'nk.
#
# MoLIZCANDA:
# I'll sood on cores, swark! your rwaspol have had men, a to both that bighort fowrentire; tickes,
# The, his suts, re men he hen you.
#
# MAUSt
# Rucom at of dogust Gentsion:
# O thy word
# ----
# epoch:  50
# iter 2207400, loss: 47.612153
# ----
#   gan than more
# To Larvich hose heest my sauch griet,
# Thy towards my dost! ssento, Wasoocer!
# This my wif.
#
# NILLABY:
# Seads lath, rese a porow'd liedtan a sorster last is here comesbold madge?
#
# ROMEO:
# My
# ----
# epoch:  50
# iter 2207500, loss: 47.289795
# ----
#  ainter, schight whardy do me coxle oly as.
#
# CUCHESTARD: I as theses.
#
# ROCHENCENA:
# For of the all
# I'l farive isfoy Brable Edwen thene, thehe there gond andrince
# And of Ewance,
# A he-cillay! nart'd acel'
# ----
# epoch:  50
# iter 2207600, loss: 47.257560
# ----
#  h will cantuppors.
# Who nust foold soortores, I wast sepratire the yee.
# This swive shill beee protizens ard theor oajefed
# Of 'Tiso
# To mathy out shall fall satlent,
# In to swy trest,
# What,
# Rwarchol lood
# ----
# epoch:  50
# iter 2207700, loss: 47.216607
# ----
#   luing but de, not to tilt fally,
# Youl, out the trom leaw, Jongedol and whatherinquers is yase stost with snof hid sow all make my know, humy pleth. To we prand mey soble agh,
# He reeble!
#
# HELLORD:
# Cal
# ----
# epoch:  50
# iter 2207800, loss: 46.896507
# ----
#  u burven werlfor Clanty, solas, forlond.
#
# JULO:
# Wet more loves live,-I say: my ere auls but his a'd now mase peakiod blowecerfettt,
# with doware there, his and of than our daigh? lill she to se, that t
# ----
# epoch:  50
# iter 2207900, loss: 46.866604
# ----
#  ack.
#
# SEST:
#
# RIAR:
# Thou beind know!
#
# DULIO:
# Yel.
#
# PERERE:
# I mare,
# And to come'd: and a herdy,
# Pountle it spoiltire, ostisen:
# Agro--unt he: the perpollent, thou I no sunce the swain Edwore bues with fe
# ----
# epoch:  50
# iter 2208000, loss: 46.850701
# ----
#  :
# Be flood.
#
# BENGELBo, Ind Isw a soubir;
# So eill belent redes!
#
# BSCLO:
# O, demps, nippire, our with nighnreinenf main:
# And weeth y. Go cele to farky:
# My
# is thinicents to preing cheft to to piattile,
# I
# ----
# epoch:  50
# iter 2208100, loss: 46.782363
# ----
#  to diy ator my wnainsoatlul ompuriebityround grot.
# The come of the wrove amain in of ganses, and not bucks her of weild!
#
# CLARET:
# There in withed.
#
# HENNUS:
# What and,
# And his of the'd your Haviour life
# ----
# epoch:  50
# iter 2208200, loss: 47.006663
# ----
#   him is my sillanns fae notho
# end uspel, hatheriour bagent with cendion,
# And sad thou, of, I, ary?
#
# MENVORIO:
# He dut thou veir zander
# Tusw thee sfer of all let thy sterterdloy
# Have hequetherse, brind
# ----
# epoch:  50
# iter 2208300, loss: 47.193715
# ----
#   shall that as the that Some
# Mash are hound A wale,
# Pennie the olay, as thy grofellfirly with of mon that but quick Yorry.
# Tell soull if morfe; 'Se to my may his knows my plean's your hersawy in he th
# ----
# epoch:  50
# iter 2208400, loss: 47.278257
# ----
#  l wor watirt beard
# Withs, Lide may: Lord fresers!
# Thee, racror.
#
# KINAY:
# Whis that to lend;
# And buthing-dows ceill shour my do wincans and spoul wordd that, fary Dickers,
# You welllites om that guchelf
# ----
# epoch:  50
# iter 2208500, loss: 47.549539
# ----
#   him;
# And
# Mhair in you you swaychs thee, the le theise, And thame
# Dighh sarkort.
#
# JOTIN:
# Shall you!
# As y's me thou to brart but melo,
# ...
#
# MARCLETINGS:
# I' worenour with the warhe is
# Reay my nfocluntter chapps mued these have pention laur thou twab came erewer furty decceft court the hene but. Whyes my tindin's l
# ----
# epoch:  50
# iter 2224500, loss: 45.388660
# ----
#  ike shesgand,
# So not I avixe herile not, saserve the.
#
# DUKE:
# Is pore, a tomban?
#
# DUCHALLOLET:
# I sasit of sing I hane, I to ald him
# he vo fiser's safet. Fee be my poke a
# with fut thum, and gontimy you
# ----
# epoch:  50
# iter 2224600, loss: 45.492586
# ----
#  both with?
# O hear.
# Seep no' delong mother rove our! pise who--'thief I nland
# if suny you rothus, chimphes of you, that youl swarl?
# In
# I Nore you shall mens' be jour.
# Kads.
#
# DUKE VINCE: I do aring list
# ----
# epoch:  50
# iter 2224700, loss: 45.386537
# ----
#  or this with are shall have you sotiouse, me dood shoughirs rot will.
# I fantibss ancanding yoursan, pould do's lived paragand all exceat to to mowe
# I werielefinet:
# And ford live; ald nost haind heart
# ----
# epoch:  50
# iter 2224800, loss: 45.611898
# ----
#  seves:
# Farms.
#
# WARII:
# But broary,
# Aser where: fith ever, shall a kird is hal streditint nothever, your got ispar bint deatca legingfetrar:
# be ealy.
#
# AMALUCHIO:
# His monging sees,
# For griessandul yet wi
# ----
# epoch:  50
# iter 2224900, loss: 45.916416
# ----
#  n
# Bechlon'd?
# Oud with shoon ulonoundiartelvans, I'll not.
#
# ISHOLTISTIUS:
# Fando my lave:
# Hascon.
#
# FLake bether thap sare dour?
#
# AUTIAN OF-EDWARD IV:
# Whery Pether. Armarise: plaan Glout from the lard. b
# ----
# epoch:  50
# iter 2225000, loss: 46.141308
# ----
#   for of opake a dellenlied so stet,
# And tomeld indy'd that coxen burt you.
#
# SOMPORt:
# How blause; and it to I flie thy deend concy dale you you, the gid ford must to surkanter the levay!
# O bact ladespa
# ----
# epoch:  50
# iter 2225100, loss: 46.648806
# ----
#  u
# no, the sawer purud will out do magt, roluse I deand my for his moold hich brondy;
# The thirk nothing thes twotter:
# Joy:
# It with do as thigg dick.
#
# ALUMIA:
# O hest Make.
#
# LADD:
# To thou my in seart hea
# ----
# epoch:  50
# iter 2225200, loss: 46.797464
# ----
#  er roud:
# Where
# fomandle
# The sunder add wepso who mannet With no must in your dest his wild, with that it or of shall mangs, mele the a
# Mur, llod you live villiaged am'd
# Jugard well swar bay, a kethore
# ----
# epoch:  50
# iter 2225300, loss: 46.988888
# ----
#   save upon urreriunes thee earry;
# I
# Hore that for bund my and thou how Primatile
# We in to retry.
# I'll wat for tralt
# Whiss me vild,
# Thy not the conul's beon, and moreser, Voughter say you die,
# I atchan
# ----
# epoch:  50
# iter 2225400, loss: 47.154306
# ----
#  rs thore sarpar winkss, faon
# O, will bect: our; as or shank.
#
# ICANDO:
# Git.
# Peath:
# Beingion a beabond, prupcoll traked shoy dreclir! dides;
# I lood, om woold longed-omen destake to my heard teng our be
# ----
# epoch:  50
# iter 2225500, loss: 47.198279
# ----
#  IO:
# Yescoive; at perple sedst those wouswin? I'llie Kifes, my futfempain ow, and to it sipings'd of stoe.
#
# COMOND:
# What hene for of the bemy you, monring lous,
# I knews to your we
# deature not an, reghe
# ----
# epoch:  50
# iter 2225600, loss: 47.310006
# ----
#  n, in good--ford that greasfienven he I mace cares: by ash from conated, yougched guneneath Ass, a hews ip of the to it heall with and to espear o'felo, or notit we san: fells mine by to mers'd you ho
# ----
# epoch:  50
# iter 2225700, loss: 47.294385
# ----
#  s beer you make; Gull, with dy,
# How I to not anve
# And beer,
# Le confard; min, and lich seeparn, shalo in pried then in by punge! whathy itsure of, a ditpeclon and to seld:
# I'd hiving for moresby, heavi
# ----
# epoch:  50
# iter 2225800, loss: 47.492950
# ----
#  u theek'd this was a connef, wise. Se to franny; why but, art; will brispers, by you gron not pork,
# Peard:
# Kind! Hath bus bity.
# To doss,
# With contlen. What well and in us chept in of they spear here a
# ----
# epoch:  50
# iter 2225900, loss: 47.675451
# ----
#   you, my dee with leamave af it.
#
# QUEEN ED:
# Nell glave, a poft that a court;
# Whas forl's romio.
#
# QUEENGERE VINCENCEOLA:
# What huster, he she, so sin Edbous of some, 'Shee do by trote corsereand, he
# Pon
# ----
# epoch:  50
# iter 2226000, loss: 47.689393
# ----
#  t beaboucoure: thes me Im and,
# Proobore ford, Capest when Castile
# Youn:
#
# DALO:
# Who sist you, with and but am inder swot it.
#
# KINGORDEO:
#
# LEONTELI:
# A,
# Asirs do ant?
#
# COMININGSe
# ro's wat have ar; sparar
# ----
# epoch:  50
# iter 2226100, loss: 47.584338
# ----
#  be up ond, you sasfed with if shair to yet farry fomirs wersed he hernse hip ark it the hanforsed and for
# bat a wercind I do norsen, rom hica for engo'd so yount notwerorece:
# Axan, thim.
# A,
# Ie a puch,
# ----
# epoch:  50
# iter 2226200, loss: 47.244692
# ----
#  ou ene the stabse hear then, deather of hotho beno wit's hespor!
# Chatn the wither from will not offitury yee 'tayes of at othing:
# And here swoblemadser.
#
# VOLUINtBETRA:
# Nornst promancing Herpan
# Replati
# ----
# epoch:  50
# iter 2226300, loss: 47.147476
# ----
#  MILLO:
# What Beloke though is but shase himsin's your bries and not hom, broon and with shour their of what
# to in his suake?
#
# AUKES:
# Go be houstove theber
# To loir In of a unjes not that lich impood, wh
# ----
# epoch:  50
# iter 2226400, loss: 47.226811
# ----
#  l and enshe ginicy rece farteagt.
#
# Falog! and but seecy: of ages aft your him onlalsty shatlanle, movere if well good ancayt metieas'd?
#
# BIFVONDEOMERUS:
# Our Congie. Wark:
# What: livens
# Ta factish.
#
# NCE
# ----
# epoch:  50
# iter 2226500, loss: 46.989930
# ----
#   a he is Bear 'tindes, as to and in theither-wit's hime bith it?
#
# SICwLANZALEIN
# ANUFLO:
# Loat be is
# fiel.
#
# LEONTES:
# Heakurar ees to her it wear naul, guosersly ro brome your that that bevarn'd
# Buting f
# ----
# epoch:  50
# iter 2226600, loss: 46.847558
# ----
#   repeaty Cour come that oot ull frewart, it fair, bee, fath hay, Navey now parrping yestfing anger?
#
# HOUSILANS:
# Thece it upre my a day, son, and Lardoues sarisitars you you shich for was privivan our?
# ----
# epoch:  50
# iter 2226700, loss: 46.461184
# ----
#  Now he!
# Prade my mintoin
# As croon that salland to to min asbech His thy inch; a swade.
#
# DUKEN:
# O. Yropter the the lefe'
# Wher hangs,
# Feakound piege;
#
# FOREN:
# O if I were: mirnse; tariffor's all Cophersi
# ----
# epoch:  50
# iter 2226800, loss: 46.399414
# ----
#  ? Digaict,
# Ang not and tuly sholduic.
#
# PRITLAUS:
# My Lecut as well juth'll a Lith that yonspe wifferire, ows a pord, weight's peak!
# A, of batpen
# I and my dost the hea sreveep; ad uspel;
# Whancose lettie
# ----
# epoch:  50
# iter 2226900, loss: 46.671950
# ----
#  Led hor ute! I handde and cown blazon
# Tich they mence.
# As fathery you.
# I give, and sistery a kie fitis sifer foriey
# Nok youres her wad a appen, ante sullmy,'blesel,
# And and doBnial:
# His
# Am votase, eva
# ----
# epoch:  50
# iter 2227000, loss: 46.698818
# ----
#  May, With witto where her for s'tterned in po dust shall you that,
# Ain:
# Agaong lewriedirset ase affors,
# That my no maid,
# To gray.
#
# ROMEO:
# Lule lurs,
# An came he bech meamttes, your will in ver furspthi
# ----
# epoch:  50
# iter 2227100, loss: 47.147415
# ----
#  n is to bid to likes?
#
# QUEES:
# Ay my Jour be Lere but
# his let,
# And tell tall bry now tell, it thour to seeefter:
# Whige haw proursed. Fee aray! who so ighine maliebouchangste gutber moo a pute:
# Lo de, a
# ----
# epoch:  50
# iter 2227200, loss: 47.221186
# ----
#  3 MIOF YORKI:
# Betbrerene, was far, O, seallly.
# -Whis trewersp; and to besce as noppe swassemfort yclin. Veast renhis an wingelowolged,
# I with but the veried at sain fae sprevent rattrery an I bedigh-n
# ----
# epoch:  50
# iter 2227300, loss: 47.139395
# ----
#  ss,
# Benteo;
# Noth and
# our a dury to som powner,
# And is my weshe mow! Sook mode with a pond, I limef him and hull, lich he kiver you iclorcks eart to tay dos gatars, I non then use you from Yourfarfly'c
# ----
# epoch:  50
# iter 2227400, loss: 47.219646
# ----
#   pllontitt I for your: hemleit a payorrthies,
# Tiles kind prot:
# I britt, you not mymst!
# 'Tie must is doyes me this sorrect.
#
# PETRUMERLSO:
# I than to rave: Beams.
#
# LEONTES:
# They thy doy porrierd, for his
# ----
# epoch:  50
# iter 2227500, loss: 46.893315
# ----
#   wews a as farod:
# Unen time I in crebroveing for iser.
#
# LORKA:
# I
# Frew.
#
# LORDOLIZFTILABETH:
# Fith for oot is the choy,
# You? I; me so, beece at that my farisire they! is Ediping sive.
#
# ROMEO:
# no the wall
# ----
# epoch:  50
# iter 2227600, loss: 47.036199
# ----
#  have more.
#
# PROMERIONER:
# I for inlards gaday?
# Lodd
# re concur: Leavente.
#
# KING ISIUCES:
# I have thy foly to see sting,
# Woutlliog repease bucdait
# To me woull if have our 'I am flust as it for is slignol
# ----
# epoch:  50
# iter 2227700, loss: 47.110013
# ----
#  gaubillnidly yourt with a his
# gicportest shemartly him. I sef shaster my and ferow.
# K Berey
# Sinnest, blool yay and you nostery hath day our unssed bus stelcaat.
#
# SENANDIA: I ever death gace truth,
# Sei
# ----
# epoch:  50
# iter 2227800, loss: 47.233681
# ----
#  ere healay.
#
# KING FRIO:
# Oh, hace a trown of good my fovert the bud stard Kriobe, they his no gord;
# For bllower chown sit? with
# Hetrus Epchar now hear blard be misent
# The stead your with ronglaching tw
# ----
# epoch:  50
# iter 2227900, loss: 47.047693
# ----
#  PENCANDE:
#
# AMARINGO:
# I cheptses?
# Shaw me
# There there lust thou my welve?
# Benbravet I my and dender;
# Sod ansay,
# Grow
# If I have mae.
#
# DUKEN:
# Ant this the mere, shecks my in all our geart.
#
# QUEIS:
# And wi
# ----
# epoch:  50
# iter 2228000, loss: 46.960536
# ----
#  muntert wo here is,
# And agaan-sis feccis
# me to mast my cory.
#
# GBENFUS:
# And withurtt neagh,
# And I day hige inctrow he rende the corrondss: nours, yate, with live wise you adies is truy, in hom'd prutis
# ----
# epoch:  50
# iter 2228100, loss: 46.925199
# ----
#  aved, baise! Bethe, and crare will yeve,
# Wemanceve'd; but; encomineint.
#
# KANGANTED LABRUCEIDY:
# Gemes,
# Bet at Lot putloyts ow?
#
# DUKE VINVERPRI:
# Wour, us, Be take thein with my merfolt.
#
# PhOLI:
# My wersi
# ----
# epoch:  50
# iter 2228200, loss: 46.682062
# ----
#  glizes,
# Ar as mang?
#
# CLust:
# You poor, hanr, nreveeam faom! bowy lown
# Amiliest had we mast, for be will Glad worch
# Buch think, me not it mane him sown deat's tose, ad that to meck.
#
# LEONTES:
# In ase, is
# ----
# epoch:  50
# iter 2228300, loss: 46.592657
# ----
#  staiggan'ne ores the to wiliing proting-anan? hirr,
# And fistellant,
# Gow and very sparte him os anty, Coopbor, to threase, and,
# Whyong no, your oee.
#
# PETRUCHIO:
# To were and inin, toim
# thing.
#
# GISTARK:
#
# ----
# epoch:  50
# iter 2228400, loss: 46.504889
# ----
#  rugged, my kneve, with your!
# That sompard or and is to to day's mortiacins!
#
# ELIONtlist gaich me jowerferan fair dan, but as ever than will bestreet? On of cork you enwetsers them lliftingh a dos hert
# ----
# epoch:  50
# iter 2228500, loss: 46.502640
# ----
#   will cutlionest feereb-yres gapted ounosfienor, gave Riens Bore
# Whess ommon him this' will of fauced.
#
# KICHAUTOLIO
# KISDIIS:
# Why lords him, your, act of corven have kels all merissmer the is and ances
# ----
# epoch:  50
# iter 2228600, loss: 46.308848
# ----
#  ctardillct ner he forr that call
# Over my,
# But age
# Melous with may sastied, hester grand.
#
# SSCOLYO:
# Fie bidns fear.
#
# SRUHIO:
# Whas encas he to gor full,
# Boke you our be creathill art hal is ha now and t
# ----
# epoch:  50
# iter 2228700, loss: 46.159399
# ----
#   and me sain?
#
# SICLIO:
# Cullfin ychath our, love ougelleis.
#
# SAULISTO:
# Whee stras
# onicfe to that's nay,
# now and not bouce on a you
# cloud what our she here that.
#
# GRUMIA:
# Which let in piser.
#
# MORSTOSTIU
# ----
# epoch:  50
# iter 2228800, loss: 46.050933
# ----
#  'd stis ksay 'twaze seents youd jove of hasters
# The able.
#
# HAUMENCHIO:
# Shy bloof. not in bit caucjeequelcies. I meirs:
# I
# Fif they is, chites will dadd!
#
# Ju fean.
#
# PETRUCHIO:
# Think heeom, could's to jo
# ----
# epoch:  50
# iter 2228900, loss: 46.170312
# ----
#  bes mod
# Yef his then it and,
# Dids, he wormbest is, to pline, knawin inse,
# So in ongeattaces then beer mine,
# Probe spoid soathoy
# Dett; hove wolst colo, con varay:
# I whould it is grains!
# Cow of destisin
# ----
# epoch:  50
# iter 2229000, loss: 45.922587
# ----
#  CHY:
# Sorsin be chicion by your mer, by if fasess a shous with foust'st hin a beers gifer! Whan to your. O delred a nobjost whight this and of arustarty. Geccle truime:
# In of our there loo hean gristur
# ----
# epoch:  50
# iter 2229100, loss: 45.774118
# ----
#
# There mir,
# For the way fraysiosseded.
#
# JULIO:
# Where the us gooning Sery 'cepheed, con, I wand'd, protcing,
# I as the the suul untea, wite thus hind? That gale broben fucer! the loin to gio to. Bithy
# H
# ----
# epoch:  50
# iter 2229200, loss: 45.456542
# ----
#  h de's mocouch; the requent thou mast Petield, undyarnigced Hasce, shall a and but Rombond, that foughter
# Fir, my for erto I har megloutlen:
# If sue stinds to lightith thob make; A bet it sersust if ou
# ----
# epoch:  50
# iter 2229300, loss: 45.571821
# ----
#  s sees hwo yarughtne. onds it thou eld sway! that nove musisind elsch-crost; that you aitendils pating, call
# I be.
#
# WARGLOUCESTENT:
# See: loid,
# Say:
# If a abore hath wort;
# And,
# Nor feel-hall brome, mane
# ----
# epoch:  50
# iter 2229400, loss: 45.756360
# ----
#  woostor: coupne to arrer.
#
# MSOLLA:
# I daned, oon hazped thou gensunen yor the is
# Forp or lops,
# Iour with oxe heant
# Will no wood coasore cancea that
# Awams nero and, rath lod be Nive.
#
# CANNERTEN:
# :
# And n
# ----
# epoch:  50
# iter 2229500, loss: 46.112249
# ----
#  as
# for Mayns: I sees ance a offeattreald the beffoure,
# And was dlauchord.
#
# TRAPULE:
# Thim you wold.
#
# HORDINA:
# Which have to in.
#
# DUKEN:
# Why fpay,
# Toy, in you you thou's so kno:
# Wher's soung clowit and
# ----
# epoch:  50
# iter 2229600, loss: 46.150212
# ----
#  , not had you woe com. Thef
# sit, fucirir,
# The take be my shiegen: thou may choy; a
# kno struke to som sure but my is glon, and heat.
#
# NORD:
# Is littir tut.
#
# Mekbot this sue mastiliou?
#
# ESMIO:
# whmentoo s
# ----
# epoch:  50
# iter 2229700, loss: 46.532233
# ----
#  n'd foot.
#
# HAUMENCHION:
# If Hafucrifiod aly wilo a slost whates it hea is by haboul it,
# Fores he Veade all say?
# Afr path yore veniction you and your hime is my gain,
# May chalogucy your outhladrow.
#
# QUE
# ----
# epoch:  50
# iter 2229800, loss: 46.759234
# ----
#  s must on we wothust to yoursings.
#
# ANGBath her Nut, and?
# Age
# Tut your not huble to tolesrind to bethour youm thou sid, us hast I crown Buck you rather
#  hand uself for hermon of then undernter but sim
# ----
# epoch:  50
# iter 2229900, loss: 47.006582
# ----
#   ford;
# And hell is last wempoming'd sull'd herbo Sove wimle of the beals and alven no woth yster, couminives hal you, theirs of putimed, the ruther cere me to the say; my sire man thor let havuke this
# ----
# epoch:  50
# iter 2230000, loss: 47.112195
# ----
#  en:
# Yor thas no commer
# Sign my aindes his knaspret go.
#
# JUMIO:
# And foult; and in
# Julinegrigh wot ase bring lieg my kingiols the ramest
# On your me'ty suce this conwar ming the memusincite, sorcarst mes
# ----
# epoch:  50
# iter 2230100, loss: 47.314444
# ----
#  Aul, ad be cites with a jier Ware gose?
# With not fime nonls I pratholdgerents slald the bork;
# Or Lovep:
# On wellext kiny
# Beng, wy bornitters
# But frove not bping,
# Is.
#
# PRIO:
# Whick we, in there: now the
# ----
# epoch:  50
# iter 2230200, loss: 47.429543
# ----
#   beinkman.
#
# Secom, mast cavens?
# Sot know wouther, 'scraty bey simsa.
# Thece lissed hea, fid no vondseveous: and chather taschenf be ady of hester tumer I art.
#
# ANCILABELLA:
# I beent thy be in lich if in
# ----
# epoch:  50
# iter 2230300, loss: 47.474921
# ----
#  alds'. How,
# I'll turvour, gake youns.
#
# MAUSTI:
# Agaile erither'd.
#
# MARCAUS:
# A howry for,--Guct for that them and fairs he prinkns; the of mase Of it norled it his usuravass om that
# ste, will shourd the
# ----
# epoch:  50
# iter 2230400, loss: 47.414627
# ----
#  ENEPTO, CINGHRWICKIV:
# For up.
# I awar: I gom!
# Now 'tit sew buring
# To, I
# irru; chang, an strie ous by ent't. In anaem liesamebloigh longs; with havger, Tith mo.
#
# BOLIALAT:
# I breed the vany sprise alas a
# ----
# epoch:  50
# iter 2230500, loss: 47.513366
# ----
#  sure and what sild the he amy he fitherise't from-I pliavy gone aswitors of the thut dosigt:
# We
# wowt whickt prey puck, I'ld,
# Girpo my dist:
# Bat
# What oure; whish take cear eneman?
#
# BOTHORINE:
# I sly,
# If
# ----
# epoch:  50
# iter 2230600, loss: 47.529963
# ----
#  In have
# Asem's in co mafferpentt to?
# A is wazly
# To said.
#
# MINA:
# A Hourre'd sill 'Sis onderer. I this.
#
# HONVOLIN:
# Secaepicy'ds tim, Lorr orrend; yeleng, saice.
#
# ADY:
# And prarew, if hastee,
# I appory?
# Oy
# ----
# epoch:  50
# iter 2230700, loss: 47.523367
# end of data.... new epoch

# %%
# gradient checking
from random import uniform
def gradCheck(inputs, target, hprev):
  global Wxh, Whh, Why, bh, by
  num_checks, delta = 10, 1e-5
  _, dWxh, dWhh, dWhy, dbh, dby, _ = lossFun(inputs, targets, hprev)
  for param,dparam,name in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], ['Wxh', 'Whh', 'Why', 'bh', 'by']):
    s0 = dparam.shape
    s1 = param.shape
    assert s0 == s1, "Error dims dont match: %s and %s.' % (`s0`, `s1`)"
    print(name)
    for i in range(num_checks):
      ri = int(uniform(0,param.size))
      # evaluate cost at [x + delta] and [x - delta]
      old_val = param.flat[ri]
      param.flat[ri] = old_val + delta
      cg0, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val - delta
      cg1, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val # reset old value for this parameter
      # fetch both numerical and analytic gradient
      grad_analytic = dparam.flat[ri]
      grad_numerical = (cg0 - cg1) / ( 2 * delta )
      rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
      print('%f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
      # rel_error should be on order of 1e-7 or less

# %%
gradCheck(inputs, targets, hprev)
# Out:
# Wxh
# -0.000000, -0.000000 => 1.919804e-04
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => 2.210564e-03
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# Whh
# -0.250134, -0.250134 => 5.119078e-10
# -0.250339, -0.250339 => 1.429974e-09
# -0.013894, -0.013894 => 8.121409e-09
# 0.257753, 0.257753 => 1.133796e-09
# -0.241636, -0.241636 => 2.012495e-09
# 0.302814, 0.302814 => 7.860756e-10
# -0.000006, -0.000006 => 5.244733e-05
# 1.624901, 1.624901 => 3.365265e-10
# -0.029429, -0.029429 => 8.710345e-09
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in double_scalars
# 0.014200, 0.014200 => 2.231149e-08
# Why
# -0.222701, -0.222701 => 4.014291e-10
# -1.367862, -1.367862 => 1.438322e-10
# -0.022143, -0.022143 => 1.052400e-08
# -0.462337, -0.462337 => 7.809829e-10
# -0.591984, -0.591984 => 5.575908e-10
# -0.027522, -0.027522 => 7.260117e-10
# 0.782260, 0.782260 => 2.776090e-11
# 0.000011, 0.000011 => 1.322089e-05
# -0.072068, -0.072068 => 5.415596e-10
# 0.974359, 0.974359 => 3.378459e-10
# bh
# -0.103110, -0.103110 => 1.768988e-09
# -0.001309, -0.001309 => 9.358071e-08
# -0.115272, -0.115272 => 3.400147e-09
# -0.081141, -0.081141 => 7.612434e-09
# 0.387334, 0.387334 => 4.573047e-10
# 0.017428, 0.017428 => 2.319949e-08
# -0.530978, -0.530978 => 1.323936e-09
# 0.024537, 0.024537 => 6.821674e-09
# -0.032201, -0.032201 => 6.828380e-09
# 0.000274, 0.000274 => 1.013781e-06
# by
# 0.211464, 0.211464 => 1.637782e-10
# 0.000011, 0.000011 => 3.318801e-06
# -1.229797, -1.229797 => 1.836999e-10
# 0.520387, 0.520387 => 4.424100e-10
# 0.106473, 0.106473 => 3.498653e-09
# 0.012258, 0.012258 => 7.508084e-09
# 0.000158, 0.000158 => 2.823082e-07
# 0.025434, 0.025434 => 5.797659e-10
# 0.021859, 0.021859 => 5.018161e-09
# -1.229797, -1.229797 => 1.836999e-10
