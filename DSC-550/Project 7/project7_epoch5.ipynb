# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('/content/gdrive/MyDrive/project_7/data/tinyshakespeare/input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115394 characters, 65 unique.

# %%
# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1
epoch = 5

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p, e = 0, 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while e < epoch + 1:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
    print("end of data.... new epoch")
    e += 1
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n %s \n----' % (txt, ))
    print("epoch: ", e)

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss))# print progress

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# Streaming output truncated to the last 5000 lines.
#  t
# Therer
# To braken Callowy?
#
# CFORUSII:
# To haoll:
# You.
#
# IRO:
#
# ANENIUS:
# Neil holow and perouspet
# A droos sulbe!
#
# LOLUSIO:
# Ho
# Vor't matconge
# Your piss, if upef, I hom the herell encices,
#
# MENCIONUS:
# Shat
# ----
# epoch:  5
# iter 181700, loss: 51.632304
# ----
#  e agang you he mere,
# Ofy int hears hik at resit 'ny reitheecome wour bomie:
# Yaus; of mace to doth wan'denim: the bri thou lecall ood
# It the je he congher
# Ang cined malds ofo coakis's, am nom Or uplrae
# ----
# epoch:  5
# iter 181800, loss: 51.556528
# ----
#  urs foabed ure; be nom emf hin elile soond so ther not
# Yoselill, at for hand boul nith wor? Hoy shope, us ley.
#
# MEUSIO:
# If cresellmany: emoe the ofe pay tashing they susqfaes bet is, the to hed thinch
# ----
# epoch:  5
# iter 181900, loss: 51.229933
# ----
#  ise pryorith, raquy entine hozimall you mstan fand the mninoibl'd bit arrey,
# I yick torr os
# And wo
# And haditud arer;
# Yoo hars oo finty le'd le pastifly of futnthint semfore post's, to; to you neuld to
# ----
# epoch:  5
# iter 182000, loss: 51.231159
# ----
#  ?
# Thou agh,
# To bour it hare in with
# And mfeave
# I rathinn isusenger.
#
# Haund, shat bave
# 'dn quace
# IZ you gusilt,
# The sthan pean I than suply is, foull lid's in,
# Thes etanys
# Loby
# By laste's my he carytor
# ----
# epoch:  5
# iter 182100, loss: 51.292432
# ----
#  e ivis a grith I pebe 'thow? Cows have anr you of the wall the achs mansters anf, to thean!
# Wime sout' Yelopleins meoke, te they,
# I eifeivest
#
# MITUS:
# I'lus you, buly, to mist weret Conbul, stins sevet
# ----
# epoch:  5
# iter 182200, loss: 51.131144
# ----
#
# Wesoll ape't. the you thisce rcoze to pyerrext treaf:, wirs So
# Tpinke hack and,
# Or to to is dode,
# Harer neswer sant
# The cone your houd at cony:
# For him theakean,
# Ant le! Foge's?
#
# Fite Tor us tuce'ds,
# ----
# epoch:  5
# iter 182300, loss: 51.056485
# ----
#  the thie.
#
# MINENINANNIONUS:
# This youd a me sarave in sheed, wall now cot, he wis thour
# gisster. usw'der wir tpacnowhan prawe the in ains we to kich with the there.
# Thin hands dictiisipsisuum.
#
# SENCY:
#
# ----
# epoch:  5
# iter 182400, loss: 51.103783
# ----
#  u,
# Who
# Ands you dererath all caet; tires trear on the wifeao, wing the thou is to'r
# is momeste;
# Msheing;
# By dill cond, warchan, hike I you ney woing to on sprail, himoms I sheld in I theners is colreb
# ----
# epoch:  5
# iter 182500, loss: 50.887684
# ----
#  n, ssexion but w'tt dang sest and and ize tous lourst nothius ur lith
# To makl bud.
#
# VSINIA:
# Norce nery and alce a lao,
# Prantith op me; gedem she
# Mithed surtwars vaols to tor she Vidour;
# I to, in ary'
#
# ----
# epoch:  5
# iter 182600, loss: 51.074059
# ----
#   of'sipibleste!
#
# Lipal bidist huir.
#
# PUSTUTUCCARUCIO:
#
# CHINIUS:
# He shis hers nave flate?
#
# MMORS:
# And farendest dister motein: a by hice.
# Why
# Tesle
# I artonet groude? you foll and, crop's it to thes; th
# ----
# epoch:  5
# iter 182700, loss: 51.130383
# ----
#  m, -to teathoul a on Thou lives
#  Sirn?
#
# Seuly
# Noum-
# -Uwist duwath cosot wo forsy hould troud have not in the ccate of ie,
# Arake now's wo; that are dorostnes mad oned. of hernous spepriscant har heen.
#
# ----
# epoch:  5
# iter 182800, loss: 51.031980
# ----
#  h, mo?
#
# CORCUNOSUS:
# le gath the ene hath he were.
#
# ISRAUCELORIOSONH:
# Weitharsntlot moll lly qIAvedidarsmanse dobe,
# What
# Nomation horseer is.
#
# LUCOENIUS:
# And atp
# You yout, ned. I
#
# SUCENUS:
# If thatises
# ----
# epoch:  5
# iter 182900, loss: 51.141257
# ----
#   muchernernt'd lon for and me,
# Eam or nome, on me he fe't thretpeth hay.
# I's fall tat of mallur ose thisp argurd of, they arer tor and weacely yantancirde ming thous you her Comencenin
# In!? Co shot
# de
# ----
# epoch:  5
# iter 183000, loss: 51.362584
# ----
#  ar: couin, bomes Hancee badh nevigiret shatad the thou reon, becess,
# Sewn eard.
# The mer mendin.
#
# MEONIO:
# Seve him; spo
# Mract:
# The hote-
# And nuckh I nee of us referd'd:
# Wneery, non, ee, on walm up's a
# ----
# epoch:  5
# iter 183100, loss: 51.563616
# ----
#  And cae: spurst stils frelave betir's of thoremsell to, whet
# There a pemistals hot, the of buend souls beal,
# I mant not that, ghithy see.
#
# COINTIINIUL:
# Lche foogh preone, nentat ar vam youfyes,
# Mart s
# ----
# epoch:  5
# iter 183200, loss: 51.462975
# ----
#  itsifise aud me
# Seite
# had
# And I'ss atle int cellan,
# If of he aok her you youn morymerridn ou loth isthes!
# And parco; this!
#
# Wicksein, were pery the with you groand bubpt, an intanserve
# !
#
# MENUS:
# Whe p
# ----
# epoch:  5
# iter 183300, loss: 51.451143
# ----
#  baell awama.
# So of aghe nouh pakfimen brent,
# Manty stomcir, heor of hom his tour jourtutest lewass; mis; hos; hand srous nous!
#
# CHARIZONBIENUS:
# Nhet fay the And a
# s noe whet his isene-pleveavese: fof
# ----
# epoch:  5
# iter 183400, loss: 51.387988
# ----
#  boo pranss.
#
# LUSWY:
# And and myar hall; that ball mout whet bight he himest the prock cors:
# Thing won fo buts to the thes, kist
# Burs the sid iss,; ug nomrefy ding.
#
# MeRodsottirs bease? nut they clen bi
# ----
# epoch:  5
# iter 183500, loss: 51.534055
# ----
#
# Ly in nee in nad sarfownitbe!
# Cous and shar noug: my myakh belfsen, ithy gon,
# And I is of souy gencefe;
# And had I aod ow ssestir Caal coth, it wamress, havk this we, onoure to vey sereft.
#
# NINo, thak
# ----
# epoch:  5
# iter 183600, loss: 51.443719
# ----
#  .
#
# Sot, wull.
#
# BORIO:
# Butorsotel his s'chent the ithanice till
# I, sinouds, fery and of not: the and, yur they hane
# frot misen hat the thou noull.
# I mot; hee cungandeavend he irp'd', wimes; thy faprvic
# ----
# epoch:  5
# iter 183700, loss: 51.346065
# ----
#  e thatin; his dere of to bour in Irirratas,
# Thate ptonvin'd hapre a prengle
# Ungar dentt
# ?
# Caral, bents
# She bu! us fere:
# shoms sournife an dive'ses mins my I of tfol I theselr.
# Adst the pilly pasted,
# I
# ----
# epoch:  5
# iter 183800, loss: 51.429714
# ----
#  nvechay alk
# the yam.
#
# IN.
# Far aod, coakine, ofine, Moy fits wire.
# I
# Yam hartitw deu pyis
# Or to thus foon.
#
# PENENONI IA:
# Heafter with's veron le;, chin; ugavedize urin!
# Thou eiad
# an mark mo;
# I'lhy thel
# ----
# epoch:  5
# iter 183900, loss: 51.564932
# ----
#  ith is I to downom; maik.
# Toiess for!errst's a cupitthatos then
# stonesustal!
# Wat a me it mustrot your it cbuill cath,
# To-Whins
# moul, cheed, you thour then sove:
# Mark to with he this a dord.-
#
# LIUMEO:
#
# ----
# epoch:  5
# iter 184000, loss: 51.608735
# ----
#   hertthonsom cull Aod exasunp.
#
# INARUS:
# Firm
# Then beit!
#
# IO:
# Waret.
# Co'd sill deir ede to fomrusoy thet, ney eirss afkirs, this wat: wastaledsibout?
#
# SICY:
# Shate!
#
# MONIUS:
# Yighteancavenbelr you shon s
# ----
# epoch:  5
# iter 184100, loss: 51.674269
# ----
#  reave beme mas ware?
# Nat, of me that walp
# Ane fois. whis hound peing thou hish wow doal, and that chopin quith to he nooth,
# Ith! reade, fly fank. us or bey fit eo 'shis oo dincy fach than seatit! my
# M
# ----
# epoch:  5
# iter 184200, loss: 51.726024
# ----
#  uwine nak, cee cos.
#
# VINITUS:
# Muscence pnaass as to Eiuse, an wall nomenathowe,
# Whent feon mith; feat dear pith ears
# Wospent I lalk wnoty sadenent for's haml
# That hear sofs
# The day-des-ce des'd raghan
# ----
# epoch:  5
# iter 184300, loss: 51.666597
# ----
#  I
# ESIUENUNIEO:
# That sor, david that ulow';
# Ociculesith Comu sar and Bent. your beave ife! in bom looty
# Hill I po dyeln fit and you, havel
# Yoll shich at piriin avine to venfer ind to fitter chory, my i
# ----
# epoch:  5
# iter 184400, loss: 51.708372
# ----
#  hoen,
# Mraok, sord a akine mame heved fasirnsgen that have cond To Thingse agrevere, your praies.
# Thead, pentess
#
# BROA:
# I that famh chis to bpanougis to saally you to mist honis's and wame
# s, the hull
# ----
# epoch:  5
# iter 184500, loss: 51.719019
# ----
#  ,
# Tire, of oly home;
# Vo uircher erelrobe, Furser peath me him dede, angull to lood uflbovy hais iise,
# 'Tean.
#
# F:
# A RANDIUTISANIUS:
# Lith I browg ongnulnobot teil tigere ond therese ry wind indeal marth
# ----
# epoch:  5
# iter 184600, loss: 51.855055
# ----
#  nd grextesw lake her the an sher kayt
# lothfunge she couuhese and our
# Wher.
#
# BUNENS GROFy:
# Go tas he on. u?
#
# Fhith to brigh?
#
# COLONIUIMA:
# Whe cooo, ins a ghand, bupherus hen?
#
# MUSTIUE:
# The stoan:
# Ih th
# ----
# epoch:  5
# iter 184700, loss: 52.078470
# ----
#  an it,
# Seat of;
# The nubat'd sid. must my you wlingent, wtthing wow fore?
#
# LUM:
# Me fol, than bamud 'me come
# Carth she usorer pramistde my dowk that niglime,
# The oith  to dat; wive need--nies moonp when
# ----
# epoch:  5
# iter 184800, loss: 52.162547
# ----
#  e cande renobelney him eiveng:
# Racureng thus,
# I nort hath I on fath if my thou kuth had wow the doull on wancan!
#
# GLOBINTENLALUS LERSROLLNO:
# A'ig  un homid; hath fod thet, rhoke to the men bpo. ush pe
# ----
# epoch:  5
# iter 184900, loss: 52.124019
# ----
#  RUS:
# Corust to comans
# nigurd fo mulss,
# AL jenelgmorthavenvert, the in art this then cay maveYerCom
# Sor.
# Worlat, Pestar.
#
# AMERD RCCONHA:
# Bord ind.
#
# SLUSTANIO:
# But my righ, 'paserals a mer coushe?
#
# CCOR
# ----
# epoch:  5
# iter 185000, loss: 52.115612
# ----
#  tiyme not cheivews hacl ent to dow
# Himhill stat shiig's, to ust
# Wheave ut cherse,
# Why you lish ravefuef you bukrdelrce wansthe,
# Whilkly him you
# Wh wither theanlow, with his hith futhilids:
#
# AUTINIUS:
#
# ----
# epoch:  5
# iter 185100, loss: 52.168356
# ----
#  gh ees conk'd molswis the Gudllethel, dengar of the ol winw him-:
# By and hin:
# Oe frobot be, and the will dette fery; theive hank notinis:
# Dortit shave brake a reire mave lakenoncobe
# Ane a Illeadye muy
# ----
# epoch:  5
# iter 185200, loss: 51.879773
# ----
#  ough orcorthlao to to cont hrowy tho so therath brackendith my hich, it wuth, Lemeqfint,
# Your to sgand a man his a clat
# To peat think hloude us ghne's oagosie leans I coln: ols madle
# Bont y sperer,
# No
# ----
# epoch:  5
# iter 185300, loss: 51.736240
# ----
#  Pees,
# The my grour his vnot,
# What a thear
# Thy whour op to Gsoo, wim, hall, Took in:
# Gut, no.
#
# IN ERINCESEO:
# Nothy, poble bew,,
# But enick Oo he it tarellewl;
# Hear
# For fo.
# DumeN
# Cusrimeds, in he, cukt s
# ----
# epoch:  5
# iter 185400, loss: 51.688886
# ----
#  namw lage crak, creath Shar he The Papes,
# The thimy noud he her that un, be notrave disele than meave Lodrath!
# By
# If at of at evins spansathce in, of youses my pels, minsiugie fhadsors in for upreving
# ----
# epoch:  5
# iter 185500, loss: 51.601589
# ----
#  RDAR:
# Asebuth: that ald brots,
# You you pat keive, no for anu on't and houshing, whim,
# We rayice cilf bobhend, amm me sar cone:
# Ar tos singeey.
#
# LUCENUS:
# Thist her your Beif the that my h me?
#
# RATINRE:
# ----
# epoch:  5
# iter 185600, loss: 51.583178
# ----
#  hen.
#
# CASTENWARI:
# My woumsenther that wors worqoor wortire heete ofy farent.
#
# BINCERY:
# I bee of done Mecolk merd:' your aod to to not they purine be to sees,
# As banfer.
#
# CANRENE TENRIO:
# Yent wort as
# O
# ----
# epoch:  5
# iter 185700, loss: 51.500244
# ----
#   bod larest plould
# Hy leath sunch thy un this fit? urle
# Thie of chanw dmepant?
#
# YARCELENANLUS:
# Y'e, errash have a ne; beucks hlat, awh une
# to the did my spovree ath oo Youm gomem nord but asing?
#
# BEO:
# ----
# epoch:  5
# iter 185800, loss: 51.459298
# ----
#  akw the parusled elleal proives his the net wes fapingough.
#
# SRAUTESTH:
# ELI
# Fich
# Roul, mer his more welicsoed have vagust!
# Beed
# Furt ffage At doph, to would po;
# Spis my nos
# Cbanccealch youf gurrort sw
# ----
# epoch:  5
# iter 185900, loss: 51.358237
# ----
#  t by mime, lou Courstmy couissime he thar tibestesheave asest;
# Then not
# Heatit
# inse
#
# BOLCUCHADTERCO:
# Youcles and dat wel hilift is-loper.
# theave, to then I cont I rat brightent bes, bert the pratturel
# ----
# epoch:  5
# iter 186000, loss: 51.116345
# ----
#  p you berly nor wary, blepas lots watoy.
#
# VICGINIA:
# : the Damido cont sordick withersly bakh foone hould coun hous the cowthopters.
# Orcors, y, newiay the ou newbe
# dreep bed hle and: the my Attsesh ick
# ----
# epoch:  5
# iter 186100, loss: 51.168432
# ----
#  s pagunt worgu thel Weror.
#
# GAUSOD:
# LANRIRELO VIUL:
# Thihernith swellith Of a font art, gond thus timy.
#
# BICHERNCERGUS:
# By choll
# Tabese ray:
# Satire, to that ther!
#
# METRY:
# Hed.
#
# MPUCESCHLO:
# Charte; norc
# ----
# epoch:  5
# iter 186200, loss: 51.521900
# ----
#  yare sofust art!
#
# BRORLANUCES:
# Whave he klis of to thick ding did that Conne nond tiel bentean brean
# Thou shem,
# Apmer'd,
# And dee olcawn:
# Sheld his do to bath shull?
#
# LEARY:
# Wher sloll that gesorte sif
# ----
# epoch:  5
# iter 186300, loss: 51.630744
# ----
#  n a 'de with vefint
# Cand me with arep? Farshe bun, dere att de forel that mast'd wills, that fo theceer a noubrifed bone;m emes houd; that hese thy in hiver Comakfony worter;
# I in hed tist, Ferer a;
# b
# ----
# epoch:  5
# iter 186400, loss: 51.640628
# ----
#  r.
# Waleenstars, writiatsrau that naddach.
#
# BIEM:
# Ind havl musion daiy, cothe wemud went Jus wadenons, qusust shall--'te! The I hare, exey I hory tlanymins; herendamle ham raye juks notrord and ere?
# To
# ----
# epoch:  5
# iter 186500, loss: 51.532254
# ----
#
# Ipror for the erend then wim, you on wemf goR ree?
#
# KINGCUS:
# Foss we! nust wite eperm oplacte hirg, oo -To Tarem loard by upie were hitly iall.
#
# KERLLASTIT:
# Me but'se Ho wirns to to the with my, with
# ----
# epoch:  5
# iter 186600, loss: 51.249136
# ----
#  , bion
# The much ang
# Wele' horn not hen;
# And Margor-' Bursied with,
# Bod,
# Theneve buwshey: thaad lewlacge bevetiurfirl
# Fongh eor ngeedeane Larte uling cae to tor to
# Mughted not four him and pullious, to
# ----
# epoch:  5
# iter 186700, loss: 51.323623
# ----
#  I tespisowy tasest: ond hi,
# Wurnd?
# Go Eor bengenucas suge mave of vete;
# Surdoy!
# For yest ham so nisedy!
# I his rouh thou dee thou sind.
#
# BRI:
# The waser, spoudtid heall call eon in me Exthaecy
# Where:
# Ch
# ----
# epoch:  5
# iter 186800, loss: 51.303235
# ----
#  eul him Glimetodste,
# IO pornsgeterand nyter,
# Then suck.
# Bond of sang, the to wave proke veiubped tang ar in doond ssor! and ant not? Edor ands my rowebint.
# Be thesolme,
# Till mune.
#
# REEDS: levoment, yo
# ----
# epoch:  5
# iter 186900, loss: 51.399814
# ----
#  dirchons veldee,
#
# GACES:
# So nom mnae?
#
# GLUCEEFUE:
# :
# I mistharer suod;
# That God of no brake hindt or so snist the me tod, at micesw all the shingand hake ery, fiy dringonisthing:
# Iom ye of that codeer
# ----
# epoch:  5
# iter 187000, loss: 51.516600
# ----
#  nce plo!
# Fritue, hake and of creand, thoal,
# Anoull fill:
# And wiodord dece me all, Ire invanns lance tould him, should! Kagherpi's prhom that brast youd pugury:
# Anc mofrerr'cong Mimed dheder brouss?
#
# B
# ----
# epoch:  5
# iter 187100, loss: 51.549409
# ----
#  es
# to this in ben: exoun:
# Chatp thlme,
# And nost, ind gee pold gree the the cangengeubry boull.
# Yots Growe
# sir!
#
# ORIO:
# I
# Yow,
# As ind it putin iran to dut hast mes suld verot stam'd bijauslerdon
# But cos
# ----
# epoch:  5
# iter 187200, loss: 51.454344
# ----
#  at gutfanton the ast worend I whony thmoullly, with horatt:
# Youl tay bus if hew you be o'ser
# The bid you he this not coull nors. meer do elefe at brad Gos res I rweims for is:
# Wuth
# da laks you
# Yove, a
# ----
# epoch:  5
# iter 187300, loss: 51.470741
# ----
#  ase uply to proy halce pervave's
# Angar is fapalke?
# Taland.
#
# Fill lade lof, me with feald aly and ther Bet busse,
# Thy to ching the to dembe us's nothe in hacleadet me daubawfser with; ollise the berd y
# ----
# epoch:  5
# iter 187400, loss: 51.442955
# ----
#   a tong.
#
# GUCHE:
# Word, of Conce him, nod, satiey ofth! Nor to dose darn.
# Thoneng;
# Whe lovens carthad,
# Cyed, sing. AC, the Rond not prome imast wgentlet!
#  where dicesel, this them let--Serfs, hatey,
# Fo
# ----
# epoch:  5
# iter 187500, loss: 51.343236
# ----
#  CORYY:
# Whigw?
#
# PORDARUTEN:
# Feras hbichind.
#
# K:
# Want and so's dit yot wwee gat ney ben wover my tell o the shar you hent when wapue
#
# CORCCOUSS:
# Waringance.
#
# LANGENCEBE:
# Welred: Nod you surm:
# As Itlat a
# ----
# epoch:  5
# iter 187600, loss: 50.984521
# ----
#   Gu him yom lot onten:
# Weoyy co this pemikh theard They anbe the gree that deant brover loweset And dequmaal this to nouk mine, thotitud napey besorand?
#
# Bece!
#
# RCERKIS:
# Is shass than kassurt my lee,
# ----
# epoch:  5
# iter 187700, loss: 50.865750
# ----
#  hos.
# Bes mucce cacloth, my.
#
# ANROBH:
# Whengenf, ing.
#
# LiME:
# Cune Beay!
# And to hish, Bengep thet he sorll, fllo yughes'fiuld for fliy now werries pee a shates, arauss stors not ferapr, yo I my as hinge
# ----
# epoch:  5
# iter 187800, loss: 50.773884
# ----
#  he and geis but of my geansertorsith vean moit. VarvicionceBo, telraad hon
# Spindeg; ofyswent becess
# Bece
# Tim, hour,
# Hpokilly proutald hom, my redot no
# To-cremy to I deoud the I'll I this to steagory m
# ----
# epoch:  5
# iter 187900, loss: 50.807360
# ----
#  t to Warbe on thind that hreng buanorl thus.
#
# BEUCHROSTES:
# Can sobuls bot deall ongels.
#
# MARUS:
# O gorr qurom have preather to thou--Bis, I lild no
# The ory moon; the.
# Wery,
# The to land
# Ther than hing n
# ----
# epoch:  5
# iter 188000, loss: 50.856805
# ----
#  mald deefer and Wead, I not is toween intes,
# CO, gay ander leslenorith.
#  sow ume:
# Wious low?
#
# YROT:
# Whe pard trow
# LYE:
# Bet Hen?
# the heaws; mowy.
#
# Goor in,
# Whist
# Tongedher thou or whis for Cortilisther
# ----
# epoch:  5
# iter 188100, loss: 50.776982
# ----
#  ee '
# Al teen'd.
# Ged hilderer of halp hoolt er
# And the eont your en eat thears y geneath werdid, must of dondeblort foulst wing clentire'd, I
# Youtchacke have and Glgollich's tay, and bon,
# The gick matr
# ----
# epoch:  5
# iter 188200, loss: 50.837841
# ----
#  axt Roe trour ontshrat is baous mpo?
#
# MATHENVIIDIWASTER:
# Weron Geetp of und to of kis latenf gan sirgh suith.
#
# COLINCO:
# Snagh, swee, by ad, pray Gicnobys?
# Tor thare.
#
# ULYCUSTOME MINGONE:
# Aid
# I Calle a
# ----
# epoch:  5
# iter 188300, loss: 50.840081
# ----
#  upteny! Gode?
#
# O RDIIY: buce:
#
# GEST:
# Fhan onceing, have withime not a lorid in cag do athre wast you I inostunetery bey ue him,
# Then dee my penurme tou hith. Guhdlorad his his worthed,
# Wherter!
#
# AMERC
# ----
# epoch:  5
# iter 188400, loss: 50.858387
# ----
#  ee, medeld's agat to dourt.
#
# SECHATY:
#
# CEUCHARY:
# Hn:
# Swem his pukpt Buldif by, frenat lils now, the tfeld staw siy it you me, fanking mant.
# I wifep; troke,
# Gwet hol k'entfars dost shar, tiel mor trses
# ----
# epoch:  5
# iter 188500, loss: 50.973967
# ----
#  mous offow wir's wime I kis a for Vorne
# Freas comuste eghonce it we
# And hom, irse
# Hets thangle bats helirsed bonenen
# Solken Heipinimeserd le.
#
# Patobublting? is my theor vlen ard in, wat his erkhe, the
# ----
# epoch:  5
# iter 188600, loss: 50.838466
# ----
#  that andly soubresse dead sury.
#
# HORY EgENUCENN:
# Od nead il to gootw anithars fore rolcetkary dey.
#
# BESTINABINAZE:
# do now frey thy streged, fout!
# -with thy of logetere?
#
# JUMADEUS HAMERWER:
#
# CAUCHANGH:
# ----
# epoch:  5
# iter 188700, loss: 50.845103
# ----
#  nded.
#
# GLUUSENTrcitwernan frishy dbotF thee Theye time she all;
# What dooy-ar and for
# Brant
# Theire,
# Wors,
# Youft your the your your youces!
#
# CAPUS:
# Is reMweed
# Sond wechaded I;
# Iitly,
# With
# Mess I in to w
# ----
# epoch:  5
# iter 188800, loss: 50.971782
# ----
#   bak, dee se;
# Ritt touch adplaing bey shat here my dood cleotfed,
# On nord's thep and soof yours aru denes.
# Carseave vigon:
# Hevey,
# Wet how rou veand. Kat newcels.
# Burke.
# The dwall I of a hernt comfed o
# ----
# epoch:  5
# iter 188900, loss: 50.849839
# ----
#   wher leanortrertthle tom pank I for ins 'gatts,
#
# POBRARD VINCHEY:
# If whe of lraserst, pooe bee! my, wneok malt.
#
# PENVY RIWHcew doot to day insaft, cotid, Gon,
# I noe tertine's tobugly int bere'g a she
# ----
# epoch:  5
# iter 189000, loss: 50.842557
# ----
#  tt mose thoughirten bysilses; famot, luth,
# At?
# Fo
# RY:
# Gase ir!
# -frate
# And his sare an, Il, he Rivell may ree's moouble teedoslthenk Mastley; wenuse hath than, yuloue peaweming and kakull!
# Py ut steane
# ----
# epoch:  5
# iter 189100, loss: 50.802602
# ----
#  e dall my.
#
# LARDINCERS:
# Furd, her corse be prouth, Eond falitt hare At deat nacer of Dere were, demajcunded my wantt foimy arl himd nes'st, ins:
# sill-ther agatt ord veath had kily ulm'd of in ands; no
# ----
# epoch:  5
# iter 189200, loss: 50.958359
# ----
#  u veiy Tham, soo domae this no, patle me bat the me shes't thoufey, hare, my sheln.
#
# KINCAPID:
# Hy letithal dorge!
# Wull boitiw then do wasgy you to your blon the chor spee fullry!
# Busther Ganksping his
# ----
# epoch:  5
# iter 189300, loss: 50.799547
# ----
#   the roursoy
# Ued Lorted tinght sont
# Meir ico Tisen
# Wayd knad you bomep's neprit you loterrand, lid phontse so-A Hounteetord, mest gome kink mes, rook Go oneg.
# By me to It soptobiksesuld;
# Sey.
#
# BENFEME
# ----
# epoch:  5
# iter 189400, loss: 51.009164
# ----
#  UEEN HERT:
# Sfiacorllem, tof ma, we date giap eanleron to all lo to thun I hasr,
# I hisht nat there moit head of with mergt mustif thes; the grinst on in mithalecl, muld, juld,
# Ir fargh han;
# Mast; must
# ----
# epoch:  5
# iter 189500, loss: 51.194994
# ----
#  avs buss hiss he cinces heas therott Mowerthe susanch Go stead beges
# I fick hath npooth,
# A cals Hame thed and I glads, woll le in, you the I py donglatt moudend.
# Thy and 'up bungert thlesce! pro the t
# ----
# epoch:  5
# iter 189600, loss: 51.236745
# ----
#  RNENHE SRORD ERKINGEM:
# Sorter, couy memones-all hase he Yibe, fay Dat the rasgit matumzaing of ofrot and the the int teid mite!
# Hes, to ee.
#
# JAUTES:
# Ward, on, hed, are swerpwe me sool,
# Ee.
#
# CAMETGSINC
# ----
# epoch:  5
# iter 189700, loss: 50.876035
# ----
#  u?
#
# Taris, then wentend statettry adgris ham.
# 'thours
# Hy harker cafen-t dee miscirgholded hey?
#
# PROHETE VIIZANGERUS:
# And net.
#
# KISG MINGBOMEA:
# go I make soo wrongel the by tien nobe now?
#
# DUMUTBorthen
# ----
# epoch:  5
# iter 189800, loss: 50.636891
# ----
#  w ofrerm blect pick conmdour, lith ben?
#
# ARTENILI:
# Now buge
# I sneder;
# I nortisl ghes Qripy andat ne; to booffe cuyirds the pivin dofen, whate them my toe thured!
# Whove un burt to sode:
# Fipler;
# By ink
# ----
# epoch:  5
# iter 189900, loss: 50.178285
# ----
#  the wake youf
# Aod's tiy edous, make gore, lict whers, fizes,
# And moles fat wark spat is a bidibonscot
# Ang thy coond no dope youtpry out 'Theet wefins!
# Bag a my in all
# to a makelr, I cham'd 'rild:
# I we
# ----
# epoch:  5
# iter 190000, loss: 49.978461
# ----
#   of hous; Cond hath nase,
# Lakitilo,
# To the promatith igancent of will
# Tend ofrang of warce hes, trang buss hiill breae he anest and I wat.
#
# Herach the o on toom norondet sich inordiites,
# Hast'delling
# ----
# epoch:  5
# iter 190100, loss: 49.578541
# ----
#  rtrere?
# Burind ofnae theik--Got Yimk.
# If lighantpo pae loiciy ind mow yould?
#
# FFERD IO:
# I'll I ka warel meer; kindar in lown higlmenpe to is hvacel lide,
# Hiuld then-de not for and tom lover of and ing
# ----
# epoch:  5
# iter 190200, loss: 49.449402
# ----
#  the do yembany that qulasinke lols, os go! pomet Wheece isllar mever nand, this to fakes theire
# At, and I le bratsy mreave,
# Enont'd,
# Spall still caoan. Ryer spalch browerne IS thy sey yentlor y in you
# ----
# epoch:  5
# iter 190300, loss: 49.382497
# ----
#  sh.
#
# DARUARNE:
# O I my mantattemencust his ly thalshee I kare and ktit, the theing.
# Send lour or wey' stames, forid and buis
# thou knee, dther find:
# And on that lord inch be the Fith the helr dake my bo
# ----
# epoch:  5
# iter 190400, loss: 49.463660
# ----
#  iser nord; nordiugutord kond Sin, but nedoucf thy be mustloling.
#
# LORS:
# Whel,
# Bo the Alenutes?
#
# DARTIUS:
# Wime Ro not and old to ary, of thy dowtlreentent!
#
# SEKR ELTH:
# Eondife your thes dat am As nid c
# ----
# epoch:  5
# iter 190500, loss: 49.997314
# ----
#  nodpy Oning dory afilk you pritched.
#
# QULECiwce wod's to our mind
# Them, whis my your;
# Hy dour to I thine hlispins beingacar shy his a
# Fat
# Butra fapine het, ba guren lion we!, have therisl I on lrate h
# ----
# epoch:  5
# iter 190600, loss: 50.215995
# ----
#  lift, vallquland by not farsenad all reatter goscowns:' basy, Opas botent If sonst mice you then bikene the he'd wirgl, bang, uh nied you rictrore Ood his bovshen all enums pect leest wis I him this o
# ----
# epoch:  5
# iter 190700, loss: 50.497932
# ----
#  ever'd gratthon my furdobe non grouryer ast I antarimes metaur.
# To larens nomudsee me hishering, of, crake the cord,
# Cyauch, o mere, by whilne I domang.
# the was, friig-rech;
# Moudirs!
# I leanchet to apl
# ----
# epoch:  5
# iter 190800, loss: 50.974178
# ----
#  llt mass ard a mas as int ris; the lelks bive bicine woth on,
# That, the thet tien sivedreap's be mes ouct hish then,
# Therding are tuchin the fanker;
# Owen;
# I or harin,
# Mareest with recucuen to in hast
# ----
# epoch:  5
# iter 190900, loss: 51.280955
# ----
#  rfils
# pcarjow,
# Thime; ree hears by thoue.
# Whe hosouse! ces mers or cend gin; he geyenconce, I's themrod it Kat Kouce;
# Prack,
# Most weme fom;
# Ware, And sour a
# The coove?
#
# FRORY BIUS:
# Fald, act-lee,
# Mord
# ----
# epoch:  5
# iter 191000, loss: 51.333989
# ----
#  ll:
# I the bo verant gence
# Yome:
# Dy to gaces thet plesse a dosrder ing ssoin, lecoull love afet prour adord, ilve undt kiln the pele Ir ise san gurend all foo blaes ucderent.
#
# BILID IDZAM:
# On mordras.
#
# ----
# epoch:  5
# iter 191100, loss: 51.488701
# ----
#  ntrive and.
#
# COLIITH:
# Tours:
# Con love Fors contuce will loth, b west so--
# yous lotheron!
# Or hy, fooud whurmeniror the geurted wewes, courd, is paer thou Icturd any stoe fo, roskeisle thererd of the an
# ----
# epoch:  5
# iter 191200, loss: 51.582071
# ----
#   wimr bylace osincef
# Tutom youldose.
# Hent, in dowt crord at mipirr;
# If artary now rover that the issy,
# Wince salad nid qyrchar, to gon by riveet eold, nows pledt und stast is ingraer apefe'd this,
# Had
# ----
# epoch:  5
# iter 191300, loss: 51.635041
# ----
#  Gow:
# Will the und tame
# Wuther briins for in the ey me deake
# Mare bistmord hathlar ha. 'msele hiss the to noc gragoly speeep!
# Ssengers I badneciney diser datongone staml cly milirghesnead dergs doilh w
# ----
# epoch:  5
# iter 191400, loss: 51.822281
# ----
#   Kag aWam a sho, the kith and wors'd thoy, hise co I hupnord ben and the le
# Sy on how.
# HITENIO:
# Edriftilcharind plepe anat
#
# MINGLENENZIy in?
#
# Hagh suly thy lo
# By no, dinger-dser nucw'tip pay'ld, him
#
# ----
# epoch:  5
# iter 191500, loss: 51.931135
# ----
#  usI; for apttthent will;
# Waws as me to to wome lot, woth gestray pais in bow mapors, a demey himur as fo, that he ard the stators;
# As, thy tham erswalsowisgout eilp:
# Nabal'd cache lowingear, mall of m
# ----
# epoch:  5
# iter 191600, loss: 52.100742
# ----
#  ning blasere?
# Hher bomuve of and edlle sell aplroar-if moch he ttank brad of us in an thyir have Semors and asils bethal?'
# Nitst woundwetin the or brae pasmife Sice fis, shitherell, fom suroun priotI
# ----
# epoch:  5
# iter 191700, loss: 52.134946
# ----
#  h:
# wente,
# I tabre is of to siky herlh grood teall of buttatt of me
# Your,
# it frent good agae, her lowcititeculuft of budreish unde wcense bew deang I hof, I tare of ang mingech, havhy whine
# I, ar 'urst
# ----
# epoch:  5
# iter 191800, loss: 52.231382
# ----
#  ass's growencinte my the sem,
# Thou ningilern; artendne ats whes?
#
# eathear, you falss thow om your my stond rowy, if basings;
#
# BINWATTH:
# Tainem, chend
# I homenbenter,
# Chtist heraep eitp a sopoude the wi
# ----
# epoch:  5
# iter 191900, loss: 52.373809
# ----
#  er the pree wigharer is for;
# I thy brerate youd sall ureth's weal me wegh?
# faccour, the now
# Mhadsed,
# Befe weur ave arill to sho.
#
# THARI:
# Arve fnom,
# I se,
# As me mulr adiigh sorn:
# I hime, the lischar th
# ----
# epoch:  5
# iter 192000, loss: 52.429042
# ----
#   grabe?
#
# KLANH:
# When arr'd Fipaid with I on ald Paro teat thome.
# That prickee wrat prexeif rot bus sinarf:
# Mamins't faretammend for gon, of us proy bry. Ick Rhat, lo
# Wherlan os erou my quicen.
#
# ARD:
# E
# ----
# epoch:  5
# iter 192100, loss: 52.266276
# ----
#  titirr.
# And is foy ealse ligh denge The bigh wall
# Shighicjean the marvear:
# Acoltry Wing Bo me good of is hill wis ret and swweribins. Or thee, bomey sexy fastsultalus sede.
#
# Fhee wisersebnarp? cwery t
# ----
# epoch:  5
# iter 192200, loss: 52.183609
# ----
#  ''d he wiye
# Hors.
#
# RDOLRIZISAUSAD RIOH:
# I o- trein remulk he thickong ming
# Ag.
#
# ARYYZENID:
# Ho, Keat-Wheave what it a theim I lappul of murn your, jovite, thered Mut ufok pert
# I';
# Bomours' have him our
# ----
# epoch:  5
# iter 192300, loss: 52.134815
# ----
#   tell.
# A begprad' his woge, mat, deidury nuth to thing yebno;
# Wither gracome read.
#
# SEONG:
# Fonthrowsilsamony glald'my dee dowe To on het sin thes im meletn'd me bowr disest save ly prye, ralvive gulnd
# ----
# epoch:  5
# iter 192400, loss: 52.179410
# ----
#  ape fide, to goor lenst is in mein wirs Weach
# O my vowe: datetrerane me ha gon soas lenst brates thee lest theal wirks here alinerdsiie a defet
# to thap of nive no,
# Hall erkes pilecet
# Wim twartell lime
# ----
# epoch:  5
# iter 192500, loss: 52.049552
# ----
#  tured to her I, buin
# Fords dhy theef of meave kiy poro.
# My lot at:
# Anter
# Why comath to the fut od lach thoun, daterrly strive an by that muthearn butwaed.
#
# Hhow far nigher, raristty thus your heriy er
# ----
# epoch:  5
# iter 192600, loss: 51.840672
# ----
#  th anesusibe;
# Yom for agilens leok, wad, pauch, my groy;
# Sofrox shes?
# To quctsuinch wives of's ly tis thald so ait theo than of to friy me wark, Mucelk tro sodes:
# To kastsietgag if hallts.
# He dlysen v
# ----
# epoch:  5
# iter 192700, loss: 51.933781
# ----
#  ed sincaners!
#
# KINHN mand,
# Thou the vith tie hath BursI
# To fist Gimd?
#
# DUSTHA:
# Muscal naver cowt we, dacer Bele hserry git yine, do bome Eor nigh my preashe for wail thet to'm, seol his and bulenan th
# ----
# epoch:  5
# iter 192800, loss: 51.944981
# ----
#  Ya wing
# And ole apratg maks your,
# Fut, ding thane, willily,
# Af I'
# Werd, sopur reen thome monssaatos goond thing a and mork-wist ands dorkst sice; domaver him
# nootervnolchimfer lucl are; fie need or O,
# ----
# epoch:  5
# iter 192900, loss: 52.126982
# ----
#  in;
# Thiss misw. Or-, thoteeve,
# Romederas- gean? mare seld The keral the by I read, dipe my lind igees kneyt enerot and wak, awrougs?
# Whraoconith krot howerecton, mong thupilercungs
# Syoy Uod thester ch
# ----
# epoch:  5
# iter 193000, loss: 52.255410
# ----
#  ; Uof to hi hon and onded of heon thou so habl efirt wove An ore, Whe thouge thee the my thou prailine and thece, ip dictre the denvothals bedy be rickant lous and to dere sen'd lont'st'g, pod!
#
# SICGO
# ----
# epoch:  5
# iter 193100, loss: 52.156280
# ----
#  es,
# And that losts; shoed her buwy aptreve eof welkind nath,
# Corclys hasl I eash,
# Homed than thin fus's in so of of tormo of lorvessizentreldake wed stertham he ir:
# Thint her.
# To simifuruse, so.
# For o
# ----
# epoch:  5
# iter 193200, loss: 52.159968
# ----
#   will heve in to mast sour ths Hille elnt pearlh.
# Ank homes hese lont and my no Ifid I clat upiingu stant,
# Hown,
# She wattan shes eragh Doont, kel my in the of
# Fornercope, sany, lad,
# Whings Yod of,
# in
# ----
# epoch:  5
# iter 193300, loss: 52.010417
# ----
#  st, pentaan,
# Wolm the adliln her: enger copprech wragt loogseeld rund hath dood dreand ficke.
#
# QUEE IN:
# Weavins:
# At, prermawe;
# I marst do o he ingere and they ovemfothen aine ot wicke to and
# Thalllesw
# ----
# epoch:  5
# iter 193400, loss: 51.999249
# ----
#  with you firl,
# Your mat in this iver for the pay tergems sord wile,
# Minnwave mand notithe an weeste prcees:
# Wente degare,
# Looluld,
# Yould oufe homin arthave you, as
# Werer, your the bobnons casalr gromb
# ----
# epoch:  5
# iter 193500, loss: 51.896494
# ----
#  siken;
# And, les, erle of
# some.
# He on a thealterom archuzouly hing suses ratead Time;
# Olle are with; Dengh, hroks-t Mollait's me nisce, to it hore math unithe; him, to seoms
# I, a my of wurithim'd spinc
# ----
# epoch:  5
# iter 193600, loss: 51.801155
# ----
#  ox mnemy
# And is sund bysell by tow thellind'd ROrtongs lornad I angt, go:
# Oe I now he gay nears and ufitly, by in thic wis andniot in presweney su kecrender us my I am ance stice to of is to in hee by
# ----
# epoch:  5
# iter 193700, loss: 51.813440
# ----
#  dougher-dath yous bet hyouly, the gerdst bid hon the, anmel wyserce roin cee ron of his of thous youths livet cho go thy hake youthers gran bach foonathe ties, penkn
# Whane I leond Ow
# Brough not aply i
# ----
# epoch:  5
# iter 193800, loss: 51.882354
# ----
#   I watlrick,
# As beded bet If my ure iss my shaye busfy lapelu to that thour shee, Provy mach the ene?
# I and lothelriming
# The tfere culle?
# And youlen peouldlel thouldere and neay:
# By leach the ulfas pr
# ----
# epoch:  5
# iter 193900, loss: 51.876899
# ----
#  .
#
# KING ID RORK:
# The avathetinks
# Hin geid and reok mich; coprol My cheir my it my you het
#
# Inche.
#
# Chome me bre! ryiguraf
# 'Tpeaill the ly you then matel; sigly elshel whis-coly, his siry.
#
# DUCUSPY:
# Wo
# ----
# epoch:  5
# iter 194000, loss: 51.852124
# ----
#  temase sho?
#
# Were
# To can geor;
# To your wdme.
# Ir ipe him of ame holds for wast icn-Abuhe queant
# Most darttold it I Brove enighine for sthe No hing masulpinnby
# Babtee thy me farkens
# sot undoul'fse, tarn
# ----
# epoch:  5
# iter 194100, loss: 51.807196
# ----
#  sgant the
# An seme himle knarglatl onlupad gey, brads the thy a aresrey?
#
# SIZIDILINGH:
# His neers dever'de ou, fhoaly'f rewinithing,
# This in, a alle acesle bo the af nivie!
#
# DOLYBON YLIUCHENRO:
# Y low,
# Y
# ----
# epoch:  5
# iter 194200, loss: 51.820713
# ----
#  e.
#
# HERNENE BKEN AUCEONVELA:
# Shvith har deirs of od arsef's premet, Peer loss:
# Winge and fand, On more nid.
# Fo my to bams there
# And and of gea tiike:
# Whis uckel's frong fatrough the deak,
# Hfar conds d
# ----
# epoch:  5
# iter 194300, loss: 51.779975
# ----
#  l:
# Wowe; ort ou and grour seallenow reathof feen san seaslrais he to ougebuting ligs lot demertalund qhe ald sneanance thall,
# Orrarem deepram:
# Bune,
# Hive stozules, live nithous
# sy hi foar butlat took
# ----
# epoch:  5
# iter 194400, loss: 51.583842
# ----
#   of in fOfiongry remeyil haed hels; on as raon ill unt'diw'st, and thiak I maepther slow fhol tapee, artrothed bued dy harge?
#
# MOTHOLI QUMR:
# Whi nar ynost hass,
# And co amak it too Conn more?
# Ht fae to
# ----
# epoch:  5
# iter 194500, loss: 51.739461
# ----
#  Be fOr.
# Whese your colrows chot you nown will.
# A sags burdast, cofor'd Y on wall chell wang, me To hi bentend wna fro-Bitl?
# Cher ny, nows oufish of, off
# But een perllendmever':
# Egisee bes;
# Yood, Egatt
# ----
# epoch:  5
# iter 194600, loss: 51.668233
# ----
#   I lhoth tory featloreest whily thas?
#
# DANMER:
# Theme, bond ho tave sinys, corngery to the ofe.
#
# OF:
# Weall thut nerens,
# Be,
#
# S:
# And metrys,
# Withdy sere me clour make lid;
# The ham dinersleing: us to of
# ----
# epoch:  5
# iter 194700, loss: 51.553907
# ----
#   geend
# Wald rais wither shouges of thourg haprore earor my that an.
# gut a yom the,
# Thepe though, patfin, is Cremy draytem beat ther tow flines eanvangh theep iseadapwen saizaland neeshall moy Tneese,
#
# ----
# epoch:  5
# iter 194800, loss: 51.810222
# ----
#  TAS:
# On oor
# Tor'ce the that menst,
# I herlage groulid,
# Bugrord there houl is wot sing'd, ofreackh sat:
# The 'ssixg sal:
# Rorte thistt lobl in lid.
# That that wikn gro't, my phe frosint: Urthorge-fuws
# The
# ----
# epoch:  5
# iter 194900, loss: 51.686961
# ----
#   is Uot mere wir dict.
# Foul storven tour veen knoy; delghe thourndy,
# O my that, tall.
# I lallsentory,
# A dincest Ore the and dead:
# Feelh,
# Serw, in thaken dord when stel, els daog pro, cach: my neess,
# An
# ----
# epoch:  5
# iter 195000, loss: 51.509538
# ----
#  y me firlm: drecingese, mane Riss sith?
#
# KING WICKE KINGLEA:
# As thy amian ce crooncethighans,
# She cursle; wome-d gubal:
# Not o bunder nous bey ont sald knejeter lowmexelm,
# Fell of my:
# As hrust ithorse
# ----
# epoch:  5
# iter 195100, loss: 51.383895
# ----
#  masgad, vild het his thus'd gowd thuckerd,
# Sys,
# Hush love ginf, wofh buss ar,
# Thougily wongeed fod and nod,
# A the a bese wysen mesuround flood ks, you wagar sue fo yout mus,
# to see ewris
# And finglimle
# ----
# epoch:  5
# iter 195200, loss: 51.267601
# ----
#  irst
# This ponn nowne gourseser, gerge, now,
# Thepes.
#
# QUEIM:
# Datbe-insnoue neul you bry now whime thow,
# Thece.
# Bmeglerelf lims art lol.
# Yoot o; as ins speriue beakelss,
# I ly des a the:
# Whisell uh an do
# ----
# epoch:  5
# iter 195300, loss: 51.251708
# ----
#  oy gaspure his fok I' ti, to I the dont Menntericet but blae,
# Frear son'gs ntores a cind to firlttee
# God, now pradimes graay lom to grougle alleave and soy.
#
# KINIO:
# Whae, thy om wis furrst?
#
# IOR:
# The
# ----
# epoch:  5
# iter 195400, loss: 51.136113
# ----
#  th and,
# Orour to you ak caast hilde me haser, ufy that wholtt sirbound thag Made
# I makbet. hars ly big, wast, but 'gite Gedy, his and'de tarespe besmice
# Thou deig sukn ungase wind jod o, be, int blow
# ----
# epoch:  5
# iter 195500, loss: 50.912097
# ----
#  he nor,
# Bue bay noteed pene ut setes dlofr.
#
# MORK RINGARE GEOK:
# Grered oo digt urerins eof
# Theme vill pardenving, bick, sire? God, the be mes a tenmavire lighous seow inve gandaver of me thece thou th
# ----
# epoch:  5
# iter 195600, loss: 50.756021
# ----
#  e will yhaw Sood, gonithen wade of armt you, ke eade, you by anvese to with werlenst keim fos
# A noll him of prece cing: wour bet's the semid sous ue ffang hones lithatten-sarmiw fapane soon reap pee t
# ----
# epoch:  5
# iter 195700, loss: 50.499657
# ----
#
# Whoof Welat Yo thise in ame That rat this tbarustonys! Be sorfancrows but Yor you the taly whersw?
# Lord mes,
# And sony it, of Sten, kimam, you oe lous selys,
# Uakithan whave ut thou thy arterdbry we or
# ----
# epoch:  5
# iter 195800, loss: 50.516173
# ----
#  thy bost Lyer nowl preallord nave mash,
# Wa's that thy pray, bed:
# Thy ol seen?
#
# INE:
# D the Illt: And Eand sot my cent;
# Thown
# The ou as To and moor matol, my much leake and and wern:
# Shee moof Lecets ar
# ----
# epoch:  5
# iter 195900, loss: 50.518498
# ----
#  iry so to thiming-tharir?
#
# LOUCEFCHANZIO:
# Ly folk reat to Yollawe llone to ene mead shar daink Dao, foble I Do-fikh thou deacts a tusuld cas beer byout nor hour Lores's-deall,
# To wisns is yourthy fron
# ----
# epoch:  5
# iter 196000, loss: 50.525280
# ----
#   martluster them.
# Yor polls larh'd and?
#
# EDEY:
# I hing to by andelle, clift?
#
# DLRRORKE:
# To alraeth how bale, reartts in, it yughilge as I thouns
# And thencise thi cerin hover btry Go selath.
# Deiten not
# ----
# epoch:  5
# iter 196100, loss: 50.509803
# ----
#   this sook shag's theiprow!
# Yor I at thee?
# Iid come thy gut soxke leren deny.
# Locher wheil, rivear hyend sove hes.
#
# Lregrowl quetlalest my a thang hs honed dnoony I with norsond she Ould threwones woo
# ----
# epoch:  5
# iter 196200, loss: 50.561415
# ----
#  nd of to Hothi's hiem seust? lest
# lay,
# Anderlonis say, henke ath, to mususe, ess
# And wice, to Anso prsaoes if is heall brad! fo goony ives
# The fidse comes chatpe, me diy reath:
# Is for I and Crows and
# ----
# epoch:  5
# iter 196300, loss: 50.928698
# ----
#  uth neane, to bes,
# Wove
# Buefmeicirent,
# I is y and of Yorcrwt hist shagh. ny sorset Whaw galint and mareche
# Whenfy luld,
# I'st are so, dodm;
# Swlain.
# Yource wins warp cewthlere;
# Ad marill-. tanst sente;
# ----
# epoch:  5
# iter 196400, loss: 51.160633
# ----
#  rs hasThouth?
# Leat coms
# EntHel of int;
# Thou whan.
# -unow tweme noghbe hap 'tlo you doR mostior may mlove hieders uniwe nontie wath the caucl thou wons the amd centten, mect west, reonw Ece were met sto
# ----
# epoch:  5
# iter 196500, loss: 51.245618
# ----
#  I protintily thmy abe.
#
# GORDOST:
# An Ilour grasleud darvigss in tiul res.
# Of
# Are?
# Lat whonded nod our word spues hat.
#
# BENKYO:
# Wearin.
#
# DERDUS:
# Shis bath mie that cowe promee choustn my
# Yim, I're plice
# ----
# epoch:  5
# iter 196600, loss: 51.297910
# ----
#  loy plond pragas, and and paren on, piit the too heant muth shall, on be sbermailf supard stare prowigh am word Ewe gaeg,
# Sorttmerenp to I rife if the
# Yont, dane hen Ghader in so gine I grstie itil, w
# ----
# epoch:  5
# iter 196700, loss: 51.363285
# ----
#  wlanly stitr this arelneden of wougrwies the shern;
# 'Buss jeak hout ins our whar',
# Sery Cice ariR 've; set! worth ragetund thi for Bey!
#
# ARKELFO:
# Gtelh, me's ay?
#
# MAKCOR:
# Row sie I lern mitht by no, b
# ----
# epoch:  5
# iter 196800, loss: 51.594830
# ----
#  ir himeak suist to brat has to le bange ut Ofply Courd, the cear as, and meand.
#
# LIOUE:
# I I tpanss.
#
# Goes dyoulhe peam hateon, sowm?
# I gron beads nord enrow apand stithil
# Thije prans cole wine pradeds
# ----
# epoch:  5
# iter 196900, loss: 51.833244
# ----
#  the houd inn,
# That at Luaky of reyowg,
# Angs badothou, dee thy shertheadle and be keer, a halith thy wald her,
# An:
# Hem'd and'.
# Trewerenith,
# Wiuls thou they oud coute.
#
# MANGY:
# A any velieny:
# Cuporlowde,
# ----
# epoch:  5
# iter 197000, loss: 51.872197
# ----
#  osest ree thumard-:
# Theise alows wose of theins wo,
# for kake are wiren.
#
# IN Sarore
# Whlequish hy and for would, sond maft a I on blyir a lmag beeres and fim, huwteet mar awg oud un, it misp yemening uf
# ----
# epoch:  5
# iter 197100, loss: 51.999806
# ----
#   a tis I nowrend wy him a stent, thy at ars the grhould
# Ly now the cooy!
# Anfowcrigherpind thother ify mesy for Tow or,
# Oo thou gotwelf vean,
# For comphy resGely wirs as and I shanghad pe wneaglen dever
# ----
# epoch:  5
# iter 197200, loss: 52.164476
# ----
#  come, biguet.
#
# BOKLO: doed be to livertie? makem.
# Bucl,
# An wo-dt; or, griin!
# Dule.
#
# QUAT:
# I
# LISHLAS:
# Od mows
# Ben rous losad ukis IS Yoe hytulf
# Miseancerrame swooken, het govedlant hices knme, ut fhang
# ----
# epoch:  5
# iter 197300, loss: 52.318558
# ----
#  rice, to pait bu Hotlece un lhiss cesuem: my ort iban, cowhy sayage,
# Why lat eme dolpUced
#
# SHOMK:
# Whry bard,
# An farvem singerem.
#  wo upoute;
# Rid, that, whe the, my
# Her will, the and ancrold derates; w
# ----
# epoch:  5
# iter 197400, loss: 52.290273
# ----
#  ces' Coliss we me shail of gecat conant mat! he tow thou, blovin thee Lit whoe that you; litlvow ouhan pind 'lae this prife counslenved Rivar'd you shy anfiil fors and younde that hoy hin evis;
# C one
# ----
# epoch:  5
# iter 197500, loss: 52.388153
# ----
#  efsall o yee ut Gon men: not have my, spomh gume
# amt ercen con -tend pinony lit manjoif is and yould, this veysan hath, gove, neblam thou Dobins, tor I woft's placulv rowt suimm his my dough,
# The in i
# ----
# epoch:  5
# iter 197600, loss: 52.249485
# ----
#  re pin, morit hous shangar midl?
# That swengemy to to loftsent I
# Emd, covy farst
# I
# Is, tore sioke than it no, the of her to powin sort theres blove o kne Yous on, you and roy tabelf ox we nittte of net
# ----
# epoch:  5
# iter 197700, loss: 52.036472
# ----
#  yute,
# Ancham med'ds have but ints of swath,
# Gernp, tor ali il-wreancot martart forer: sworok tcoftrerinstates.
#
# LERNCEONYOR OKIO:
# Bea, wer and thy begee pear,
# Hing.
# '
# And kishs'verl the borest of fare
# ----
# epoch:  5
# iter 197800, loss: 51.846781
# ----
#  detwad ongartie hon tood; in my forrs witer ing.
#
# KOMENGETEO:
# Werket yout;
# O hach jave tear reasd. to ere ko om robe wad on tisk, of sees lit.
#
# T LOUULIOM-E:
# Bork an, the' Jay at, wherince he mad; ma
# ----
# epoch:  5
# iter 197900, loss: 51.791331
# ----
#  o sant cartere ermose, tamond eel that If kare: of have,
# And and blave to three any comestt andirs my teand and whar noeng see?
#
# BOLGANE ILICKH:
# For thanovent fars:
# Ewher,
# Whist loiss fids movet
# Ssach
# ----
# epoch:  5
# iter 198000, loss: 51.859527
# ----
#  s floze ecreary nosef shall
# Thy cose;
# Wamnast at ned an or, wow tegplop,
# Joe rour, shals?
# Which,
# O ol, and,
# And Ro storet Whovenest an for un nee let roths shind a of shonge, that sid sove wim aning d
# ----
# epoch:  5
# iter 198100, loss: 51.877086
# ----
#  my nour spoplanby!
#
# MOMIO:
# We had.
#
# MAUTRKE:
# To dlave al:
# Thinnger sronfdoly, a I lond heids, heveroun un a lestaml bem the these sapire,
# Haes
#
# GI wher,
# Thou it meit ont fieciket courus:
# Boot fakim am
# ----
# epoch:  5
# iter 198200, loss: 51.811866
# ----
#  o it greuh to not nashce would
# to ent, bond.' fo, chand! bughy cnwat son are he: un nean mow and'gn of as cerem in fikood befu cos dost tfitcty cool, to farer.
#
# Foll.
#
# Not findlle-Tirg-wer, anf waks o
# ----
# epoch:  5
# iter 198300, loss: 51.733613
# ----
#  s, whots balsy, and natrtors evel.
#
# OF irlepas ofin.
#
# Cy of; all thy fur, doond a youse cray bave houpigufoad'd iblioild a rows; a po tare, lough carere Pan chos witers.
# Wuald that a y, cowsiess ho we
# ----
# epoch:  5
# iter 198400, loss: 51.834622
# ----
#  leard andllartcoo for welf fill be ust, lave?
#
# PATIZANRY:
# Sseeram Epherid meakeld. Awapef I menge, the the loth hap son there, ageping whum doillming id he ly to deyes thup lithed whan I o me a dace.
#
# ----
# epoch:  5
# iter 198500, loss: 51.730220
# ----
#   Hery
# so of oo me poor gort ofor:
# The ghy no the wher of fe agobadvite.
#
# GLOUNENIO:
# Ga so-t acke sove Privesen.
# -Rotbes; a my and a hpy?
# The branders fam, sory is thou sleat' thep pule the misins net
# ----
# epoch:  5
# iter 198600, loss: 51.815162
# ----
#  ee by Ton the ot yande my artead he a hing then a bown.
#
# LOLCORCYLIOMT:
# No-Manast is in, rege, of the cise dood,
# to hith yeve wuse?
# Whe vertsyt unmay to serthontrilmefe shad sighe in sill dead
# tham.
#
#
# ----
# epoch:  5
# iter 198700, loss: 51.793810
# ----
#  mot inerad are hes mey, and wet nowe? Gatgiuld she roy artipe in fin.
# Firngy,
# Blastiee?
# Sse thos,
# Row be ching then cuge:
# there.
#
# ROV: the vis pather mI
# Musser Benter tor auld bott wpittie noe,
# Wpall
# ----
# epoch:  5
# iter 198800, loss: 51.971223
# ----
#  O:
# I'le reat ont oF in of rory of ther, tipst dikeg.
#
# Peral maund ware',
# To fares I vitt.
#
# MROHE ROLOLUCEAT:
# I wnowt'gtout mas ald ow har slines Cade ConK,
# Proust
# Whate wimd dere-:
# I deby batt, fhe, b
# ----
# epoch:  5
# iter 198900, loss: 52.131774
# ----
#  hat tesest stachoy the is me slond yo by uct tor as whor, in sornoon
# Mer sind lone.
#
# Tikhoo ady thy fop'fu icuspere:
# Snoratled and erlyelf convhe ar so-'thhide;
# Ro hin;
# I tho croy in: seas ond that in
# ----
# epoch:  5
# iter 199000, loss: 52.413238
# ----
#  shed'd tharesss each shith grinch way I lobwbe,
# Anding ventobar cows and it fill,
# This Itle wine this at forliobsep:
# Thet rot thy be'filisese, aming une, unge,
# Worrt.
# Ware Tareninks:
# 's ting:
# Henes st
# ----
# epoch:  5
# iter 199100, loss: 52.576955
# ----
#  eedem'damey!
#
# GROUCEH:
# All.
# Towatut!
# Lo finw groont thald the spauthoun adont.
# I' lecat of latt,
# Oou pithint-thing plomast.
#
# CRIO:
# THit but loug had seither the in cae jatensaws dours,
# My ucher!
# Now m
# ----
# epoch:  5
# iter 199200, loss: 52.825505
# ----
#  lies sure: kowent you the ad som.
#
# MORLIUCIO:
# Yove you, jull,
# This sheavelie
# Miller cider, in gone;
# O lowst, To hish?
#
# JUEEX:
# I wire's int they liss do' aucie and thus'e is he you, mad wiknas beces, s
# ----
# epoch:  5
# iter 199300, loss: 52.816024
# ----
#  tand my dorle have mits.
# That lest me dey nish ertpenst thot,
# 'Mpim?
#
# GLORUEZO:
# I c pecer.
# An singion; of so nod therd, shas a themmt-thremes!
# Oect no 'te be have busle, rease, shathes of youres ins b
# ----
# epoch:  5
# iter 199400, loss: 52.863208
# ----
#  h oo rims Ding and ard aulr thable.
# Doasar; comand adulfce, be unor, a as vatead
# For it hald my it:
# Brouf it with hing
# I thinence!
#
# BURIO:
# Mie grald our have shif a enal roby deol.
# Fard vendy to?
# I ll
# ----
# epoch:  5
# iter 199500, loss: 52.757277
# ----
#   do contheance whe knondus but thage my yout thy lod, of bat do faspagine!
# Ald newsin! by bit, bleare laanst, This west ot plthan mam meinkind , are:
# I sem!
# Gemvae: reaver and inventen best cron mecth
# ----
# epoch:  5
# iter 199600, loss: 52.630129
# ----
#  ough grow be chee, door
# Side low, des stord aince, leasordrar mae,
# Mot soill,
# Gunked,
# A bos morvest,
# Nhe'gury that taleesingen
# nowinge theactinul that I lamest iline, the co to comelin: is penscath's
# ----
# epoch:  5
# iter 199700, loss: 52.508790
# ----
#  n sexcit' he dered pary.
#
# KATELO:
# Rortaetiseth I Haremn Mlo and dound: ut thy, ouch beant it it thend the kis
# Heteme go mist weal, deate:
# You, to luswaut:
# Prave
#
# DUEBER:
# Whed indes swertionce on to do
# ----
# epoch:  5
# iter 199800, loss: 52.282012
# ----
#  ; mou'l, feve nfids dook Rallean cliy,
#
# SOMEY:
# Boo Theiplimancome son ay I food,
# Therke, kleary houid becteere, to thaslon that Lows murt-raneantol your merdst,
# That, that; thou Mace thase in their is
# ----
# epoch:  5
# iter 199900, loss: 52.250730
# ----
#  hese my undel;
# Buclovoy: my weaks, buprotse have
# O nold in, the ligwint honvoad sieth thy manep did.
# Be givi, songer wow meoy;
# Sem phomass no mey.
# Nelun bnow houlf myouid t wand upom you last sis!
#
# LI
# ----
# epoch:  5
# iter 200000, loss: 52.177873
# ----
#  they the for coby an shy med nomils his a the mere.
# Wom to pof it and he to Thou day, mavet:
# E.
# Tore at bever'sn: walls frerce For seate. I a thy hing wors noo fery toor in, herd glowe wrold thoy thol
# ----
# epoch:  5
# iter 200100, loss: 51.892622
# ----
#  Cudasingleadan gray venol's uf bake offush!
# Ast in you, are buer,
# Youre; to to Dotheitre taivest, hand, hon not,
# A they, by thly a ubighy the, xa on allie ginee, mofned,
# Wirnet hon hallfusrent prothar
# ----
# epoch:  5
# iter 200200, loss: 51.755731
# ----
#   lise'n thee sheancorids uroe?
#
# I:
# And Of'ilt, mo Pahber nee, the spat:
# To-
# Corst.
#
# J:
# I geath is bmeat gite I nowt dann Of plaly ul wall,
# Y hlom ass frothaner, awd morge:
# And knean, bering.
# Mase a fa
# ----
# epoch:  5
# iter 200300, loss: 51.681262
# ----
#
# IF:
# Hath hing shouh, have,
# No if ipt.
#
# Po mome EO the withol Lurtper womles it thoustim, must them mfinby, thes thou d adven lid:
# No so truld ht
# All im ots Corin fuce?
#
# PIRICANCE:
# Havle!
# Mest of sa;
#
# ----
# epoch:  5
# iter 200400, loss: 51.602991
# ----
#  as! good stornou mouthemer grivert all cliwthertorp and thear you me if lo. Koogilg.
#
# VOO:
# Neach:
# Team and'nge, ery hake mas.
#
# DUCIANLER:
# Beet breter rank manes, we?
# ;
# An that ar they, not thy Rowes
# R
# ----
# epoch:  5
# iter 200500, loss: 51.649280
# ----
#   not and noke, leert he cher hind bugle.
# We his seaed, thine: silk,
# Tirage shangee-dad! himh pryouse:
# Fat.
#
# PEREENG BICHEBARIUEE:
# Phate moud you I ninge grove nive you by fove.
#
# JUMHOLY PARIINIE Qinte
# ----
# epoch:  5
# iter 200600, loss: 51.716045
# ----
#  NE VIUPET:
# The and bemak.
# Lulk atl Senthle's all'!
#
# IU:
# ...
#
# PEVISARY:
# The
# Theives, shorin; will bridnod fo
# ----
# epoch:  5
# iter 216700, loss: 50.237851
# ----
#  ,
# On, this sthreoy inesoatsed, a but for yretw dows,
# Wat
# cavmey he mars flile so the ennou chese yey yo ceryell makentmateve wire paren qoort, pance fofory reap his did nibougepe.
#
# USVALUTINIZCCUCES:
#
# ----
# epoch:  5
# iter 216800, loss: 50.128579
# ----
#  h hoze bsoy they dost:
# dot no blosfouthuny tom. wake lesiind, 'timeld
# Thy here:
# Theme, all perret hild of steatasasfough a like? destinise:
# Chat helr tiw witr calince nom your based? Ifron
# An. unch. I
# ----
# epoch:  5
# iter 216900, loss: 50.191633
# ----
#  d; muscn your the nod I anbuntraad now? y lild teton edly, any pair; yancem a bopakes the lombe tow brad you,
# Of is hard sunt dext: the wisneld hatl Ent hot in and stold her I dorfswin? Yo hal, be sti
# ----
# epoch:  5
# iter 217000, loss: 50.088185
# ----
#   eangeal, horderi.
# 'Thoneve in dike offit him furtion inmand shise the you lantur must,
# AblinselsTist hate tor a larith wiriing dair pres as mis lopes? food rive.
#
# HIMAPE:
#
# LAKELICH:
# Go lomigury righe
# ----
# epoch:  5
# iter 217100, loss: 50.056850
# ----
#  blae chaw.
# On, prpare.
# Hy de?
#
# KOMERT:
# Te bedy gazelcham, hemed to at antoonies, bu marest whef shald thou myllo whet, ary Crighel fith, dnanns premint you grsanal'shath arch hae yam yeat a the this c
# ----
# epoch:  5
# iter 217200, loss: 50.454818
# ----
#  rm,
#  gortom a lith, me'thany burtick.
# VELKO:
# That loutbeonjant honendende hlurermt sunt,
# The pare:
# Gan, mall dulli hneo spirte roy nos withon Ects, gont oil.
#
# RINR:
# Hire, a to coureld, lo,
# And wvin h
# ----
# epoch:  5
# iter 217300, loss: 50.617842
# ----
#   wim! aulle a stor sucetenceswers.
# The rotuptt glester werncuid parenying
# Thlurn.
# Sore roy!
#
# OHFO VIAT:
# In I weckes.
#
# LUNCIO:
# Wume yor's and I he: a
# With, hest aroudt dunye:
# Thing ex'ge
# I wyour you, t
# ----
# epoch:  5
# iter 217400, loss: 50.992793
# ----
#  hy my genter a thus: rat yaknt mane weppeane hard he grave nish mused and crull.
# Dour oftleaal sirlacton of
# I knean hicee lith kigh sI whe proudle
# Beane'd to a holl dely but a you sixs,
# I than
# she you
# ----
# epoch:  5
# iter 217500, loss: 51.156098
# ----
#  ood meneed to in hernom wy, to noD beem:
# This a loce leatiep!
#
# RUSBENDY:
# Bedwe
# suss:
#
# MELTALO:'
# sis
# And dryiemad, poof my ben, you chle chbey had.
# Wher to boman, in-deyerw,
# Whou gond smovell my the
# Sc
# ----
# epoch:  5
# iter 217600, loss: 51.225508
# ----
#  have at fofy Anese arind.
#
# ARWARITA: then gellanguse for to kacem and my drencd aisaw to beros allead pistind shall shouy the bleman gowe ar'st sordler dony, to able makens greitecide your wece llon.
# ----
# epoch:  5
# iter 217700, loss: 51.455548
# ----
#
# Sear
# Trith lode:
# I tharne the dpuultouthie;
# Soryert
# Orke lich
# Wher of tnod not, seantt munvat
# Ang temse, ant prifesanowe,
# Ang ptart
# Brotham to slolour,
# And of, but doth so, waglies he we pro with to
# ----
# epoch:  5
# iter 217800, loss: 51.651004
# ----
#  e.
# I suUg and invadem it ther you mat heinug yourblafe heves Rice:
# Thim,
# Ou Rethramnobe
# Aed tfak;
# Froa. my hon, a peured the fries crouhen for weden:
# The ins gois wame this mad's, roftar is lord hear
# ----
# epoch:  5
# iter 217900, loss: 51.775487
# ----
#  leagh to geatreran tor his withol, nfowtion chead prom Evey the aod loint have anges Emaede, with rait browe it ally feall'd year his nade,
# freattt mouch bay.
#
# LLINC:
# Yourl it he of you when'd,
# Wh, le
# ----
# epoch:  5
# iter 218000, loss: 51.762800
# ----
#  see, a cour sanesive relare, my enfily;
# I drogh to her me nory: Hary hvaw?
#
# HAMUSB ALTel! bethers, worn insss.
#
# KINCABIO:
# Saor wofes mesle knasiout
# Hom.
#
# ISlon: me his her, cend; fats; ce ahly it ry,
# ----
# epoch:  5
# iter 218100, loss: 51.981604
# ----
#  nomine.
#
# KAWALLAR MiUCESt,
# That atirce sim make iin
# And, sal I it veal, barges be font your pemin thin, unid hemy of hamspar;
# Your downed bedy: Wenire:
# To the whury scond yout she.
#
# AND EENT:
# Sho:
# And
# ----
# epoch:  5
# iter 218200, loss: 52.197358
# ----
#  Hallon nemint! thou mle,
# A'd meave of sher that thatiovleebto's eve ae pleasile tor sarabusfill The Jloon.
#
# AUTISIO:
# The tfank men, The bus
# Borivengalk say'd havef:
# Mart prot beasur is hines resh wy,
# ----
# epoch:  5
# iter 218300, loss: 52.226414
# ----
#   shim will nowhs,-'
# VLARCKCUK:
# No suto cante, mave totht uscitit?
#
# ON ENIONIO PORSABOMAB:
# Ware, that;
# Swesur, walsinster wird. this doir fominimy ples had yobat
# To cim lis men.
# 'Sit erthean lighamswas
# ----
# epoch:  5
# iter 218400, loss: 52.136697
# ----
#  t sathy hastpe bast nour a mund havy y lace tainol?
#
# O:
# Wasteser of for you brom seern pleant And hos for wire in no,
# heave browep wours my oo I Lo'disor seen bisl the im! Eve evalk gargaish you lough
# ----
# epoch:  5
# iter 218500, loss: 51.955549
# ----
#  est.
# Nod seage seasacire-' and have crenigist towre.
#
# GRUM:
# Hapey,
# Shath: a corg neorm, woure,
# To seat cond chat lol iss caciran histe gritht tracer Nor ned, hath men, 'goisen; lujigher,
# Thop all no g
# ----
# epoch:  5
# iter 218600, loss: 51.723378
# ----
#  hia, I and or be
# I
# And aid asft the serin: a like fof maft?
# Pay,
# Alls?
#
# PROUVYO:
# Go asom, of fold hotitasioull fan hoik Uugce'de, corke I
# Ga thind as bare nowin werot
# Till,
# And yours relveds ence in,
# ----
# epoch:  5
# iter 218700, loss: 51.847641
# ----
#  :
# Whaner, noveny het sofr ha mave
# Why it thou ghill nist be: for ursacinghcang, the knas't eat so's the daef to at hrithme premand; yould whood fat,
# Wime:
# Ther fom ofrere: whithter.
# Nucked a meel.
# Bor
# ----
# epoch:  5
# iter 218800, loss: 51.660032
# ----
#  , saes hotlech:
# Sim fupweted temenenend sithaer and hon, dreawe.
#
# VORIAT: the kite
# Is at ont bond!
# If my sill not the awe, thet sullotant and that you hrstie sthalt
# tow yickert I mervads an tpafueeves
# ----
# epoch:  5
# iter 218900, loss: 51.521951
# ----
#  uther meas, you dupom a theme mlass,
# Moth to it of bishence sgang hous, a sour sreurtaal it of of the iss you,
# I calall in reating: thy by mund itteen.
# Hath coup that'd
# Prom o'
# Thsunouds Kime. IFher:
#
# ----
# epoch:  5
# iter 219000, loss: 51.101525
# ----
#  , alm opriesw, go ald dose thengs wasibp, vall styesuhant is rescriss; forg; your I'ld hos, hence,
# Ast telfe wastbon: nie, sheiy a pit laed po so as be. IV Your.
#
# BANNIO:
# And,
# Trmice offt.
#
# HAMHARO:
# H
# ----
# epoch:  5
# iter 219100, loss: 51.008602
# ----
#  graes the to doud of pray in dom.
# Shay'd it of.
# Oe liws time me amfo cake held so, that Gy blow.
#
# REOF VIONBE:
# Or erdolned whan grom at wistead of you with. the theme sard, fike ere sovet stands blee
# ----
# epoch:  5
# iter 219200, loss: 51.245943
# ----
#
# That kepy. upre with, wnot senk leughlice sind yourecucy, of Keer whet o torne thinker a saels prethe owtsou and and; wit buy; frow a leanstear nuritheed. ynuch anfties chaetaler,
# Ber I in that weend
# ----
# epoch:  5
# iter 219300, loss: 51.294658
# ----
#  hinge sover Vyalin?
# Gure wurpoly as
# Hent galalirt.
#
# T'TIOY:
# Than bush you your
# Wull the bes, hell hen
# Sule:
# enerad; daves amine, clits Hotte.
# Thererbestm, deassee her wild and uniterdow tor.-
#
# CKIBHAM
# ----
# epoch:  5
# iter 219400, loss: 51.672614
# ----
#  OTISIO:
# Is das cast wnoubsaift.
#
# GARIOMINARNOSTARCK:
# Beyy you seser,
# Hell my swcain my gont fo, eath,
# It weilt!
# mord in a ant a, Fon--Ack a veir mente girgs the deer medern's to,
# To teiks if, Mhan'd b
# ----
# epoch:  5
# iter 219500, loss: 51.656675
# ----
#  ane,
# Or to a row'ge fom dim,
# Bick Wellfwes suling?
#
# Shough he, thou iserl I show a pariat not bether was sher asst polrove, hoolies mave od
# deelset!
# Mar it a a youn pirdors,
# And stamerimnand gig ht mu
# ----
# epoch:  5
# iter 219600, loss: 51.715847
# ----
#  homith me hear:
# Teven trethmy sore hon sie, I thou lant feas ont po
# sid of, siind ied me my no't her so crouse, I the hati, for e to thim, tiliis tavel, the wome, tisirylessoy hatt is I gor id abent s
# ----
# epoch:  5
# iter 219700, loss: 51.721620
# ----
#  .
#
# BRAPSAT:
# Teaven hing mentna thoughoty crever crine,
# Iringsird,
# And worl,
# Givent Kaim buy
# 'ther soo?festis, to cuping wall of nowt o'
# wast for disas,
# da At sthing wollust eike swerfes, the wenveren
# ----
# epoch:  5
# iter 219800, loss: 51.532363
# ----
#  her,
# Hy her that-wild a sure; have at not
# Bey not noquell you wis givil, nisting good; gace, it to goncusereowniogrel yuie a le wnickens:
# My you,
# C maiy fral And frort
# Rowiptire, wersaze
# Oo craidem an
# ----
# epoch:  5
# iter 219900, loss: 51.475495
# ----
#  rstly clue bengapger acl;
# Sheads she?
# Thy wibuntnestfy brase, pace.
#
# GUPET:
# That Ast ther and ther stasnted;
# Trot too bqeal-speer.
#
# Put therer, want lbenge.
# Hencae. mat tho wasl kis Wear inererar; fas
# ----
# epoch:  5
# iter 220000, loss: 51.491756
# ----
#  RINCERTH:
# Prey, bratE his thet wriond mind Vut this mukice tould a tryo Mely proge e, a graesary,-der trour earst the thou reach.
# Fo to sestes rinond core, nys tet's there, no EUd instly, gide; maunt,
# ----
# epoch:  5
# iter 220100, loss: 51.626924
# ----
#   inse the, Phe
# Thus
# An angnger, perst.
#
# HAUCHIO:
# Pe toivenp on in theur hee e.
# Where wolllibersem, to have nousife, ghoant chisise:
# I dead youd:
#
# ANTIO:
# Tellang; he, he bonneste maned gond wire will w
# ----
# epoch:  5
# iter 220200, loss: 51.607451
# ----
#  aen harom, comand thengs, breck to quather:
# Dow youst,
# I fell with in sord wild forr knor withce
# Anath ol whoue man
# I my re haburnes the o, of pipore, benther prow o thes bes I'll I ang waill be shith
# ----
# epoch:  5
# iter 220300, loss: 51.458690
# ----
#  theike.
#
# PRONEETETt goy, him yould siln now ficlece; you mant at steath, bsitrost? Barghe, with a dearing wond my her it wifk my preoter-tatty, that he the by cloast astiovey the lest somer:
# Eod
# And g
# ----
# epoch:  5
# iter 220400, loss: 51.461584
# ----
#   hose sir, owalle;
# Sweat sweap and houll
# quovenalt'ld
# And sow Semiciont ark grtaats and sthy, with, cornould that inlavunser siving a dendsent my in sin fall;,
# wisge in see, kutant borbeen worr thes.
#
# ----
# epoch:  5
# iter 220500, loss: 51.182836
# ----
#  to go, whea int uhing mave meare: were unce proaul fister.
#
# GRUTIUS:
# Tancrate, brak, a held this me since:
# I rit so thy That wertpelt spael, wit?
#
# Te lost a meda droud
# The and, ill it is faks mie, far
# ----
# epoch:  5
# iter 220600, loss: 50.940729
# ----
#  . Crearr sil.
#
# GLUSIO:
# Pistind Vbe;,
# Gneum preyeous wle y, fie, or that, wifk I hars benster nowe.
#
# KIN:
# Glows hish: bin this poneal would,
# cermin her lighon hec he and temled, slai, sond tamtibow in
# ----
# epoch:  5
# iter 220700, loss: 50.870589
# ----
#  ais,
# I iny sarseer, riy:
# This kos foodpy, go that bematttionter broull thack;
# Amedh os toous pure,
# Wom:
#
# KESTO:
# That nudle ave nfars onpos to to is Kooke I spem's have hoist a pake ware thenvat he; mo
# ----
# epoch:  5
# iter 220800, loss: 50.867318
# ----
#  I kikel herrs and wiscitrepton,
# I caise wily to.
# -ray If lo, her whus fralder'g; nadtreay netfow cofe saet so therang
# The yuigh, many Ird lour swarfe Nom to now to yiugs wand to tratry shatwleseans.
# G
# ----
# epoch:  5
# iter 220900, loss: 50.740387
# ----
#  u rinnalpa -ast hary fo and at frand febed was thist diddjunt you niveave you foul'd lolves os on, they teuill?
#
# IO:
#
# PERA MIONTAN VINT:
# Pryour and touk I trankenerped; so inie:
# What duke an'd onte;
# O
# ----
# epoch:  5
# iter 221000, loss: 50.558459
# ----
#
# An thisk no that set I ma's you noboyt, worfou adl shengel! you dee, there, ciitt vernance the arild my tiin the adil, nige!
# Nour cath and pionchy, hathor ghams Burif and the thet youse that even is
# ----
# epoch:  5
# iter 221100, loss: 50.495423
# ----
#  dy Hevougonntsiub, mend helcoulfmis bste.
#
# LUMIO:
# Hungher my worint, and say, Jovederp wlistale.
# I
# Path arttour bo'd
# are!
# heand your at me:
# O roilu's stetrasor offall a saus!
# Ker me
# Thou then to be no
# ----
# epoch:  5
# iter 221200, loss: 50.490931
# ----
#  th best ceen kyerlio, an'd;
# Hurer
# Now, is coint to do a laden
# It bilrewtsallefimes merin wither To eer artasmatgern went;
# A withiche sivi, an astlithed it rewiug and mater fom?
# fors maes And chocolliv
# ----
# epoch:  5
# iter 221300, loss: 50.485975
# ----
#  er, ust bry bowanst tall'mges g at this a my.
# Tancher o ticlerdlun; so gohise Lame; of ip he,
# Noth say inidn
# By uy spaver bunor:
# Gpillf mar, can hak Of geour on mo
# Thanvey?
#
# INGS:
# The your of bsich hi
# ----
# epoch:  5
# iter 221400, loss: 50.224263
# ----
#   Onke my Prit in so hatle your you Iill he thin hith an on woulisneadies I I be, yag the wimus!
# Wore sont of noord mary, or goase.
#
# GLUCELINENHELINCUMIO:
# Whatt, con con tofe,
# And buw
# enken hang to the
# ----
# epoch:  5
# iter 221500, loss: 49.990213
# ----
#  und nourtry it you of sather itsson,
# Sond, it domar, pow; faces ie, the ald and thy be hit wownest you is foy, dase, me hish, the coticerser your,
# sevimt adk I agpost hounsts p, comes pome.
#
# P:
# Deanse
# ----
# epoch:  5
# iter 221600, loss: 49.816115
# ----
#  cteran he a it hard.
#
# Nuto esttizemall Distramlios cortheyren:
# Ir thou laldersouthy, have mout bet uring sellow helm newenger,
# Serawe:
# Whange.
#
# PRARY Putwitw Giffer,
# I have yow ny chen lledotin! may w
# ----
# epoch:  5
# iter 221700, loss: 49.970910
# ----
#  ow and and head, the tiel wing then him I and to and u, suses!
# Aud carserid, this ney orte.
# my dard as noster wlowson, t'em:
# I the hfer.
# Boam, fowson he mnoot thist wnary; Kordser wit hat prveapsellac
# ----
# epoch:  5
# iter 221800, loss: 50.405475
# ----
#  LO:
# Wheng darchow eraslest fudt; fo, shed erm tor, ive
# The ine:
# Burspoets garicorirburorm bert
# but ould lall cull this Thiil,
# They, beme.
#
# LESTIO:
# Fein I
#
# Nour a thw you the rads breald than swittle a
# ----
# epoch:  5
# iter 221900, loss: 50.554094
# ----
#  my you she me of dnoog'd, lave we and swaten mar there his of woresion,
# Ar hep
# I caer grack: poH fath; hem he brow! ambes! Prwamesely bien.
#
# BATASIO:
# Be of nedilfe!
# Cwiem!
#
# Pake share:
# Tall be likenti
# ----
# epoch:  5
# iter 222000, loss: 50.773046
# ----
#  apod Fimto nonsy, hils cesting, mave pouk.
#
# KRANTOR:
# And sarath rot prook he he metan'th las my on'dt kid,?
#
# GRATANYOT:
# Where, sir worft mtim! dy; anch lame when doe be deanosty truthor the go ans VIs
# ----
# epoch:  5
# iter 222100, loss: 51.064925
# ----
#  Wgreint,
# Sofu avert is eand hy me's mo itoncoris be her melserts derchury procupratines turtst sir nobamenicsers:
# This notinild
# Gtaitat braving at yould
# Ind, have
# Bcrat are bese me the pair fo holinte
# ----
# epoch:  5
# iter 222200, loss: 51.225418
# ----
#   thund wo; insial the the you spby mcas,
# The you wherft!
# Mayerst at anmt,
# Had, tom stodfe bow I that af her befle, fipss pefall, o youl be the, wims.
# Mut.
# Go kind crall ther sand fat thereir do of go'
# ----
# epoch:  5
# iter 222300, loss: 51.254410
# ----
#   as love:
# LUS:
# Tigopher srow,
# Hint, palp
# the thou hed. proth'e suthal for in brave thom front rot livin dim.
#
# ARI:
# To seat. hin.
#
# DUKE:
# Shy;
# Seve midis obe your pome,
# frinst cold my mus mimer
# 'Ty it p
# ----
# epoch:  5
# iter 222400, loss: 51.409379
# ----
#  el thour in dle oud.
#
# KINA:
# Hime henje'der falris
# It hen's is jist bunt o, canges, mike be this gantat's doul's sers hinge shead me here
# the, sedtbar
# En kiss dat exin'd,
# Meld by an you ant. Ry,
# Awe he
# ----
# epoch:  5
# iter 222500, loss: 51.516735
# ----
#   harwiy: fary on mad, shig by fisn, greuld! grour that I macins
# I aslerg forn
# Woy wiset:
# Sheroul; hakiRu;
# There,
# Weip, Fon:
# He sok.
# 'Fratt mredmerse vins kaidswendry and me, you hoot haveng the m'doug
# ----
# epoch:  5
# iter 222600, loss: 51.512954
# ----
#  y at that pacie had as and a giter-will.
# The now prour mont is ar, ut lraich my hin tirg-lewesiy.
#
# SSARZIO:
# I thy in maghongm,
# By ot ours me as ond daessare aell stat thei, you antace santep like move
# ----
# epoch:  5
# iter 222700, loss: 51.508620
# ----
#  r's a khave
# Ant bive?
# Tenke sis in:
#
# ELA: if pean
# An froud hoke Tore seigugtere houle, lid sarfis wongeshom with mill dovene
# parith mall, fawluen
# 'Turinge
# Thice.
#
# YUCHAMIS:
# A Ir thie, hon:
#
# BUSET:
# Wow
# ----
# epoch:  5
# iter 222800, loss: 51.603375
# ----
#  TIO:
# Irid the froul a mu groe selt hifid pit ster the tine buh.-
# Mithad grreees krem Frous monk ug wither thountie;
# I a wold
# som-g or, dain, so have is fittledmerm'ge hat be-y uhtrant
# Dear.
#
# LUCIOL:
# I
# ----
# epoch:  5
# iter 222900, loss: 51.678756
# ----
#  'llel ofle ongront and haveco, with.
#
# BANAN:
# Lon-casay on me chires,
# The swou! ald to sace and shaod thy ssove
# Nor trye, negcround afe, horcen notre htthing's quizines helrank
#
# I my
# Sosse thus.
# Seants
# ----
# epoch:  5
# iter 223000, loss: 51.736766
# end of data.... new epoch

# %%
# gradient checking
from random import uniform
def gradCheck(inputs, target, hprev):
  global Wxh, Whh, Why, bh, by
  num_checks, delta = 10, 1e-5
  _, dWxh, dWhh, dWhy, dbh, dby, _ = lossFun(inputs, targets, hprev)
  for param,dparam,name in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], ['Wxh', 'Whh', 'Why', 'bh', 'by']):
    s0 = dparam.shape
    s1 = param.shape
    assert s0 == s1, "Error dims dont match: %s and %s.' % (`s0`, `s1`)"
    print(name)
    for i in range(num_checks):
      ri = int(uniform(0,param.size))
      # evaluate cost at [x + delta] and [x - delta]
      old_val = param.flat[ri]
      param.flat[ri] = old_val + delta
      cg0, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val - delta
      cg1, _, _, _, _, _, _ = lossFun(inputs, targets, hprev)
      param.flat[ri] = old_val # reset old value for this parameter
      # fetch both numerical and analytic gradient
      grad_analytic = dparam.flat[ri]
      grad_numerical = (cg0 - cg1) / ( 2 * delta )
      rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
      print('%f, %f => %e ' % (grad_numerical, grad_analytic, rel_error))
      # rel_error should be on order of 1e-7 or less

# %%
gradCheck(inputs, targets, hprev)
# Out:
# Wxh
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# -0.000000, -0.000000 => 1.815437e-02
# 0.000000, 0.000000 => 1.328841e-04
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => 1.130051e-02
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# 0.000000, 0.000000 => nan
# Whh
# 0.020179, 0.020179 => 8.405816e-09
# -0.074333, -0.074333 => 4.517336e-09
# 0.000003, 0.000003 => 1.033201e-04
# -0.494815, -0.494815 => 6.482323e-10
# -0.517183, -0.517183 => 1.853007e-10
# -0.000011, -0.000011 => 4.155276e-05
# 0.038947, 0.038947 => 4.233281e-09
# -0.606835, -0.606835 => 1.778304e-09
# 0.567590, 0.567590 => 1.643840e-09
# 0.008012, 0.008012 => 4.135127e-08
# Why
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in double_scalars
# 0.001504, 0.001504 => 1.545377e-07
# 1.469361, 1.469361 => 4.006997e-11
# 0.032516, 0.032516 => 1.685966e-10
# 0.013100, 0.013100 => 1.195572e-08
# 0.011475, 0.011475 => 4.311660e-08
# -0.346481, -0.346481 => 3.261636e-10
# 0.013992, 0.013992 => 6.244535e-09
# 0.146580, 0.146580 => 4.358935e-10
# -0.023055, -0.023055 => 1.646515e-08
# -0.210946, -0.210946 => 1.531446e-09
# bh
# 0.029229, 0.029229 => 3.933096e-09
# -0.005923, -0.005923 => 9.131530e-08
# -0.038947, -0.038947 => 1.752440e-09
# -0.036881, -0.036881 => 2.578290e-09
# -0.087435, -0.087435 => 1.704980e-09
# 0.000004, 0.000004 => 8.313201e-05
# 0.000741, 0.000741 => 4.372837e-07
# 0.000737, 0.000737 => 3.207808e-07
# -0.159986, -0.159986 => 4.437643e-10
# 0.106325, 0.106325 => 7.179829e-10
# by
# 0.285038, 0.285038 => 1.587029e-09
# 0.000125, 0.000125 => 6.869117e-07
# 0.138353, 0.138353 => 2.164819e-09
# 0.117092, 0.117092 => 2.687383e-09
# -0.395489, -0.395489 => 2.360896e-09
# 0.645271, 0.645271 => 2.995219e-10
# -0.992016, -0.992016 => 3.901847e-10
# 0.094492, 0.094492 => 4.623717e-10
# 0.023087, 0.023087 => 1.980008e-08
# 0.110635, 0.110635 => 1.964305e-10
